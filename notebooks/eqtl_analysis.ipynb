# %% [markdown]
# ## Reproduce Figure 5b

# %%
import pandas as pd
import ipynbname
REPO_PATH = ipynbname.path().parent.parent

# %% [markdown]
# ## Launch predictions using Variantformer

# %%
# Essential imports
import sys
from pathlib import Path
import warnings

warnings.filterwarnings("ignore")

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

from processors.variantprocessor import VariantProcessor

# %% [markdown]
# ### Load data

# %%
variants = pd.read_parquet(os.path.join(REPO_PATH, '_artifacts/b23c9b69.pq'))
variants['tissue'].value_counts()
# Out:
# tissue
# blood                              17724
# skin                               14723
# adipose                            14671
# brain - frontal cortex (ba9)       13029
# brain - putamen (basal ganglia)    12332
# brain - substantia nigra           10604
# Name: count, dtype: int64

# %% [markdown]
# ### Predict for first 10 variants

# %%
# tiisue map to align tissue names between VF and Eqtl catalog data
vf_tissue_map = {'skin' : 'skin - sun exposed (lower leg)',
                 'blood' : 'whole blood',
                 'adipose' : 'adipose - subcutaneous',
                 'brain - frontal cortex (ba9)': 'brain - frontal cortex (ba9)',
                 'brain - putamen (basal ganglia)': 'brain - putamen (basal ganglia)',
                 'brain - substantia nigra' : 'brain - substantia nigra'
                 }
variants['tissue'] = variants['tissue'].map(vf_tissue_map)

# %%
first10_variants = variants.head(10)
first10_variants['chr'] = first10_variants['variant_id'].apply(lambda x: x.split('_')[0])
first10_variants['pos'] = first10_variants['variant_id'].apply(lambda x: int(x.split('_')[1]))
first10_variants['ref'] = first10_variants['variant_id'].apply(lambda x: x.split('_')[2])
first10_variants['alt'] = first10_variants['variant_id'].apply(lambda x: x.split('_')[3])

# %%
variants['tissue'].value_counts()
# Out:
# tissue
# whole blood                        17724
# skin - sun exposed (lower leg)     14723
# adipose - subcutaneous             14671
# brain - frontal cortex (ba9)       13029
# brain - putamen (basal ganglia)    12332
# brain - substantia nigra           10604
# Name: count, dtype: int64

# %%
# Initialize VariantFormer
print("🚀 Initializing VariantFormer Variant Processor...")
model_class = 'v4_ag' # model class can be 'v4_ag', 'v4_pcg'. AG model is all-genes model trained on both protein-coding and non-coding genes.
# model_class = 'v4_pcg' # Uncomment to use the PCG model
vep = VariantProcessor(model_class=model_class)
# Run variant predictions
print("🔬 Running VariantFormer variant analysis...")
output_dir = "/tmp/vep_eqtl_output"
# Predict expression effects for all variants
raw_predictions = vep.predict(var_df=first10_variants, output_dir=output_dir)
print("Formatting VariantFormer scores and computing eQTL statistics...")
formatted_scores = vep.format_scores(raw_predictions)
print("Computing eQTL statistics...")
final_results = vep.eqtl_scores(formatted_scores)
# Out:
# 2025-11-04 15:00:08 - processors.variantprocessor - INFO - Initializing Variant Processor...
# 2025-11-04 15:00:08 - processors.multi_datasets_loader - INFO - Loading gene annotations...
# 2025-11-04 15:00:08 - processors.multi_datasets_loader - INFO - Loading CRE annotations...
# 🚀 Initializing VariantFormer Variant Processor...
# 🔬 Running VariantFormer variant analysis...
# 2025-11-04 15:00:09 - processors.variantprocessor - INFO - Loading variants...
# 2025-11-04 15:00:09 - processors.multi_datasets_loader - INFO - Loaded 10 variants
# 2025-11-04 15:00:09 - processors.variantprocessor - INFO - Loaded 10 variants for processing
# 2025-11-04 15:00:09 - processors.variantprocessor - INFO - Mapped 10 gene-variant pairs
# 2025-11-04 15:00:09 - processors.variantprocessor - INFO - Loading BPE encoder...
# 2025-11-04 15:00:09 - processors.variantprocessor - INFO - Loading model...
# 2025-11-04 15:00:09 - processors.model_manager - INFO - Loading Seq2Reg model...
# Loaded BPE vocabulary from /work/vocabs/bpe_vocabulary_500_using_huggingface.json
# 2025-11-04 15:00:10 - processors.model_manager - INFO - Loading Seq2Reg gene model...
# 2025-11-04 15:00:10 - processors.model_manager - INFO - Creating Seq2Gene model...
# 2025-11-04 15:00:15 - processors.model_manager - INFO - Model class: <class 'seq2gene.model_combined_modulator.Seq2GenePredictorCombinedModulator'>
# 2025-11-04 15:00:15 - processors.model_manager - INFO - Model architecture:
# 2025-11-04 15:00:15 - processors.model_manager - INFO - Model: Seq2GenePredictorCombinedModulator
# 2025-11-04 15:00:15 - processors.model_manager - INFO -   start_tkn: 96,768 params
# 2025-11-04 15:00:15 - processors.model_manager - INFO -   cre_tokenizer: 31,826,153 params
# 2025-11-04 15:00:15 - processors.model_manager - INFO -   gene_tokenizer: 31,826,153 params
# 2025-11-04 15:00:15 - processors.model_manager - INFO -   gene_map: 787,968 params
# 2025-11-04 15:00:15 - processors.model_manager - INFO -   cre_map: 787,968 params
# 2025-11-04 15:00:15 - processors.model_manager - INFO -   combined_modulator: 1,157,298,176 params
# 2025-11-04 15:00:15 - processors.model_manager - INFO -   tissue_heads: 4,726,273 params
# 2025-11-04 15:00:15 - processors.model_manager - INFO -   gene_loss: 0 params
# 2025-11-04 15:00:15 - processors.model_manager - INFO - Total number of parameters: 1,227,349,459
# 2025-11-04 15:00:15 - processors.model_manager - INFO - Loading checkpoint from /work/_artifacts/v4_ag_epoch9_checkpoint.pth
# 2025-11-04 15:00:20 - processors.model_manager - INFO - Model loaded successfully on cuda
# 2025-11-04 15:00:20 - processors.variantprocessor - INFO - Initializing trainer...
# INFO: Using bfloat16 Automatic Mixed Precision (AMP)
# 2025-11-04 15:00:20 - lightning.pytorch.utilities.rank_zero - INFO - Using bfloat16 Automatic Mixed Precision (AMP)
# INFO: GPU available: True (cuda), used: True
# 2025-11-04 15:00:20 - lightning.pytorch.utilities.rank_zero - INFO - GPU available: True (cuda), used: True
# INFO: TPU available: False, using: 0 TPU cores
# 2025-11-04 15:00:20 - lightning.pytorch.utilities.rank_zero - INFO - TPU available: False, using: 0 TPU cores
# INFO: HPU available: False, using: 0 HPUs
# 2025-11-04 15:00:20 - lightning.pytorch.utilities.rank_zero - INFO - HPU available: False, using: 0 HPUs
# 2025-11-04 15:00:20 - processors.variantprocessor - INFO - Initialization complete!
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# 2025-11-04 15:00:20 - lightning.pytorch.accelerators.cuda - INFO - LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# 2025-11-04 15:00:21 - filelock - DEBUG - Attempting to acquire lock 128109017529616 on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock
# 2025-11-04 15:00:21 - filelock - DEBUG - Attempting to acquire lock 128109017526880 on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock
# 2025-11-04 15:00:21 - filelock - DEBUG - Attempting to acquire lock 128109017529856 on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock
# Predicting: |          | 0/? [00:00<?, ?it/s]
# 2025-11-04 15:00:21 - filelock - DEBUG - Attempting to acquire lock 128109017523904 on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock
# 2025-11-04 15:00:21 - filelock - DEBUG - Attempting to acquire lock 128109017522272 on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock
# 2025-11-04 15:00:21 - filelock - DEBUG - Attempting to acquire lock 128109017520256 on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock
# 2025-11-04 15:00:21 - filelock - DEBUG - Lock 128109017523904 not acquired on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock, waiting 0.05 seconds ...
# 2025-11-04 15:00:21 - filelock - DEBUG - Lock 128109017526880 acquired on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock
# 2025-11-04 15:00:21 - filelock - DEBUG - Lock 128109017520256 not acquired on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock, waiting 0.05 seconds ...
# 2025-11-04 15:00:21 - filelock - DEBUG - Lock 128109017522272 not acquired on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock, waiting 0.05 seconds ...
# 2025-11-04 15:00:21 - filelock - DEBUG - Lock 128109017529856 not acquired on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock, waiting 0.05 seconds ...
# 2025-11-04 15:00:21 - filelock - DEBUG - Lock 128109017529616 not acquired on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock, waiting 0.05 seconds ...
# 2025-11-04 15:00:21 - filelock - DEBUG - Attempting to acquire lock 128109017517616 on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock
# 2025-11-04 15:00:21 - filelock - DEBUG - Lock 128109017517616 not acquired on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock, waiting 0.05 seconds ...
# 2025-11-04 15:00:21 - filelock - DEBUG - Attempting to acquire lock 128109017516512 on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock
# 2025-11-04 15:00:21 - filelock - DEBUG - Lock 128109017516512 not acquired on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock, waiting 0.05 seconds ...
# 2025-11-04 15:00:21 - filelock - DEBUG - Attempting to acquire lock 128109017523904 on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock
# 2025-11-04 15:00:21 - filelock - DEBUG - Attempting to acquire lock 128109017520256 on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock
# 2025-11-04 15:00:21 - filelock - DEBUG - Attempting to acquire lock 128109017522272 on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock
# 2025-11-04 15:00:21 - filelock - DEBUG - Attempting to acquire lock 128109017529616 on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock
# 2025-11-04 15:00:21 - filelock - DEBUG - Attempting to acquire lock 128109017529856 on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock
# 2025-11-04 15:00:21 - filelock - DEBUG - Lock 128109017523904 not acquired on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock, waiting 0.05 seconds ...
# 2025-11-04 15:00:21 - filelock - DEBUG - Lock 128109017520256 not acquired on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock, waiting 0.05 seconds ...
# 2025-11-04 15:00:21 - filelock - DEBUG - Lock 128109017522272 not acquired on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock, waiting 0.05 seconds ...
# 2025-11-04 15:00:21 - filelock - DEBUG - Lock 128109017529856 not acquired on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock, waiting 0.05 seconds ...
# 2025-11-04 15:00:21 - filelock - DEBUG - Lock 128109017529616 not acquired on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock, waiting 0.05 seconds ...
# 2025-11-04 15:00:21 - filelock - DEBUG - Attempting to acquire lock 128109017517616 on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock
# 2025-11-04 15:00:21 - filelock - DEBUG - Lock 128109017517616 not acquired on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock, waiting 0.05 seconds ...
# 2025-11-04 15:00:21 - filelock - DEBUG - Attempting to acquire lock 128109017516512 on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock
# 2025-11-04 15:00:21 - filelock - DEBUG - Lock 128109017516512 not acquired on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock, waiting 0.05 seconds ...
# 2025-11-04 15:00:21 - filelock - DEBUG - Attempting to acquire lock 128109017523904 on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock
# 2025-11-04 15:00:21 - filelock - DEBUG - Attempting to acquire lock 128109017520256 on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock
# 2025-11-04 15:00:21 - filelock - DEBUG - Attempting to acquire lock 128109017522272 on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock
# 2025-11-04 15:00:21 - filelock - DEBUG - Attempting to acquire lock 128109017529616 on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock
# 2025-11-04 15:00:21 - filelock - DEBUG - Attempting to acquire lock 128109017529856 on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock
# 2025-11-04 15:00:21 - filelock - DEBUG - Lock 128109017523904 not acquired on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock, waiting 0.05 seconds ...
# 2025-11-04 15:00:21 - filelock - DEBUG - Lock 128109017522272 not acquired on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock, waiting 0.05 seconds ...
# 2025-11-04 15:00:21 - filelock - DEBUG - Lock 128109017529616 not acquired on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock, waiting 0.05 seconds ...
# 2025-11-04 15:00:21 - filelock - DEBUG - Lock 128109017529856 not acquired on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock, waiting 0.05 seconds ...
# 2025-11-04 15:00:21 - filelock - DEBUG - Lock 128109017520256 not acquired on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock, waiting 0.05 seconds ...
# 2025-11-04 15:00:21 - filelock - DEBUG - Attempting to acquire lock 128109017517616 on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock
# 2025-11-04 15:00:21 - filelock - DEBUG - Lock 128109017517616 not acquired on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock, waiting 0.05 seconds ...
# 2025-11-04 15:00:21 - filelock - DEBUG - Attempting to acquire lock 128109017516512 on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock
# 2025-11-04 15:00:21 - filelock - DEBUG - Lock 128109017516512 not acquired on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock, waiting 0.05 seconds ...
# 2025-11-04 15:00:21 - filelock - DEBUG - Attempting to acquire lock 128109017523904 on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock
# 2025-11-04 15:00:21 - filelock - DEBUG - Attempting to acquire lock 128109017522272 on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock
# 2025-11-04 15:00:21 - filelock - DEBUG - Attempting to acquire lock 128109017529616 on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock
# 2025-11-04 15:00:21 - filelock - DEBUG - Attempting to acquire lock 128109017529856 on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock
# 2025-11-04 15:00:21 - filelock - DEBUG - Attempting to acquire lock 128109017520256 on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock
# 2025-11-04 15:00:21 - filelock - DEBUG - Lock 128109017523904 not acquired on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock, waiting 0.05 seconds ...
# 2025-11-04 15:00:21 - filelock - DEBUG - Lock 128109017522272 not acquired on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock, waiting 0.05 seconds ...
# 2025-11-04 15:00:21 - filelock - DEBUG - Lock 128109017529616 not acquired on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock, waiting 0.05 seconds ...
# 2025-11-04 15:00:21 - filelock - DEBUG - Lock 128109017529856 not acquired on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock, waiting 0.05 seconds ...
# 2025-11-04 15:00:21 - filelock - DEBUG - Lock 128109017520256 not acquired on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock, waiting 0.05 seconds ...
# 2025-11-04 15:00:21 - filelock - DEBUG - Attempting to acquire lock 128109017517616 on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock
# 2025-11-04 15:00:21 - filelock - DEBUG - Lock 128109017517616 not acquired on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock, waiting 0.05 seconds ...
# 2025-11-04 15:00:21 - filelock - DEBUG - Attempting to acquire lock 128109017516512 on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock
# 2025-11-04 15:00:21 - filelock - DEBUG - Lock 128109017516512 not acquired on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock, waiting 0.05 seconds ...
# 2025-11-04 15:00:21 - filelock - DEBUG - Attempting to acquire lock 128109017523904 on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock
# 2025-11-04 15:00:21 - filelock - DEBUG - Attempting to acquire lock 128109017522272 on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock
# 2025-11-04 15:00:21 - filelock - DEBUG - Attempting to acquire lock 128109017529616 on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock
# 2025-11-04 15:00:21 - filelock - DEBUG - Attempting to acquire lock 128109017529856 on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock
# 2025-11-04 15:00:21 - filelock - DEBUG - Attempting to acquire lock 128109017520256 on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock
# 2025-11-04 15:00:21 - filelock - DEBUG - Lock 128109017523904 not acquired on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock, waiting 0.05 seconds ...
# 2025-11-04 15:00:21 - filelock - DEBUG - Lock 128109017522272 not acquired on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock, waiting 0.05 seconds ...
# 2025-11-04 15:00:21 - filelock - DEBUG - Lock 128109017529616 not acquired on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock, waiting 0.05 seconds ...
# 2025-11-04 15:00:21 - filelock - DEBUG - Lock 128109017529856 not acquired on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock, waiting 0.05 seconds ...
# 2025-11-04 15:00:21 - filelock - DEBUG - Lock 128109017520256 not acquired on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock, waiting 0.05 seconds ...
# 2025-11-04 15:00:21 - filelock - DEBUG - Attempting to acquire lock 128109017517616 on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock
# 2025-11-04 15:00:21 - filelock - DEBUG - Lock 128109017517616 not acquired on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock, waiting 0.05 seconds ...
# 2025-11-04 15:00:21 - filelock - DEBUG - Attempting to acquire lock 128109017516512 on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock
# 2025-11-04 15:00:21 - filelock - DEBUG - Lock 128109017516512 not acquired on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock, waiting 0.05 seconds ...
# 2025-11-04 15:00:21 - filelock - DEBUG - Attempting to acquire lock 128109017522272 on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock
# 2025-11-04 15:00:21 - filelock - DEBUG - Attempting to acquire lock 128109017523904 on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock
# 2025-11-04 15:00:21 - filelock - DEBUG - Attempting to acquire lock 128109017529616 on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock
# 2025-11-04 15:00:21 - filelock - DEBUG - Attempting to acquire lock 128109017529856 on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock
# 2025-11-04 15:00:21 - filelock - DEBUG - Attempting to acquire lock 128109017520256 on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock
# 2025-11-04 15:00:21 - filelock - DEBUG - Lock 128109017522272 not acquired on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock, waiting 0.05 seconds ...
# 2025-11-04 15:00:21 - filelock - DEBUG - Lock 128109017523904 not acquired on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock, waiting 0.05 seconds ...
# 2025-11-04 15:00:21 - filelock - DEBUG - Lock 128109017529616 not acquired on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock, waiting 0.05 seconds ...
# 2025-11-04 15:00:21 - filelock - DEBUG - Lock 128109017529856 not acquired on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock, waiting 0.05 seconds ...
# 2025-11-04 15:00:21 - filelock - DEBUG - Lock 128109017520256 not acquired on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock, waiting 0.05 seconds ...
# 2025-11-04 15:00:21 - filelock - DEBUG - Attempting to acquire lock 128109017517616 on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock
# 2025-11-04 15:00:21 - filelock - DEBUG - Lock 128109017517616 not acquired on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock, waiting 0.05 seconds ...
# 2025-11-04 15:00:21 - filelock - DEBUG - Attempting to acquire lock 128109017516512 on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock
# 2025-11-04 15:00:21 - filelock - DEBUG - Lock 128109017516512 not acquired on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock, waiting 0.05 seconds ...
# 2025-11-04 15:00:21 - filelock - DEBUG - Attempting to acquire lock 128109017522272 on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock
# 2025-11-04 15:00:21 - filelock - DEBUG - Attempting to acquire lock 128109017523904 on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock
# 2025-11-04 15:00:21 - filelock - DEBUG - Attempting to acquire lock 128109017529856 on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock
# 2025-11-04 15:00:21 - filelock - DEBUG - Attempting to acquire lock 128109017529616 on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock
# 2025-11-04 15:00:21 - filelock - DEBUG - Attempting to acquire lock 128109017520256 on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock
# 2025-11-04 15:00:21 - filelock - DEBUG - Lock 128109017522272 not acquired on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock, waiting 0.05 seconds ...
# 2025-11-04 15:00:21 - filelock - DEBUG - Lock 128109017523904 not acquired on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock, waiting 0.05 seconds ...
# 2025-11-04 15:00:21 - filelock - DEBUG - Lock 128109017529856 not acquired on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock, waiting 0.05 seconds ...
# 2025-11-04 15:00:21 - filelock - DEBUG - Lock 128109017529616 not acquired on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock, waiting 0.05 seconds ...
# 2025-11-04 15:00:21 - filelock - DEBUG - Lock 128109017520256 not acquired on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock, waiting 0.05 seconds ...
# 2025-11-04 15:00:21 - filelock - DEBUG - Attempting to acquire lock 128109017517616 on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock
# 2025-11-04 15:00:21 - filelock - DEBUG - Lock 128109017517616 not acquired on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock, waiting 0.05 seconds ...
# 2025-11-04 15:00:21 - asyncio - DEBUG - Using selector: EpollSelector
# 2025-11-04 15:00:21 - filelock - DEBUG - Attempting to acquire lock 128109017516512 on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock
# 2025-11-04 15:00:21 - s3fs - DEBUG - Setting up s3fs instance
# 2025-11-04 15:00:21 - filelock - DEBUG - Lock 128109017516512 not acquired on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock, waiting 0.05 seconds ...
# 2025-11-04 15:00:21 - botocore.hooks - DEBUG - Changing event name from creating-client-class.iot-data to creating-client-class.iot-data-plane
# 2025-11-04 15:00:21 - botocore.hooks - DEBUG - Changing event name from before-call.apigateway to before-call.api-gateway
# 2025-11-04 15:00:21 - botocore.hooks - DEBUG - Changing event name from request-created.machinelearning.Predict to request-created.machine-learning.Predict
# 2025-11-04 15:00:21 - botocore.hooks - DEBUG - Changing event name from before-parameter-build.autoscaling.CreateLaunchConfiguration to before-parameter-build.auto-scaling.CreateLaunchConfiguration
# 2025-11-04 15:00:21 - botocore.hooks - DEBUG - Changing event name from before-parameter-build.route53 to before-parameter-build.route-53
# 2025-11-04 15:00:21 - botocore.hooks - DEBUG - Changing event name from request-created.cloudsearchdomain.Search to request-created.cloudsearch-domain.Search
# 2025-11-04 15:00:21 - botocore.hooks - DEBUG - Changing event name from docs.*.autoscaling.CreateLaunchConfiguration.complete-section to docs.*.auto-scaling.CreateLaunchConfiguration.complete-section
# 2025-11-04 15:00:21 - botocore.hooks - DEBUG - Changing event name from before-parameter-build.logs.CreateExportTask to before-parameter-build.cloudwatch-logs.CreateExportTask
# 2025-11-04 15:00:21 - botocore.hooks - DEBUG - Changing event name from docs.*.logs.CreateExportTask.complete-section to docs.*.cloudwatch-logs.CreateExportTask.complete-section
# 2025-11-04 15:00:21 - botocore.hooks - DEBUG - Changing event name from before-parameter-build.cloudsearchdomain.Search to before-parameter-build.cloudsearch-domain.Search
# 2025-11-04 15:00:21 - botocore.hooks - DEBUG - Changing event name from docs.*.cloudsearchdomain.Search.complete-section to docs.*.cloudsearch-domain.Search.complete-section
# 2025-11-04 15:00:21 - s3fs - DEBUG - RC: caching enabled? False (explicit option is False)
# 2025-11-04 15:00:21 - filelock - DEBUG - Attempting to acquire lock 128109017522272 on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock
# 2025-11-04 15:00:21 - filelock - DEBUG - Attempting to acquire lock 128109017529616 on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock
# 2025-11-04 15:00:21 - filelock - DEBUG - Attempting to acquire lock 128109017529856 on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock
# 2025-11-04 15:00:21 - filelock - DEBUG - Attempting to acquire lock 128109017523904 on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock
# 2025-11-04 15:00:21 - botocore.loaders - DEBUG - Loading JSON file: /work/.venv/lib/python3.12/site-packages/botocore/data/endpoints.json
# 2025-11-04 15:00:21 - filelock - DEBUG - Lock 128109017522272 not acquired on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock, waiting 0.05 seconds ...
# 2025-11-04 15:00:21 - filelock - DEBUG - Attempting to acquire lock 128109017520256 on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock
# 2025-11-04 15:00:21 - filelock - DEBUG - Lock 128109017529616 not acquired on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock, waiting 0.05 seconds ...
# 2025-11-04 15:00:21 - filelock - DEBUG - Lock 128109017529856 not acquired on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock, waiting 0.05 seconds ...
# 2025-11-04 15:00:21 - filelock - DEBUG - Lock 128109017523904 not acquired on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock, waiting 0.05 seconds ...
# 2025-11-04 15:00:21 - filelock - DEBUG - Lock 128109017520256 not acquired on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock, waiting 0.05 seconds ...
# 2025-11-04 15:00:21 - filelock - DEBUG - Attempting to acquire lock 128109017517616 on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock
# 2025-11-04 15:00:21 - filelock - DEBUG - Lock 128109017517616 not acquired on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock, waiting 0.05 seconds ...
# 2025-11-04 15:00:21 - botocore.loaders - DEBUG - Loading JSON file: /work/.venv/lib/python3.12/site-packages/botocore/data/sdk-default-configuration.json
# 2025-11-04 15:00:21 - botocore.hooks - DEBUG - Event choose-service-name: calling handler <function handle_service_name_alias at 0x7483bc2e3060>
# 2025-11-04 15:00:21 - botocore.loaders - DEBUG - Loading JSON file: /work/.venv/lib/python3.12/site-packages/botocore/data/s3/2006-03-01/service-2.json.gz
# 2025-11-04 15:00:21 - botocore.loaders - DEBUG - Loading JSON file: /work/.venv/lib/python3.12/site-packages/botocore/data/s3/2006-03-01/service-2.sdk-extras.json
# 2025-11-04 15:00:21 - filelock - DEBUG - Attempting to acquire lock 128109017516512 on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock
# 2025-11-04 15:00:21 - filelock - DEBUG - Lock 128109017516512 not acquired on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock, waiting 0.05 seconds ...
# 2025-11-04 15:00:21 - botocore.loaders - DEBUG - Loading JSON file: /work/.venv/lib/python3.12/site-packages/botocore/data/s3/2006-03-01/endpoint-rule-set-1.json.gz
# 2025-11-04 15:00:21 - filelock - DEBUG - Attempting to acquire lock 128109017522272 on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock
# 2025-11-04 15:00:21 - filelock - DEBUG - Attempting to acquire lock 128109017529616 on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock
# 2025-11-04 15:00:21 - filelock - DEBUG - Attempting to acquire lock 128109017529856 on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock
# 2025-11-04 15:00:21 - filelock - DEBUG - Attempting to acquire lock 128109017523904 on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock
# 2025-11-04 15:00:21 - filelock - DEBUG - Lock 128109017522272 not acquired on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock, waiting 0.05 seconds ...
# 2025-11-04 15:00:21 - filelock - DEBUG - Attempting to acquire lock 128109017520256 on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock
# 2025-11-04 15:00:21 - filelock - DEBUG - Lock 128109017529616 not acquired on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock, waiting 0.05 seconds ...
# 2025-11-04 15:00:21 - filelock - DEBUG - Lock 128109017529856 not acquired on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock, waiting 0.05 seconds ...
# 2025-11-04 15:00:21 - botocore.loaders - DEBUG - Loading JSON file: /work/.venv/lib/python3.12/site-packages/botocore/data/partitions.json
# 2025-11-04 15:00:21 - filelock - DEBUG - Lock 128109017523904 not acquired on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock, waiting 0.05 seconds ...
# 2025-11-04 15:00:21 - filelock - DEBUG - Lock 128109017520256 not acquired on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock, waiting 0.05 seconds ...
# 2025-11-04 15:00:21 - botocore.hooks - DEBUG - Event creating-client-class.s3: calling handler <function add_generate_presigned_post at 0x748902990ea0>
# 2025-11-04 15:00:21 - botocore.hooks - DEBUG - Event creating-client-class.s3: calling handler <function add_generate_presigned_url at 0x748902990c20>
# 2025-11-04 15:00:21 - botocore.configprovider - DEBUG - Looking for endpoint for s3 via: environment_service
# 2025-11-04 15:00:21 - filelock - DEBUG - Attempting to acquire lock 128109017517616 on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock
# 2025-11-04 15:00:21 - botocore.configprovider - DEBUG - Looking for endpoint for s3 via: environment_global
# 2025-11-04 15:00:21 - filelock - DEBUG - Lock 128109017517616 not acquired on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock, waiting 0.05 seconds ...
# 2025-11-04 15:00:21 - botocore.configprovider - DEBUG - Looking for endpoint for s3 via: config_service
# 2025-11-04 15:00:21 - botocore.configprovider - DEBUG - Looking for endpoint for s3 via: config_global
# 2025-11-04 15:00:21 - botocore.configprovider - DEBUG - No configured endpoint found.
# 2025-11-04 15:00:21 - botocore.endpoint - DEBUG - Setting s3 timeout as (5, 15)
# 2025-11-04 15:00:21 - botocore.loaders - DEBUG - Loading JSON file: /work/.venv/lib/python3.12/site-packages/botocore/data/_retry.json
# 2025-11-04 15:00:21 - botocore.client - DEBUG - Registering retry handlers for service: s3
# 2025-11-04 15:00:21 - botocore.utils - DEBUG - Registering S3 region redirector handler
# 2025-11-04 15:00:21 - botocore.utils - DEBUG - Registering S3Express Identity Resolver
# 2025-11-04 15:00:21 - s3fs - DEBUG - CALL: get_object - () - {'Bucket': 'czi-variantformer', 'Key': 'model/common/reference_genomes/cres_seqs_manifest.parquet'}
# 2025-11-04 15:00:21 - botocore.hooks - DEBUG - Event before-parameter-build.s3.GetObject: calling handler <function sse_md5 at 0x7483bc2b2020>
# 2025-11-04 15:00:21 - botocore.hooks - DEBUG - Event before-parameter-build.s3.GetObject: calling handler <function validate_bucket_name at 0x7483bc2b1f80>
# 2025-11-04 15:00:21 - botocore.hooks - DEBUG - Event before-parameter-build.s3.GetObject: calling handler <function remove_bucket_from_url_paths_from_model at 0x7483bc2802c0>
# 2025-11-04 15:00:21 - botocore.hooks - DEBUG - Event before-parameter-build.s3.GetObject: calling handler <bound method S3RegionRedirectorv2.annotate_request_context of <aiobotocore.utils.AioS3RegionRedirectorv2 object at 0x7483c6734560>>
# 2025-11-04 15:00:21 - botocore.hooks - DEBUG - Event before-parameter-build.s3.GetObject: calling handler <bound method ClientCreator._inject_s3_input_parameters of <aiobotocore.client.AioClientCreator object at 0x7483c49a6ea0>>
# 2025-11-04 15:00:21 - botocore.hooks - DEBUG - Event before-parameter-build.s3.GetObject: calling handler <function generate_idempotent_uuid at 0x7483bc2b1da0>
# 2025-11-04 15:00:21 - botocore.hooks - DEBUG - Event before-parameter-build.s3.GetObject: calling handler <function _handle_request_validation_mode_member at 0x7483bc2809a0>
# 2025-11-04 15:00:21 - botocore.hooks - DEBUG - Event before-endpoint-resolution.s3: calling handler <function customize_endpoint_resolver_builtins at 0x7483bc2804a0>
# 2025-11-04 15:00:21 - botocore.hooks - DEBUG - Event before-endpoint-resolution.s3: calling handler <bound method S3RegionRedirectorv2.redirect_from_cache of <aiobotocore.utils.AioS3RegionRedirectorv2 object at 0x7483c6734560>>
# 2025-11-04 15:00:21 - aiobotocore.regions - DEBUG - Calling endpoint provider with parameters: {'Bucket': 'czi-variantformer', 'Region': 'us-east-1', 'UseFIPS': False, 'UseDualStack': False, 'ForcePathStyle': False, 'Accelerate': False, 'UseGlobalEndpoint': True, 'Key': 'model/common/reference_genomes/cres_seqs_manifest.parquet', 'DisableMultiRegionAccessPoints': False, 'UseArnRegion': True}
# 2025-11-04 15:00:21 - aiobotocore.regions - DEBUG - Endpoint provider result: https://czi-variantformer.s3.amazonaws.com
# 2025-11-04 15:00:21 - botocore.regions - DEBUG - Selecting from endpoint provider's list of auth schemes: "sigv4". User selected auth scheme is: "<botocore.UNSIGNED object at 0x7483b47b5d60>"
# 2025-11-04 15:00:21 - botocore.hooks - DEBUG - Event before-call.s3.GetObject: calling handler <function add_expect_header at 0x7483bc2b2340>
# 2025-11-04 15:00:21 - botocore.hooks - DEBUG - Event before-call.s3.GetObject: calling handler <bound method S3ExpressIdentityResolver.apply_signing_cache_key of <aiobotocore.utils.AioS3ExpressIdentityResolver object at 0x7483c4967f20>>
# 2025-11-04 15:00:21 - botocore.hooks - DEBUG - Event before-call.s3.GetObject: calling handler <function add_recursion_detection_header at 0x7483bc2b04a0>
# 2025-11-04 15:00:21 - botocore.hooks - DEBUG - Event before-call.s3.GetObject: calling handler <function inject_api_version_header_if_needed at 0x7483bc2b3880>
# 2025-11-04 15:00:21 - botocore.endpoint - DEBUG - Making request for OperationModel(name=GetObject) with params: {'url_path': '/model/common/reference_genomes/cres_seqs_manifest.parquet', 'query_string': {}, 'method': 'GET', 'headers': {'x-amz-checksum-mode': 'ENABLED', 'User-Agent': 'aiobotocore/2.25.1 md/Botocore#1.40.61 ua/2.1 os/linux#6.5.13-65-650-4141-22041-coreweave-amd64-85c45edc md/arch#x86_64 lang/python#3.12.10 md/pyimpl#CPython m/b,D,Z cfg/retry-mode#legacy botocore/1.40.61'}, 'body': b'', 'auth_path': '/czi-variantformer/model/common/reference_genomes/cres_seqs_manifest.parquet', 'url': 'https://czi-variantformer.s3.amazonaws.com/model/common/reference_genomes/cres_seqs_manifest.parquet', 'context': {'client_region': 'us-east-1', 'client_config': <aiobotocore.config.AioConfig object at 0x7483bc2e8c80>, 'has_streaming_input': False, 'auth_type': 'none', 'unsigned_payload': None, 'auth_options': ['aws.auth#sigv4'], 's3_redirect': {'redirected': False, 'bucket': 'czi-variantformer', 'params': {'Bucket': 'czi-variantformer', 'Key': 'model/common/reference_genomes/cres_seqs_manifest.parquet', 'ChecksumMode': 'ENABLED'}}, 'input_params': {'Bucket': 'czi-variantformer', 'Key': 'model/common/reference_genomes/cres_seqs_manifest.parquet'}, 'signing': {}, 'endpoint_properties': {'authSchemes': [{'disableDoubleEncoding': True, 'name': 'sigv4', 'signingName': 's3', 'signingRegion': 'us-east-1'}]}, 'checksum': {'response_algorithms': ['crc32', 'sha1', 'sha256']}}}
# 2025-11-04 15:00:21 - botocore.hooks - DEBUG - Event request-created.s3.GetObject: calling handler <bound method AioRequestSigner.handler of <aiobotocore.signers.AioRequestSigner object at 0x7483b479cce0>>
# 2025-11-04 15:00:21 - botocore.hooks - DEBUG - Event choose-signer.s3.GetObject: calling handler <function set_operation_specific_signer at 0x7483bc2b1b20>
# 2025-11-04 15:00:21 - botocore.hooks - DEBUG - Event before-sign.s3.GetObject: calling handler <function remove_arn_from_signing_path at 0x7483bc280400>
# 2025-11-04 15:00:21 - botocore.hooks - DEBUG - Event before-sign.s3.GetObject: calling handler <function _set_extra_headers_for_unsigned_request at 0x7483bc280a40>
# 2025-11-04 15:00:21 - botocore.hooks - DEBUG - Event before-sign.s3.GetObject: calling handler <bound method S3ExpressIdentityResolver.resolve_s3express_identity of <aiobotocore.utils.AioS3ExpressIdentityResolver object at 0x7483c4967f20>>
# 2025-11-04 15:00:21 - botocore.hooks - DEBUG - Event request-created.s3.GetObject: calling handler <bound method UserAgentString.rebuild_and_replace_user_agent_handler of <botocore.useragent.UserAgentString object at 0x748901ec2fc0>>
# 2025-11-04 15:00:21 - botocore.hooks - DEBUG - Event request-created.s3.GetObject: calling handler <function add_retry_headers at 0x7483bc280220>
# 2025-11-04 15:00:21 - botocore.endpoint - DEBUG - Sending http request: <AWSPreparedRequest stream_output=True, method=GET, url=https://czi-variantformer.s3.amazonaws.com/model/common/reference_genomes/cres_seqs_manifest.parquet, headers={'x-amz-checksum-mode': b'ENABLED', 'User-Agent': b'aiobotocore/2.25.1 md/Botocore#1.40.61 ua/2.1 os/linux#6.5.13-65-650-4141-22041-coreweave-amd64-85c45edc md/arch#x86_64 lang/python#3.12.10 md/pyimpl#CPython m/b,D,Z cfg/retry-mode#legacy botocore/1.40.61', 'amz-sdk-invocation-id': b'f2093f11-8824-451c-a126-d0290943ec40', 'amz-sdk-request': b'attempt=1'}>
# 2025-11-04 15:00:21 - botocore.httpsession - DEBUG - Certificate path: /work/.venv/lib/python3.12/site-packages/certifi/cacert.pem
# 2025-11-04 15:00:21 - filelock - DEBUG - Attempting to acquire lock 128109017516512 on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock
# 2025-11-04 15:00:21 - filelock - DEBUG - Lock 128109017516512 not acquired on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock, waiting 0.05 seconds ...
# 2025-11-04 15:00:21 - filelock - DEBUG - Attempting to acquire lock 128109017522272 on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock
# 2025-11-04 15:00:21 - filelock - DEBUG - Attempting to acquire lock 128109017529616 on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock
# 2025-11-04 15:00:21 - filelock - DEBUG - Attempting to acquire lock 128109017529856 on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock
# 2025-11-04 15:00:21 - filelock - DEBUG - Attempting to acquire lock 128109017523904 on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock
# 2025-11-04 15:00:21 - filelock - DEBUG - Lock 128109017522272 not acquired on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock, waiting 0.05 seconds ...
# 2025-11-04 15:00:21 - filelock - DEBUG - Attempting to acquire lock 128109017520256 on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock
# 2025-11-04 15:00:21 - filelock - DEBUG - Lock 128109017529616 not acquired on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock, waiting 0.05 seconds ...
# 2025-11-04 15:00:21 - filelock - DEBUG - Lock 128109017529856 not acquired on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock, waiting 0.05 seconds ...
# 2025-11-04 15:00:21 - filelock - DEBUG - Lock 128109017523904 not acquired on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock, waiting 0.05 seconds ...
# 2025-11-04 15:00:21 - filelock - DEBUG - Lock 128109017520256 not acquired on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock, waiting 0.05 seconds ...
# 2025-11-04 15:00:21 - filelock - DEBUG - Attempting to acquire lock 128109017517616 on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock
# 2025-11-04 15:00:21 - filelock - DEBUG - Lock 128109017517616 not acquired on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock, waiting 0.05 seconds ...
# 2025-11-04 15:00:21 - filelock - DEBUG - Attempting to acquire lock 128109017516512 on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock
# 2025-11-04 15:00:21 - filelock - DEBUG - Lock 128109017516512 not acquired on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock, waiting 0.05 seconds ...
# 2025-11-04 15:00:21 - filelock - DEBUG - Attempting to acquire lock 128109017529616 on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock
# 2025-11-04 15:00:21 - filelock - DEBUG - Attempting to acquire lock 128109017522272 on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock
# 2025-11-04 15:00:21 - filelock - DEBUG - Attempting to acquire lock 128109017529856 on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock
# 2025-11-04 15:00:21 - filelock - DEBUG - Attempting to acquire lock 128109017523904 on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock
# 2025-11-04 15:00:21 - filelock - DEBUG - Attempting to acquire lock 128109017520256 on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock
# 2025-11-04 15:00:21 - filelock - DEBUG - Lock 128109017529616 not acquired on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock, waiting 0.05 seconds ...
# 2025-11-04 15:00:21 - filelock - DEBUG - Lock 128109017522272 not acquired on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock, waiting 0.05 seconds ...
# 2025-11-04 15:00:21 - filelock - DEBUG - Lock 128109017529856 not acquired on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock, waiting 0.05 seconds ...
# 2025-11-04 15:00:21 - filelock - DEBUG - Lock 128109017523904 not acquired on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock, waiting 0.05 seconds ...
# 2025-11-04 15:00:21 - filelock - DEBUG - Lock 128109017520256 not acquired on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock, waiting 0.05 seconds ...
# 2025-11-04 15:00:21 - filelock - DEBUG - Attempting to acquire lock 128109017517616 on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock
# 2025-11-04 15:00:21 - filelock - DEBUG - Lock 128109017517616 not acquired on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock, waiting 0.05 seconds ...
# 2025-11-04 15:00:21 - filelock - DEBUG - Attempting to acquire lock 128109017516512 on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock
# 2025-11-04 15:00:21 - filelock - DEBUG - Lock 128109017516512 not acquired on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock, waiting 0.05 seconds ...
# 2025-11-04 15:00:21 - filelock - DEBUG - Attempting to acquire lock 128109017529616 on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock
# 2025-11-04 15:00:21 - filelock - DEBUG - Attempting to acquire lock 128109017522272 on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock
# 2025-11-04 15:00:21 - filelock - DEBUG - Attempting to acquire lock 128109017529856 on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock
# 2025-11-04 15:00:21 - filelock - DEBUG - Lock 128109017529616 not acquired on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock, waiting 0.05 seconds ...
# 2025-11-04 15:00:21 - filelock - DEBUG - Attempting to acquire lock 128109017523904 on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock
# 2025-11-04 15:00:21 - filelock - DEBUG - Attempting to acquire lock 128109017520256 on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock
# 2025-11-04 15:00:21 - filelock - DEBUG - Lock 128109017522272 not acquired on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock, waiting 0.05 seconds ...
# 2025-11-04 15:00:21 - filelock - DEBUG - Lock 128109017529856 not acquired on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock, waiting 0.05 seconds ...
# 2025-11-04 15:00:21 - filelock - DEBUG - Lock 128109017520256 not acquired on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock, waiting 0.05 seconds ...
# 2025-11-04 15:00:21 - filelock - DEBUG - Lock 128109017523904 not acquired on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock, waiting 0.05 seconds ...
# 2025-11-04 15:00:21 - filelock - DEBUG - Attempting to acquire lock 128109017517616 on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock
# 2025-11-04 15:00:21 - filelock - DEBUG - Lock 128109017517616 not acquired on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock, waiting 0.05 seconds ...
# 2025-11-04 15:00:21 - filelock - DEBUG - Attempting to acquire lock 128109017516512 on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock
# 2025-11-04 15:00:21 - filelock - DEBUG - Lock 128109017516512 not acquired on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock, waiting 0.05 seconds ...
# 2025-11-04 15:00:21 - filelock - DEBUG - Attempting to acquire lock 128109017529616 on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock
# 2025-11-04 15:00:21 - filelock - DEBUG - Lock 128109017529616 not acquired on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock, waiting 0.05 seconds ...
# 2025-11-04 15:00:21 - filelock - DEBUG - Attempting to acquire lock 128109017529856 on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock
# 2025-11-04 15:00:21 - filelock - DEBUG - Attempting to acquire lock 128109017522272 on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock
# 2025-11-04 15:00:21 - filelock - DEBUG - Attempting to acquire lock 128109017520256 on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock
# 2025-11-04 15:00:21 - filelock - DEBUG - Attempting to acquire lock 128109017523904 on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock
# 2025-11-04 15:00:21 - filelock - DEBUG - Lock 128109017529856 not acquired on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock, waiting 0.05 seconds ...
# 2025-11-04 15:00:21 - filelock - DEBUG - Lock 128109017522272 not acquired on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock, waiting 0.05 seconds ...
# 2025-11-04 15:00:21 - filelock - DEBUG - Lock 128109017520256 not acquired on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock, waiting 0.05 seconds ...
# 2025-11-04 15:00:21 - filelock - DEBUG - Lock 128109017523904 not acquired on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock, waiting 0.05 seconds ...
# 2025-11-04 15:00:21 - filelock - DEBUG - Attempting to acquire lock 128109017517616 on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock
# 2025-11-04 15:00:21 - filelock - DEBUG - Lock 128109017517616 not acquired on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock, waiting 0.05 seconds ...
# 2025-11-04 15:00:21 - filelock - DEBUG - Attempting to acquire lock 128109017516512 on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock
# 2025-11-04 15:00:21 - filelock - DEBUG - Lock 128109017516512 not acquired on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock, waiting 0.05 seconds ...
# 2025-11-04 15:00:21 - filelock - DEBUG - Attempting to acquire lock 128109017529616 on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock
# 2025-11-04 15:00:21 - filelock - DEBUG - Attempting to acquire lock 128109017529856 on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock
# 2025-11-04 15:00:21 - filelock - DEBUG - Lock 128109017529616 not acquired on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock, waiting 0.05 seconds ...
# 2025-11-04 15:00:21 - filelock - DEBUG - Lock 128109017529856 not acquired on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock, waiting 0.05 seconds ...
# 2025-11-04 15:00:21 - filelock - DEBUG - Attempting to acquire lock 128109017522272 on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock
# 2025-11-04 15:00:21 - filelock - DEBUG - Attempting to acquire lock 128109017523904 on /work/_artifacts/model/common/reference_genomes/cres_seqs_manifest.parquet.lock
# ...
# 2025-11-04 15:00:32 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/cres_all_genes/ENSG00000095485.16/gene_vocab.csv
# 2025-11-04 15:00:33 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/reference_genomes/data_split/hg38/cres/data_split/hg38_chr10.pkl.gz
# 2025-11-04 15:00:33 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/cres_all_genes/ENSG00000095485.16/gene_vocab.csv
# 2025-11-04 15:00:33 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/reference_genomes/data_split/hg38/cres/data_split/hg38_chr10.pkl.gz
# 2025-11-04 15:00:33 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/cres_all_genes/ENSG00000095485.16/gene_vocab.csv
# 2025-11-04 15:00:33 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/reference_genomes/data_split/eas/cres/data_split/HG00404_chr10.pkl.gz
# 2025-11-04 15:00:33 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/cres_all_genes/ENSG00000095485.16/gene_vocab.csv
# 2025-11-04 15:00:33 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/reference_genomes/data_split/eas/cres/data_split/HG00404_chr10.pkl.gz
# 2025-11-04 15:00:33 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/cres_all_genes/ENSG00000095485.16/gene_vocab.csv
# 2025-11-04 15:00:34 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/reference_genomes/data/sas/genes/data/ENSG00000095485.16_HG01589.npz
# 2025-11-04 15:00:34 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/reference_genomes/data/eur/genes/data/ENSG00000095485.16_HG00096.npz
# 2025-11-04 15:00:34 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/reference_genomes/data/amr/genes/data/ENSG00000095485.16_HG00551.npz
# 2025-11-04 15:00:34 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/reference_genomes/data/afr/genes/data/ENSG00000095485.16_HG01879.npz
# 2025-11-04 15:00:34 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/reference_genomes/data/hg38/genes/data/ENSG00000095485.16_hg38.npz
# 2025-11-04 15:00:34 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/reference_genomes/data/hg38/genes/data/ENSG00000095485.16_hg38.npz
# 2025-11-04 15:00:34 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/reference_genomes/data/eas/genes/data/ENSG00000095485.16_HG00404.npz
# 2025-11-04 15:00:34 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/reference_genomes/data/eas/genes/data/ENSG00000095485.16_HG00404.npz
# 2025-11-04 15:00:34 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/reference_genomes/data_split/hg38/cres/data_split/hg38_chr10.pkl.gz
# 2025-11-04 15:00:34 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/cres_all_genes/ENSG00000095485.16/gene_vocab.csv
# 2025-11-04 15:00:34 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/reference_genomes/data_split/sas/cres/data_split/HG01589_chr10.pkl.gz
# 2025-11-04 15:00:34 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/cres_all_genes/ENSG00000095485.16/gene_vocab.csv
# 2025-11-04 15:00:35 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/reference_genomes/data_split/eas/cres/data_split/HG00404_chr10.pkl.gz
# 2025-11-04 15:00:35 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/cres_all_genes/ENSG00000095485.16/gene_vocab.csv
# 2025-11-04 15:00:35 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/reference_genomes/data_split/amr/cres/data_split/HG00551_chr10.pkl.gz
# 2025-11-04 15:00:35 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/cres_all_genes/ENSG00000095485.16/gene_vocab.csv
# 2025-11-04 15:00:35 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/reference_genomes/data_split/eur/cres/data_split/HG00096_chr10.pkl.gz
# 2025-11-04 15:00:35 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/cres_all_genes/ENSG00000095485.16/gene_vocab.csv
# 2025-11-04 15:00:35 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/reference_genomes/data_split/eur/cres/data_split/HG00096_chr10.pkl.gz
# 2025-11-04 15:00:35 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/cres_all_genes/ENSG00000095485.16/gene_vocab.csv
# 2025-11-04 15:00:35 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/reference_genomes/data_split/afr/cres/data_split/HG01879_chr10.pkl.gz
# 2025-11-04 15:00:35 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/cres_all_genes/ENSG00000095485.16/gene_vocab.csv
# 2025-11-04 15:00:35 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/reference_genomes/data_split/afr/cres/data_split/HG01879_chr10.pkl.gz
# 2025-11-04 15:00:35 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/cres_all_genes/ENSG00000095485.16/gene_vocab.csv
# 2025-11-04 15:00:36 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/reference_genomes/data/hg38/genes/data/ENSG00000095485.16_hg38.npz
# 2025-11-04 15:00:36 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/reference_genomes/data/sas/genes/data/ENSG00000095485.16_HG01589.npz
# 2025-11-04 15:00:36 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/reference_genomes/data/eas/genes/data/ENSG00000095485.16_HG00404.npz
# 2025-11-04 15:00:36 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/reference_genomes/data/amr/genes/data/ENSG00000095485.16_HG00551.npz
# 2025-11-04 15:00:36 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/reference_genomes/data/eur/genes/data/ENSG00000095485.16_HG00096.npz
# 2025-11-04 15:00:36 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/reference_genomes/data/eur/genes/data/ENSG00000095485.16_HG00096.npz
# 2025-11-04 15:00:36 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/reference_genomes/data/afr/genes/data/ENSG00000095485.16_HG01879.npz
# 2025-11-04 15:00:36 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/reference_genomes/data_split/eur/cres/data_split/HG00096_chr10.pkl.gz
# 2025-11-04 15:00:36 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/cres_all_genes/ENSG00000095485.16/gene_vocab.csv
# 2025-11-04 15:00:36 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/reference_genomes/data/afr/genes/data/ENSG00000095485.16_HG01879.npz
# 2025-11-04 15:00:36 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/reference_genomes/data_split/hg38/cres/data_split/hg38_chr10.pkl.gz
# 2025-11-04 15:00:36 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/cres_all_genes/ENSG00000095485.16/gene_vocab.csv
# 2025-11-04 15:00:36 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/reference_genomes/data_split/afr/cres/data_split/HG01879_chr10.pkl.gz
# 2025-11-04 15:00:36 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/cres_all_genes/ENSG00000095485.16/gene_vocab.csv
# 2025-11-04 15:00:36 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/reference_genomes/data_split/eas/cres/data_split/HG00404_chr10.pkl.gz
# 2025-11-04 15:00:36 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/cres_all_genes/ENSG00000095485.16/gene_vocab.csv
# 2025-11-04 15:00:37 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/reference_genomes/data_split/sas/cres/data_split/HG01589_chr10.pkl.gz
# 2025-11-04 15:00:37 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/cres_all_genes/ENSG00000095485.16/gene_vocab.csv
# 2025-11-04 15:00:37 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/reference_genomes/data_split/sas/cres/data_split/HG01589_chr10.pkl.gz
# 2025-11-04 15:00:37 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/cres_all_genes/ENSG00000095485.16/gene_vocab.csv
# 2025-11-04 15:00:37 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/reference_genomes/data_split/amr/cres/data_split/HG00551_chr10.pkl.gz
# 2025-11-04 15:00:37 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/cres_all_genes/ENSG00000095485.16/gene_vocab.csv
# 2025-11-04 15:00:37 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/reference_genomes/data_split/amr/cres/data_split/HG00551_chr10.pkl.gz
# 2025-11-04 15:00:37 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/cres_all_genes/ENSG00000095485.16/gene_vocab.csv
# 2025-11-04 15:00:38 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/reference_genomes/data/hg38/genes/data/ENSG00000095485.16_hg38.npz
# 2025-11-04 15:00:38 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/reference_genomes/data/eur/genes/data/ENSG00000095485.16_HG00096.npz
# 2025-11-04 15:00:38 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/reference_genomes/data/afr/genes/data/ENSG00000095485.16_HG01879.npz
# 2025-11-04 15:00:38 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/reference_genomes/data/eas/genes/data/ENSG00000095485.16_HG00404.npz
# 2025-11-04 15:00:38 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/reference_genomes/data/sas/genes/data/ENSG00000095485.16_HG01589.npz
# 2025-11-04 15:00:38 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/reference_genomes/data/sas/genes/data/ENSG00000095485.16_HG01589.npz
# 2025-11-04 15:00:38 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/reference_genomes/data/amr/genes/data/ENSG00000095485.16_HG00551.npz
# 2025-11-04 15:00:38 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/reference_genomes/data_split/eur/cres/data_split/HG00096_chr10.pkl.gz
# 2025-11-04 15:00:38 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/cres_all_genes/ENSG00000095485.16/gene_vocab.csv
# 2025-11-04 15:00:38 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/reference_genomes/data/amr/genes/data/ENSG00000095485.16_HG00551.npz
# 2025-11-04 15:00:38 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/reference_genomes/data_split/sas/cres/data_split/HG01589_chr10.pkl.gz
# 2025-11-04 15:00:38 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/cres_all_genes/ENSG00000095485.16/gene_vocab.csv
# 2025-11-04 15:00:38 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/reference_genomes/data_split/amr/cres/data_split/HG00551_chr10.pkl.gz
# 2025-11-04 15:00:38 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/cres_all_genes/ENSG00000095485.16/gene_vocab.csv
# 2025-11-04 15:00:39 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/reference_genomes/data_split/afr/cres/data_split/HG01879_chr10.pkl.gz
# 2025-11-04 15:00:39 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/cres_all_genes/ENSG00000095485.16/gene_vocab.csv
# 2025-11-04 15:00:39 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/reference_genomes/data_split/hg38/cres/data_split/hg38_chr10.pkl.gz
# 2025-11-04 15:00:39 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/cres_all_genes/ENSG00000095485.16/gene_vocab.csv
# 2025-11-04 15:00:39 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/reference_genomes/data_split/hg38/cres/data_split/hg38_chr10.pkl.gz
# 2025-11-04 15:00:39 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/cres_all_genes/ENSG00000095485.16/gene_vocab.csv
# 2025-11-04 15:00:39 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/reference_genomes/data_split/eas/cres/data_split/HG00404_chr10.pkl.gz
# 2025-11-04 15:00:39 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/cres_all_genes/ENSG00000095485.16/gene_vocab.csv
# 2025-11-04 15:00:39 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/reference_genomes/data_split/eas/cres/data_split/HG00404_chr10.pkl.gz
# 2025-11-04 15:00:39 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/cres_all_genes/ENSG00000095485.16/gene_vocab.csv
# 2025-11-04 15:00:40 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/reference_genomes/data/eur/genes/data/ENSG00000095485.16_HG00096.npz
# 2025-11-04 15:00:40 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/reference_genomes/data/sas/genes/data/ENSG00000095485.16_HG01589.npz
# 2025-11-04 15:00:40 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/reference_genomes/data/amr/genes/data/ENSG00000095485.16_HG00551.npz
# 2025-11-04 15:00:40 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/reference_genomes/data/afr/genes/data/ENSG00000095485.16_HG01879.npz
# 2025-11-04 15:00:40 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/reference_genomes/data/hg38/genes/data/ENSG00000095485.16_hg38.npz
# 2025-11-04 15:00:41 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/reference_genomes/data/eas/genes/data/ENSG00000095485.16_HG00404.npz
# 2025-11-04 15:00:41 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/reference_genomes/data_split/sas/cres/data_split/HG01589_chr10.pkl.gz
# 2025-11-04 15:00:41 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/cres_all_genes/ENSG00000095485.16/gene_vocab.csv
# 2025-11-04 15:00:41 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/reference_genomes/data/hg38/genes/data/ENSG00000095485.16_hg38.npz
# 2025-11-04 15:00:41 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/reference_genomes/data/eas/genes/data/ENSG00000095485.16_HG00404.npz
# 2025-11-04 15:00:41 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/reference_genomes/data_split/amr/cres/data_split/HG00551_chr10.pkl.gz
# 2025-11-04 15:00:41 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/cres_all_genes/ENSG00000095485.16/gene_vocab.csv
# 2025-11-04 15:00:41 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/reference_genomes/data_split/eur/cres/data_split/HG00096_chr10.pkl.gz
# 2025-11-04 15:00:41 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/cres_all_genes/ENSG00000095485.16/gene_vocab.csv
# 2025-11-04 15:00:41 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/reference_genomes/data_split/afr/cres/data_split/HG01879_chr10.pkl.gz
# 2025-11-04 15:00:41 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/cres_all_genes/ENSG00000095485.16/gene_vocab.csv
# 2025-11-04 15:00:42 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/reference_genomes/data/sas/genes/data/ENSG00000095485.16_HG01589.npz
# 2025-11-04 15:00:42 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/reference_genomes/data/amr/genes/data/ENSG00000095485.16_HG00551.npz
# 2025-11-04 15:00:43 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/reference_genomes/data/eur/genes/data/ENSG00000095485.16_HG00096.npz
# 2025-11-04 15:00:43 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/reference_genomes/data/afr/genes/data/ENSG00000095485.16_HG01879.npz
# 2025-11-04 15:00:58 - processors.variantprocessor - INFO - Predictions saved to /tmp/vep_eqtl_output/vep_VF.parquet
# 2025-11-04 15:00:58 - processors.variantprocessor - INFO - Cleanup complete
# Formatting VariantFormer scores and computing eQTL statistics...
# Computing eQTL statistics...

# %%
final_results.head()
# Out:
#             variant_id               genes                 tissues ref alt  \
# 0  chr10_100236603_C_T  ENSG00000095485.16  adipose - subcutaneous   C   T
# 1  chr10_100236603_C_T  ENSG00000095485.16             whole blood   C   T
# 2  chr10_100238657_T_C  ENSG00000095485.16  adipose - subcutaneous   T   C
# 3  chr10_100238657_T_C  ENSG00000095485.16             whole blood   T   C
# 4  chr10_100239989_G_A  ENSG00000095485.16  adipose - subcutaneous   G   A
#
#      chr        pos  VF-agg-log2fc-weighted  VF-AFR-2-exp-log2fc  \
# 0  chr10  100236603                0.009466             0.000000
# 1  chr10  100236603                0.017387             0.060486
# 2  chr10  100238657                0.009475             0.000000
# 3  chr10  100238657                0.017376             0.060486
# 4  chr10  100239989                0.009435             0.000000
#
#    VF-AMR-2-exp-log2fc  VF-EAS-2-exp-log2fc  VF-EUR-2-exp-log2fc  \
# 0             0.027943             0.000000             0.000000
# 1             0.006830             0.020407             0.020407
# 2             0.027943             0.000000             0.000000
# 3             0.006830             0.020407             0.020407
# 4             0.027943             0.000000             0.000000
#
#    VF-REF_HG38-2-exp-log2fc  VF-SAS-2-exp-log2fc
# 0                  0.007029             0.007029
# 1                  0.000000             0.020407
# 2                  0.007029             0.007029
# 3                  0.006830             0.020407
# 4                  0.000000             0.007029

# %% [markdown]
# ## Launch predictions using Alphagenome

# %% [markdown]
# ### Load data

# %%
variants = pd.read_parquet(os.path.join(REPO_PATH, '_artifacts/b23c9b69.pq'))

# %%
# tiisue map to align tissue names between VF and Eqtl catalog data
alphagenome_tissue_map = {'skin' : 'Skin_Sun_Exposed_Lower_leg',
                 'blood' : 'Whole_Blood',
                 'adipose' : 'Adipose_Subcutaneous',
                 'brain - frontal cortex (ba9)': 'Brain_Frontal_Cortex_BA9',
                 'brain - putamen (basal ganglia)': 'Brain_Putamen_basal_ganglia',
                 'brain - substantia nigra' : 'Brain_Substantia_nigra'
                 }
variants['tissue'] = variants['tissue'].map(alphagenome_tissue_map)

# %%
first10_variants = variants.head(10)
first10_variants['CHROM'] = first10_variants['variant_id'].apply(lambda x: x.split('_')[0])
first10_variants['POS'] = first10_variants['variant_id'].apply(lambda x: int(x.split('_')[1]))
first10_variants['REF'] = first10_variants['variant_id'].apply(lambda x: x.split('_')[2])
first10_variants['ALT'] = first10_variants['variant_id'].apply(lambda x: x.split('_')[3])
first10_variants['gene_id'] = first10_variants['gene_id'].apply(lambda x: x.split('.')[0])

# %%
# Install alphagenome
# !uv pip install alphagenome
from io import StringIO
from alphagenome import colab_utils
from alphagenome.data import genome
from alphagenome.models import dna_client, variant_scorers
import numpy as np
# Out:
# Using Python 3.12.10 environment at: /work/.venv
# Resolved 41 packages in 669ms
#    Building intervaltree==3.1.0
# Downloading grpcio (6.3MiB)
# Downloading ml-dtypes (4.7MiB)
# Downloading zstandard (5.3MiB)
#  Downloading ml-dtypes
#  Downloading zstandard
#  Downloading grpcio
#       Built intervaltree==3.1.0
# Prepared 11 packages in 458ms
# Installed 11 packages in 19ms
#  + absl-py==2.3.1
#  + alphagenome==0.4.0
#  + grpcio==1.76.0
#  + immutabledict==4.2.2
#  + intervaltree==3.1.0
#  + jaxtyping==0.3.3
#  + ml-dtypes==0.5.3
#  + sortedcontainers==2.4.0
#  + typeguard==4.4.4
#  + wadler-lindig==0.1.7
#  + zstandard==0.25.0
# 2025-11-04 15:01:08 - h5py._conv - DEBUG - Creating converter from 7 to 5
# 2025-11-04 15:01:08 - h5py._conv - DEBUG - Creating converter from 5 to 7
# 2025-11-04 15:01:08 - h5py._conv - DEBUG - Creating converter from 7 to 5
# 2025-11-04 15:01:08 - h5py._conv - DEBUG - Creating converter from 5 to 7
# 2025-11-04 15:01:08 - numcodecs - DEBUG - Registering codec 'zlib'
# 2025-11-04 15:01:08 - numcodecs - DEBUG - Registering codec 'gzip'
# 2025-11-04 15:01:08 - numcodecs - DEBUG - Registering codec 'bz2'
# 2025-11-04 15:01:08 - numcodecs - DEBUG - Registering codec 'lzma'
# 2025-11-04 15:01:08 - numcodecs - DEBUG - Registering codec 'blosc'
# 2025-11-04 15:01:08 - numcodecs - DEBUG - Registering codec 'zstd'
# 2025-11-04 15:01:08 - numcodecs - DEBUG - Registering codec 'lz4'
# 2025-11-04 15:01:08 - numcodecs - DEBUG - Registering codec 'astype'
# 2025-11-04 15:01:08 - numcodecs - DEBUG - Registering codec 'delta'
# 2025-11-04 15:01:08 - numcodecs - DEBUG - Registering codec 'quantize'
# 2025-11-04 15:01:08 - numcodecs - DEBUG - Registering codec 'fixedscaleoffset'
# 2025-11-04 15:01:08 - numcodecs - DEBUG - Registering codec 'packbits'
# 2025-11-04 15:01:08 - numcodecs - DEBUG - Registering codec 'categorize'
# 2025-11-04 15:01:08 - numcodecs - DEBUG - Registering codec 'pickle'
# 2025-11-04 15:01:08 - numcodecs - DEBUG - Registering codec 'base64'
# 2025-11-04 15:01:08 - numcodecs - DEBUG - Registering codec 'shuffle'
# 2025-11-04 15:01:08 - numcodecs - DEBUG - Registering codec 'bitround'
# 2025-11-04 15:01:08 - numcodecs - DEBUG - Registering codec 'crc32'
# 2025-11-04 15:01:08 - numcodecs - DEBUG - Registering codec 'adler32'
# 2025-11-04 15:01:08 - numcodecs - DEBUG - Registering codec 'jenkins_lookup3'
# 2025-11-04 15:01:08 - numcodecs - DEBUG - Registering codec 'json2'
# 2025-11-04 15:01:08 - numcodecs - DEBUG - Registering codec 'vlen-utf8'
# 2025-11-04 15:01:08 - numcodecs - DEBUG - Registering codec 'vlen-bytes'
# 2025-11-04 15:01:08 - numcodecs - DEBUG - Registering codec 'vlen-array'
# 2025-11-04 15:01:08 - numcodecs - DEBUG - Registering codec 'fletcher32'
# 2025-11-04 15:01:08 - numcodecs - DEBUG - Registering codec 'crc32c'

# %%
# Load the model.
API_KEY = "your_api_key_here"
dna_model = dna_client.create(API_KEY)

# %%
# Alphagenome specifications
organism = 'human'
# @markdown Specify length of sequence around variants to predict:
sequence_length = '1MB'
sequence_length = dna_client.SUPPORTED_SEQUENCE_LENGTHS[
    f'SEQUENCE_LENGTH_{sequence_length}'
]
score_rna_seq = True
download_predictions = False
# Parse organism specification.
organism_map = {
    'human': dna_client.Organism.HOMO_SAPIENS,
    'mouse': dna_client.Organism.MUS_MUSCULUS,
}
organism = organism_map[organism]
# Parse scorer specification.
scorer_selections = {
    'rna_seq': score_rna_seq,
}
all_scorers = variant_scorers.RECOMMENDED_VARIANT_SCORERS
selected_scorers = [
    all_scorers[key]
    for key in all_scorers
    if scorer_selections.get(key.lower(), False)
]

# %%
results = []
for i, vcf_row in first10_variants.iterrows():
  variant = genome.Variant(
      chromosome=str(vcf_row.CHROM),
      position=int(vcf_row.POS),
      reference_bases=vcf_row.REF,
      alternate_bases=vcf_row.ALT,
      name=vcf_row.variant_id,
  )
  interval = variant.reference_interval.resize(sequence_length)

  variant_scores = dna_model.score_variant(
      interval=interval,
      variant=variant,
      variant_scorers=selected_scorers,
      organism=organism,
  )
  df_scores = variant_scorers.tidy_scores([variant_scores])
  tissue_key = vcf_row.tissue
  df = df_scores[(df_scores['gene_id'] == vcf_row.gene_id) & (df_scores['gtex_tissue'] == tissue_key)]['raw_score']
  vcf_row['alphagenome_score_new'] = df.values[0].mean() if not df.empty else np.nan
  results.append(vcf_row)

# %%
df = pd.DataFrame(results)

# %% [markdown]
# **The alphagenome score might deviate a little because we believe the underlying model is evolving**

# %% [markdown]
# ## Visualize all the precalculated scores

# %%
variants = pd.read_parquet(os.path.join(REPO_PATH, '_artifacts/b23c9b69.pq'))

# %%
variants.head()
# Out:
#             variant_id             gene_id   tissue     slope        pvalue  \
# 0  chr10_100236603_C_T  ENSG00000095485.16  adipose  0.659835  2.606480e-38
# 1  chr10_100236603_C_T  ENSG00000095485.16    blood  0.476792  8.194630e-18
# 2  chr10_100238657_T_C  ENSG00000095485.16  adipose  0.659753  2.629150e-38
# 3  chr10_100238657_T_C  ENSG00000095485.16    blood  0.476752  8.216580e-18
# 4  chr10_100239989_G_A  ENSG00000095485.16  adipose  0.659729  2.636980e-38
#
#   ref alt       maf  VF-agg-log2fc-weighted_ag  VF-AFR-2-log2fc_ag  ...  \
# 0   C   T  0.429134                   0.009466            0.000000  ...
# 1   C   T  0.410256                   0.017387            0.060486  ...
# 2   T   C  0.429134                   0.009475            0.000000  ...
# 3   T   C  0.410256                   0.017376            0.060486  ...
# 4   G   A  0.429134                   0.009435            0.000000  ...
#
#    VF-SAS-2-log2fc_ag  VF-agg-log2fc-weighted_pcg  VF-AFR-2-log2fc_pcg  \
# 0            0.007029                    0.012622             0.000000
# 1            0.020407                    0.007350             0.033332
# 2            0.007029                    0.013702             0.000000
# 3            0.020407                    0.011797             0.033332
# 4            0.007029                    0.012604             0.000000
#
#    VF-AMR-2-log2fc_pcg  VF-EAS-2-log2fc_pcg  VF-EUR-2-log2fc_pcg  \
# 0             0.041915             0.000000              0.00000
# 1             0.006720             0.020079              0.00000
# 2             0.041915             0.000000              0.00000
# 3             0.006720             0.026719              0.00672
# 4             0.041915             0.000000              0.00000
#
#    VF-SAS-2-log2fc_pcg                         variant_id_gene  Borzoi-log2FC  \
# 0             0.000000  chr10_100236603_C_T_ENSG00000095485.16      -0.000599
# 1             0.020079  chr10_100236603_C_T_ENSG00000095485.16      -0.000461
# 2             0.007058  chr10_100238657_T_C_ENSG00000095485.16       0.000460
# 3             0.026719  chr10_100238657_T_C_ENSG00000095485.16       0.000305
# 4             0.000000  chr10_100239989_G_A_ENSG00000095485.16       0.001238
#
#    alphagenome_score
# 0           0.000815
# 1           0.000996
# 2          -0.000954
# 3          -0.000968
# 4           0.000725
#
# [5 rows x 23 columns]

# %% [markdown]
# ### VF results

# %%
# Tissue specific spoearman correlation plots
vf_spearman = variants.groupby('tissue').apply(
    lambda x: x['slope'].corr(x['VF-agg-log2fc-weighted_ag'], method='spearman')
).reset_index()
vf_spearman.columns = ['tissue', 'spearman_correlation']
vf_spearman
# Out:
#                             tissue  spearman_correlation
# 0                          adipose              0.540437
# 1                            blood              0.453173
# 2     brain - frontal cortex (ba9)              0.625611
# 3  brain - putamen (basal ganglia)              0.607318
# 4         brain - substantia nigra              0.587621
# 5                             skin              0.605895

# %% [markdown]
# ### Alphagenome results

# %%
# Tissue specific spoearman correlation plots
alphagenome_spearman = variants.groupby('tissue').apply(
    lambda x: x['slope'].corr(x['alphagenome_score'], method='spearman')
).reset_index()
alphagenome_spearman.columns = ['tissue', 'spearman_correlation']
alphagenome_spearman
# Out:
#                             tissue  spearman_correlation
# 0                          adipose              0.039658
# 1                            blood              0.035846
# 2     brain - frontal cortex (ba9)              0.044307
# 3  brain - putamen (basal ganglia)              0.016789
# 4         brain - substantia nigra              0.018051
# 5                             skin              0.019730
