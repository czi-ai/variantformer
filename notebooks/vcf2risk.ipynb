# %% [markdown]
# # VCF to Alzheimer's Disease Risk Prediction
#
# This notebook demonstrates how to predict Alzheimer's Disease (AD) risk from genetic variants in VCF files using VariantFormer. The model predicts tissue-specific gene expression changes and estimates AD risk contributions.
#
# ## Overview
#
# - Input: VCF file with genetic variants
# - Output: AD risk scores per gene-tissue pair

# %% [markdown]
# ## 1. Setup and Imports

# %%
import sys
from pathlib import Path
import ipynbname
import os
from processors import ad_risk
# !uv pip install plotly
import plotly.express as px
import ipynbname
REPO_PATH = ipynbname.path().parent.parent
# Out:
# 2025-11-04 15:11:36 - matplotlib - DEBUG - matplotlib data path: /work/.venv/lib/python3.12/site-packages/matplotlib/mpl-data
# 2025-11-04 15:11:36 - matplotlib - DEBUG - CONFIGDIR=/flow/.config/matplotlib
# 2025-11-04 15:11:36 - matplotlib - DEBUG - interactive is False
# 2025-11-04 15:11:36 - matplotlib - DEBUG - platform is linux
# 2025-11-04 15:11:36 - matplotlib - DEBUG - CACHEDIR=/flow/.cache/matplotlib
# 2025-11-04 15:11:36 - matplotlib.font_manager - DEBUG - Using fontManager instance from /flow/.cache/matplotlib/fontlist-v390.json
# Using Python 3.12.10 environment at: /work/.venv
# Resolved 3 packages in 69ms
# Installed 2 packages in 119ms
#  + narwhals==2.10.2
#  + plotly==6.4.0

# %% [markdown]
# ## 2. Load AD Risk Model
#
# Initialize the model with `v4_pcg` (DNA-to-Cell, Protein-Coding Genes) or `v4_ag`. Model artifacts are automatically downloaded from S3 on first run.

# %%
# loading AD risk prediction model
model_class = 'v4_pcg'
# model_class = 'v4_ag' # If you want to use the model trained on all genes.
adrisk = ad_risk.ADriskFromVCF(model_class=model_class)
# Out:
# 2025-11-04 15:11:38 - processors.model_manager - INFO - Loading Seq2Reg model...
# 2025-11-04 15:11:39 - processors.model_manager - INFO - Loading Seq2Reg gene model...
# 2025-11-04 15:11:39 - processors.model_manager - INFO - Creating Seq2Gene model...
# 2025-11-04 15:11:44 - processors.model_manager - INFO - Model class: <class 'seq2gene.model_combined_modulator.Seq2GenePredictorCombinedModulator'>
# 2025-11-04 15:11:44 - processors.model_manager - INFO - Model architecture:
# 2025-11-04 15:11:44 - processors.model_manager - INFO - Model: Seq2GenePredictorCombinedModulator
# 2025-11-04 15:11:44 - processors.model_manager - INFO -   start_tkn: 96,768 params
# 2025-11-04 15:11:44 - processors.model_manager - INFO -   cre_tokenizer: 31,826,153 params
# 2025-11-04 15:11:44 - processors.model_manager - INFO -   gene_tokenizer: 31,826,153 params
# 2025-11-04 15:11:44 - processors.model_manager - INFO -   gene_map: 787,968 params
# 2025-11-04 15:11:44 - processors.model_manager - INFO -   cre_map: 787,968 params
# 2025-11-04 15:11:44 - processors.model_manager - INFO -   combined_modulator: 1,157,298,176 params
# 2025-11-04 15:11:44 - processors.model_manager - INFO -   tissue_heads: 4,726,273 params
# 2025-11-04 15:11:44 - processors.model_manager - INFO -   gene_loss: 0 params
# 2025-11-04 15:11:44 - processors.model_manager - INFO - Total number of parameters: 1,227,349,459
# 2025-11-04 15:11:44 - processors.model_manager - INFO - Loading checkpoint from /work/_artifacts/v4_pcg_epoch11_checkpoint.pth
# 2025-11-04 15:11:50 - processors.model_manager - INFO - Model loaded successfully on cuda
# INFO: Using bfloat16 Automatic Mixed Precision (AMP)
# 2025-11-04 15:11:50 - lightning.pytorch.utilities.rank_zero - INFO - Using bfloat16 Automatic Mixed Precision (AMP)
# INFO: GPU available: True (cuda), used: True
# 2025-11-04 15:11:50 - lightning.pytorch.utilities.rank_zero - INFO - GPU available: True (cuda), used: True
# INFO: TPU available: False, using: 0 TPU cores
# 2025-11-04 15:11:50 - lightning.pytorch.utilities.rank_zero - INFO - TPU available: False, using: 0 TPU cores
# INFO: HPU available: False, using: 0 HPUs
# 2025-11-04 15:11:50 - lightning.pytorch.utilities.rank_zero - INFO - HPU available: False, using: 0 HPUs

# %% [markdown]
# ## 3. Explore Available Genes

# %%
all_genes = adrisk.vcf_processor.get_genes()
print(f'First 5 of {len(all_genes)} genes:')
print(all_genes[:5])
# Out:
# First 5 of 18439 genes:
#   chromosome      start        end strand             gene_id gene_name
# 0      chr20   50934867   50958555      -  ENSG00000000419.12      DPM1
# 1       chr1  169849631  169894267      -  ENSG00000000457.13     SCYL3
# 2       chr1  169662007  169854080      +  ENSG00000000460.16  C1orf112
# 3       chr1   27612064   27635277      -  ENSG00000000938.12       FGR
# 4       chr1  196651878  196747504      +  ENSG00000000971.15       CFH

# %% [markdown]
# ## 4. Explore Available Tissues
#
# The model supports 62 tissue/cell types including brain regions, cell lines, and GTEx tissues. Each has a unique ID for predictions.

# %%
# Tissues vocabulary
tissue_vocab = adrisk.vcf_processor.tissue_vocab
print('Tissues: Ids')
for tissue, idx in tissue_vocab.items():
    print(f'  {tissue}: {idx}')
# Out:
# Tissues: Ids
#   A549: 0
#   GM23248: 2
#   HepG2: 3
#   K562: 4
#   NCI-H460: 5
#   Panc1: 6
#   adipose - subcutaneous: 7
#   adipose - visceral (omentum): 8
#   adrenal gland: 9
#   artery - aorta: 10
#   artery - coronary: 11
#   artery - tibial: 12
#   bladder: 13
#   blood: 14
#   brain - amygdala: 15
#   brain - anterior cingulate cortex (ba24): 16
#   brain - caudate (basal ganglia): 17
#   brain - cerebellar hemisphere: 18
#   brain - cerebellum: 19
#   brain - cortex: 20
#   brain - frontal cortex (ba9): 21
#   brain - hippocampus: 22
#   brain - hypothalamus: 23
#   brain - nucleus accumbens (basal ganglia): 24
#   brain - putamen (basal ganglia): 25
#   brain - spinal cord (cervical c-1): 26
#   brain - substantia nigra: 27
#   breast - mammary tissue: 28
#   cells - cultured fibroblasts: 29
#   cells - ebv-transformed lymphocytes: 30
#   cervix - ectocervix: 31
#   cervix - endocervix: 32
#   colon - sigmoid: 33
#   colon - transverse: 34
#   esophagus - gastroesophageal junction: 35
#   esophagus - mucosa: 36
#   esophagus - muscularis: 37
#   fallopian tube: 38
#   heart - atrial appendage: 39
#   heart - left ventricle: 40
#   kidney - cortex: 41
#   kidney - medulla: 42
#   liver: 43
#   lung: 44
#   lcl: 45
#   minor salivary gland: 46
#   muscle - skeletal: 47
#   nerve - tibial: 48
#   ovary: 49
#   pancreas: 50
#   pituitary: 51
#   prostate: 52
#   skin - not sun exposed (suprapubic): 53
#   skin - sun exposed (lower leg): 54
#   small intestine - terminal ileum: 55
#   spleen: 56
#   stomach: 57
#   testis: 58
#   thyroid: 59
#   uterus: 60
#   vagina: 61
#   whole blood: 62

# %% [markdown]
# ## 5. Configure Parameters
#
# Specify the VCF file, target genes, and tissues for analysis.

# %%
# picking a vcf file
vcf_path = os.path.join(REPO_PATH, "_artifacts/HG00096.vcf.gz")
tissue_vocab = adrisk.vcf_processor.tissue_vocab

# picking a set of genes and their corresponding tissue ids to query

tissue_ids = [tissue_vocab['brain - cortex'], tissue_vocab['brain - hippocampus']]
gene_ids = ["ENSG00000000419.12", "ENSG00000000457.13"]

# %% [markdown]
# ## 6. Make Predictions
#
# Run the prediction pipeline: variant processing → sequence extraction → expression prediction → AD risk calculation.

# %%
# Make predictions
preds = adrisk(vcf_path, gene_ids, tissue_ids)
# Out:
# INFO: Restoring states from the checkpoint path at /work/_artifacts/v4_pcg_epoch11_checkpoint.pth
# 2025-11-04 15:11:53 - lightning.pytorch.utilities.rank_zero - INFO - Restoring states from the checkpoint path at /work/_artifacts/v4_pcg_epoch11_checkpoint.pth
# 2025-11-04 15:11:53 - fsspec.local - DEBUG - open file: /work/_artifacts/v4_pcg_epoch11_checkpoint.pth
# Loaded BPE vocabulary from /work/vocabs/bpe_vocabulary_500.json
# Filtered query df to 2 genes reducing from 2
# /work/.venv/lib/python3.12/site-packages/lightning/pytorch/trainer/call.py:283: Be aware that when using `ckpt_path`, callbacks used to create the checkpoint need to be provided during `Trainer` instantiation. Please add the following callbacks: ["ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}"].
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# 2025-11-04 15:12:00 - lightning.pytorch.accelerators.cuda - INFO - LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO: Loaded model weights from the checkpoint at /work/_artifacts/v4_pcg_epoch11_checkpoint.pth
# 2025-11-04 15:12:00 - lightning.pytorch.utilities.rank_zero - INFO - Loaded model weights from the checkpoint at /work/_artifacts/v4_pcg_epoch11_checkpoint.pth
# Predicting: |          | 0/? [00:00<?, ?it/s]
# 2025-11-04 15:12:01 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/cres_all_genes_manifest.parquet
# 2025-11-04 15:12:01 - utils.assets - INFO - Loading parquet file: /work/_artifacts/model/common/cres_all_genes_manifest.parquet
# 2025-11-04 15:12:01 - utils.assets - INFO - Validated schema - found columns: {'file_path', 'gene_id'}
# 2025-11-04 15:12:01 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/cres_all_genes/ENSG00000000419.12/gene_vocab.csv
# 2025-11-04 15:12:09 - filelock - DEBUG - Attempting to acquire lock 129002770750912 on /work/_artifacts/model/common/cres_all_genes/ENSG00000000457.13/gene_vocab.csv.lock
# 2025-11-04 15:12:09 - filelock - DEBUG - Lock 129002770750912 acquired on /work/_artifacts/model/common/cres_all_genes/ENSG00000000457.13/gene_vocab.csv.lock
# 2025-11-04 15:12:09 - asyncio - DEBUG - Using selector: EpollSelector
# 2025-11-04 15:12:09 - s3fs - DEBUG - Setting up s3fs instance
# 2025-11-04 15:12:09 - botocore.hooks - DEBUG - Changing event name from creating-client-class.iot-data to creating-client-class.iot-data-plane
# 2025-11-04 15:12:09 - botocore.hooks - DEBUG - Changing event name from before-call.apigateway to before-call.api-gateway
# 2025-11-04 15:12:09 - botocore.hooks - DEBUG - Changing event name from request-created.machinelearning.Predict to request-created.machine-learning.Predict
# 2025-11-04 15:12:09 - botocore.hooks - DEBUG - Changing event name from before-parameter-build.autoscaling.CreateLaunchConfiguration to before-parameter-build.auto-scaling.CreateLaunchConfiguration
# 2025-11-04 15:12:09 - botocore.hooks - DEBUG - Changing event name from before-parameter-build.route53 to before-parameter-build.route-53
# 2025-11-04 15:12:09 - botocore.hooks - DEBUG - Changing event name from request-created.cloudsearchdomain.Search to request-created.cloudsearch-domain.Search
# 2025-11-04 15:12:09 - botocore.hooks - DEBUG - Changing event name from docs.*.autoscaling.CreateLaunchConfiguration.complete-section to docs.*.auto-scaling.CreateLaunchConfiguration.complete-section
# 2025-11-04 15:12:09 - botocore.hooks - DEBUG - Changing event name from before-parameter-build.logs.CreateExportTask to before-parameter-build.cloudwatch-logs.CreateExportTask
# 2025-11-04 15:12:09 - botocore.hooks - DEBUG - Changing event name from docs.*.logs.CreateExportTask.complete-section to docs.*.cloudwatch-logs.CreateExportTask.complete-section
# 2025-11-04 15:12:09 - botocore.hooks - DEBUG - Changing event name from before-parameter-build.cloudsearchdomain.Search to before-parameter-build.cloudsearch-domain.Search
# 2025-11-04 15:12:09 - botocore.hooks - DEBUG - Changing event name from docs.*.cloudsearchdomain.Search.complete-section to docs.*.cloudsearch-domain.Search.complete-section
# 2025-11-04 15:12:09 - s3fs - DEBUG - RC: caching enabled? False (explicit option is False)
# 2025-11-04 15:12:09 - botocore.loaders - DEBUG - Loading JSON file: /work/.venv/lib/python3.12/site-packages/botocore/data/endpoints.json
# 2025-11-04 15:12:09 - botocore.loaders - DEBUG - Loading JSON file: /work/.venv/lib/python3.12/site-packages/botocore/data/sdk-default-configuration.json
# 2025-11-04 15:12:09 - botocore.hooks - DEBUG - Event choose-service-name: calling handler <function handle_service_name_alias at 0x754fa80ab100>
# 2025-11-04 15:12:09 - botocore.loaders - DEBUG - Loading JSON file: /work/.venv/lib/python3.12/site-packages/botocore/data/s3/2006-03-01/service-2.json.gz
# 2025-11-04 15:12:09 - botocore.loaders - DEBUG - Loading JSON file: /work/.venv/lib/python3.12/site-packages/botocore/data/s3/2006-03-01/service-2.sdk-extras.json
# 2025-11-04 15:12:09 - botocore.loaders - DEBUG - Loading JSON file: /work/.venv/lib/python3.12/site-packages/botocore/data/s3/2006-03-01/endpoint-rule-set-1.json.gz
# 2025-11-04 15:12:09 - botocore.loaders - DEBUG - Loading JSON file: /work/.venv/lib/python3.12/site-packages/botocore/data/partitions.json
# 2025-11-04 15:12:10 - botocore.hooks - DEBUG - Event creating-client-class.s3: calling handler <function add_generate_presigned_post at 0x75524ae93c40>
# 2025-11-04 15:12:10 - botocore.hooks - DEBUG - Event creating-client-class.s3: calling handler <function add_generate_presigned_url at 0x75524ae939c0>
# 2025-11-04 15:12:10 - botocore.configprovider - DEBUG - Looking for endpoint for s3 via: environment_service
# 2025-11-04 15:12:10 - botocore.configprovider - DEBUG - Looking for endpoint for s3 via: environment_global
# 2025-11-04 15:12:10 - botocore.configprovider - DEBUG - Looking for endpoint for s3 via: config_service
# 2025-11-04 15:12:10 - botocore.configprovider - DEBUG - Looking for endpoint for s3 via: config_global
# 2025-11-04 15:12:10 - botocore.configprovider - DEBUG - No configured endpoint found.
# 2025-11-04 15:12:10 - botocore.endpoint - DEBUG - Setting s3 timeout as (5, 15)
# 2025-11-04 15:12:10 - botocore.loaders - DEBUG - Loading JSON file: /work/.venv/lib/python3.12/site-packages/botocore/data/_retry.json
# 2025-11-04 15:12:10 - botocore.client - DEBUG - Registering retry handlers for service: s3
# 2025-11-04 15:12:10 - botocore.utils - DEBUG - Registering S3 region redirector handler
# 2025-11-04 15:12:10 - botocore.utils - DEBUG - Registering S3Express Identity Resolver
# 2025-11-04 15:12:10 - s3fs - DEBUG - CALL: get_object - () - {'Bucket': 'czi-variantformer', 'Key': 'model/common/cres_all_genes/ENSG00000000457.13/gene_vocab.csv'}
# 2025-11-04 15:12:10 - botocore.hooks - DEBUG - Event before-parameter-build.s3.GetObject: calling handler <function sse_md5 at 0x754fa8146160>
# 2025-11-04 15:12:10 - botocore.hooks - DEBUG - Event before-parameter-build.s3.GetObject: calling handler <function validate_bucket_name at 0x754fa81460c0>
# 2025-11-04 15:12:10 - botocore.hooks - DEBUG - Event before-parameter-build.s3.GetObject: calling handler <function remove_bucket_from_url_paths_from_model at 0x754fa80f8400>
# 2025-11-04 15:12:10 - botocore.hooks - DEBUG - Event before-parameter-build.s3.GetObject: calling handler <bound method S3RegionRedirectorv2.annotate_request_context of <aiobotocore.utils.AioS3RegionRedirectorv2 object at 0x75526a732d20>>
# 2025-11-04 15:12:10 - botocore.hooks - DEBUG - Event before-parameter-build.s3.GetObject: calling handler <bound method ClientCreator._inject_s3_input_parameters of <aiobotocore.client.AioClientCreator object at 0x75526a720e00>>
# 2025-11-04 15:12:10 - botocore.hooks - DEBUG - Event before-parameter-build.s3.GetObject: calling handler <function generate_idempotent_uuid at 0x754fa8145ee0>
# 2025-11-04 15:12:10 - botocore.hooks - DEBUG - Event before-parameter-build.s3.GetObject: calling handler <function _handle_request_validation_mode_member at 0x754fa80f8ae0>
# 2025-11-04 15:12:10 - botocore.hooks - DEBUG - Event before-endpoint-resolution.s3: calling handler <function customize_endpoint_resolver_builtins at 0x754fa80f85e0>
# 2025-11-04 15:12:10 - botocore.hooks - DEBUG - Event before-endpoint-resolution.s3: calling handler <bound method S3RegionRedirectorv2.redirect_from_cache of <aiobotocore.utils.AioS3RegionRedirectorv2 object at 0x75526a732d20>>
# 2025-11-04 15:12:10 - aiobotocore.regions - DEBUG - Calling endpoint provider with parameters: {'Bucket': 'czi-variantformer', 'Region': 'us-east-1', 'UseFIPS': False, 'UseDualStack': False, 'ForcePathStyle': False, 'Accelerate': False, 'UseGlobalEndpoint': True, 'Key': 'model/common/cres_all_genes/ENSG00000000457.13/gene_vocab.csv', 'DisableMultiRegionAccessPoints': False, 'UseArnRegion': True}
# 2025-11-04 15:12:10 - aiobotocore.regions - DEBUG - Endpoint provider result: https://czi-variantformer.s3.amazonaws.com
# 2025-11-04 15:12:10 - botocore.regions - DEBUG - Selecting from endpoint provider's list of auth schemes: "sigv4". User selected auth scheme is: "<botocore.UNSIGNED object at 0x754fa80d6300>"
# 2025-11-04 15:12:10 - botocore.hooks - DEBUG - Event before-call.s3.GetObject: calling handler <function add_expect_header at 0x754fa8146480>
# 2025-11-04 15:12:10 - botocore.hooks - DEBUG - Event before-call.s3.GetObject: calling handler <bound method S3ExpressIdentityResolver.apply_signing_cache_key of <aiobotocore.utils.AioS3ExpressIdentityResolver object at 0x75524a4f5c70>>
# 2025-11-04 15:12:10 - botocore.hooks - DEBUG - Event before-call.s3.GetObject: calling handler <function add_recursion_detection_header at 0x754fa81445e0>
# 2025-11-04 15:12:10 - botocore.hooks - DEBUG - Event before-call.s3.GetObject: calling handler <function inject_api_version_header_if_needed at 0x754fa81479c0>
# 2025-11-04 15:12:10 - botocore.endpoint - DEBUG - Making request for OperationModel(name=GetObject) with params: {'url_path': '/model/common/cres_all_genes/ENSG00000000457.13/gene_vocab.csv', 'query_string': {}, 'method': 'GET', 'headers': {'x-amz-checksum-mode': 'ENABLED', 'User-Agent': 'aiobotocore/2.25.1 md/Botocore#1.40.61 ua/2.1 os/linux#6.5.13-65-650-4141-22041-coreweave-amd64-85c45edc md/arch#x86_64 lang/python#3.12.10 md/pyimpl#CPython m/b,D,Z cfg/retry-mode#legacy botocore/1.40.61'}, 'body': b'', 'auth_path': '/czi-variantformer/model/common/cres_all_genes/ENSG00000000457.13/gene_vocab.csv', 'url': 'https://czi-variantformer.s3.amazonaws.com/model/common/cres_all_genes/ENSG00000000457.13/gene_vocab.csv', 'context': {'client_region': 'us-east-1', 'client_config': <aiobotocore.config.AioConfig object at 0x75533043aae0>, 'has_streaming_input': False, 'auth_type': 'none', 'unsigned_payload': None, 'auth_options': ['aws.auth#sigv4'], 's3_redirect': {'redirected': False, 'bucket': 'czi-variantformer', 'params': {'Bucket': 'czi-variantformer', 'Key': 'model/common/cres_all_genes/ENSG00000000457.13/gene_vocab.csv', 'ChecksumMode': 'ENABLED'}}, 'input_params': {'Bucket': 'czi-variantformer', 'Key': 'model/common/cres_all_genes/ENSG00000000457.13/gene_vocab.csv'}, 'signing': {}, 'endpoint_properties': {'authSchemes': [{'disableDoubleEncoding': True, 'name': 'sigv4', 'signingName': 's3', 'signingRegion': 'us-east-1'}]}, 'checksum': {'response_algorithms': ['crc32', 'sha1', 'sha256']}}}
# 2025-11-04 15:12:10 - botocore.hooks - DEBUG - Event request-created.s3.GetObject: calling handler <bound method AioRequestSigner.handler of <aiobotocore.signers.AioRequestSigner object at 0x754febad8230>>
# 2025-11-04 15:12:10 - botocore.hooks - DEBUG - Event choose-signer.s3.GetObject: calling handler <function set_operation_specific_signer at 0x754fa8145c60>
# 2025-11-04 15:12:10 - botocore.hooks - DEBUG - Event before-sign.s3.GetObject: calling handler <function remove_arn_from_signing_path at 0x754fa80f8540>
# 2025-11-04 15:12:10 - botocore.hooks - DEBUG - Event before-sign.s3.GetObject: calling handler <function _set_extra_headers_for_unsigned_request at 0x754fa80f8b80>
# 2025-11-04 15:12:10 - botocore.hooks - DEBUG - Event before-sign.s3.GetObject: calling handler <bound method S3ExpressIdentityResolver.resolve_s3express_identity of <aiobotocore.utils.AioS3ExpressIdentityResolver object at 0x75524a4f5c70>>
# 2025-11-04 15:12:10 - botocore.hooks - DEBUG - Event request-created.s3.GetObject: calling handler <bound method UserAgentString.rebuild_and_replace_user_agent_handler of <botocore.useragent.UserAgentString object at 0x75524a4e6120>>
# 2025-11-04 15:12:10 - botocore.hooks - DEBUG - Event request-created.s3.GetObject: calling handler <function add_retry_headers at 0x754fa80f8360>
# 2025-11-04 15:12:10 - botocore.endpoint - DEBUG - Sending http request: <AWSPreparedRequest stream_output=True, method=GET, url=https://czi-variantformer.s3.amazonaws.com/model/common/cres_all_genes/ENSG00000000457.13/gene_vocab.csv, headers={'x-amz-checksum-mode': b'ENABLED', 'User-Agent': b'aiobotocore/2.25.1 md/Botocore#1.40.61 ua/2.1 os/linux#6.5.13-65-650-4141-22041-coreweave-amd64-85c45edc md/arch#x86_64 lang/python#3.12.10 md/pyimpl#CPython m/b,D,Z cfg/retry-mode#legacy botocore/1.40.61', 'amz-sdk-invocation-id': b'dcc3e94f-10c6-4475-ae0a-56627daa5955', 'amz-sdk-request': b'attempt=1'}>
# 2025-11-04 15:12:10 - botocore.httpsession - DEBUG - Certificate path: /work/.venv/lib/python3.12/site-packages/certifi/cacert.pem
# 2025-11-04 15:12:10 - botocore.hooks - DEBUG - Event before-parse.s3.GetObject: calling handler <function _handle_200_error at 0x754fa80f8900>
# 2025-11-04 15:12:10 - botocore.hooks - DEBUG - Event before-parse.s3.GetObject: calling handler <function handle_expires_header at 0x754fa80f8720>
# 2025-11-04 15:12:10 - botocore.parsers - DEBUG - Response headers: {'x-amz-id-2': 'Arrns12pwvR39fzPyKjishMAvbt9re8YtsD/xjFDc+Op4j9OIZTjsCAHTAvrSytX0CFntXXm11c=', 'x-amz-request-id': 'W66P24RD8SCHNK9T', 'date': 'Tue, 04 Nov 2025 23:12:11 GMT', 'last-modified': 'Thu, 23 Oct 2025 22:52:46 GMT', 'etag': '"b469be4b215cdb5fe2d9ac02df216035"', 'x-amz-checksum-crc32': 'uvRKlg==', 'x-amz-checksum-type': 'FULL_OBJECT', 'x-amz-server-side-encryption': 'AES256', 'x-amz-version-id': 'eS4ZJrHvlz9LwJI.0pQ4kMKwjS4QYLAN', 'accept-ranges': 'bytes', 'content-type': 'binary/octet-stream', 'content-length': '1805209', 'server': 'AmazonS3'}
# 2025-11-04 15:12:10 - botocore.parsers - DEBUG - Response body:
# <ClientResponse(https://czi-variantformer.s3.amazonaws.com/model/common/cres_all_genes/ENSG00000000457.13/gene_vocab.csv) [200 OK]>
# <CIMultiDictProxy('x-amz-id-2': 'Arrns12pwvR39fzPyKjishMAvbt9re8YtsD/xjFDc+Op4j9OIZTjsCAHTAvrSytX0CFntXXm11c=', 'x-amz-request-id': 'W66P24RD8SCHNK9T', 'Date': 'Tue, 04 Nov 2025 23:12:11 GMT', 'Last-Modified': 'Thu, 23 Oct 2025 22:52:46 GMT', 'Etag': '"b469be4b215cdb5fe2d9ac02df216035"', 'x-amz-checksum-crc32': 'uvRKlg==', 'x-amz-checksum-type': 'FULL_OBJECT', 'x-amz-server-side-encryption': 'AES256', 'x-amz-version-id': 'eS4ZJrHvlz9LwJI.0pQ4kMKwjS4QYLAN', 'Accept-Ranges': 'bytes', 'Content-Type': 'binary/octet-stream', 'Content-Length': '1805209', 'Server': 'AmazonS3')>
#
# 2025-11-04 15:12:10 - botocore.hooks - DEBUG - Event needs-retry.s3.GetObject: calling handler <function _update_status_code at 0x754fa80f8a40>
# 2025-11-04 15:12:10 - botocore.hooks - DEBUG - Event needs-retry.s3.GetObject: calling handler <aiobotocore.retryhandler.AioRetryHandler object at 0x755325df9730>
# 2025-11-04 15:12:10 - botocore.retryhandler - DEBUG - No retry needed.
# 2025-11-04 15:12:10 - botocore.hooks - DEBUG - Event needs-retry.s3.GetObject: calling handler <bound method AioS3RegionRedirectorv2.redirect_from_error of <aiobotocore.utils.AioS3RegionRedirectorv2 object at 0x75526a732d20>>
# 2025-11-04 15:12:11 - s3fs - DEBUG - CALL: head_object - ({},) - {'Bucket': 'czi-variantformer', 'Key': 'model/common/cres_all_genes/ENSG00000000457.13/gene_vocab.csv'}
# 2025-11-04 15:12:11 - botocore.hooks - DEBUG - Event before-parameter-build.s3.HeadObject: calling handler <function sse_md5 at 0x754fa8146160>
# 2025-11-04 15:12:11 - botocore.hooks - DEBUG - Event before-parameter-build.s3.HeadObject: calling handler <function validate_bucket_name at 0x754fa81460c0>
# 2025-11-04 15:12:11 - botocore.hooks - DEBUG - Event before-parameter-build.s3.HeadObject: calling handler <function remove_bucket_from_url_paths_from_model at 0x754fa80f8400>
# 2025-11-04 15:12:11 - botocore.hooks - DEBUG - Event before-parameter-build.s3.HeadObject: calling handler <bound method S3RegionRedirectorv2.annotate_request_context of <aiobotocore.utils.AioS3RegionRedirectorv2 object at 0x75526a732d20>>
# 2025-11-04 15:12:11 - botocore.hooks - DEBUG - Event before-parameter-build.s3.HeadObject: calling handler <bound method ClientCreator._inject_s3_input_parameters of <aiobotocore.client.AioClientCreator object at 0x75526a720e00>>
# 2025-11-04 15:12:11 - botocore.hooks - DEBUG - Event before-parameter-build.s3.HeadObject: calling handler <function generate_idempotent_uuid at 0x754fa8145ee0>
# 2025-11-04 15:12:11 - botocore.hooks - DEBUG - Event before-parameter-build.s3.HeadObject: calling handler <function _handle_request_validation_mode_member at 0x754fa80f8ae0>
# 2025-11-04 15:12:11 - botocore.hooks - DEBUG - Event before-endpoint-resolution.s3: calling handler <function customize_endpoint_resolver_builtins at 0x754fa80f85e0>
# 2025-11-04 15:12:11 - botocore.hooks - DEBUG - Event before-endpoint-resolution.s3: calling handler <bound method S3RegionRedirectorv2.redirect_from_cache of <aiobotocore.utils.AioS3RegionRedirectorv2 object at 0x75526a732d20>>
# 2025-11-04 15:12:11 - aiobotocore.regions - DEBUG - Calling endpoint provider with parameters: {'Bucket': 'czi-variantformer', 'Region': 'us-east-1', 'UseFIPS': False, 'UseDualStack': False, 'ForcePathStyle': False, 'Accelerate': False, 'UseGlobalEndpoint': True, 'Key': 'model/common/cres_all_genes/ENSG00000000457.13/gene_vocab.csv', 'DisableMultiRegionAccessPoints': False, 'UseArnRegion': True}
# 2025-11-04 15:12:11 - aiobotocore.regions - DEBUG - Endpoint provider result: https://czi-variantformer.s3.amazonaws.com
# 2025-11-04 15:12:11 - botocore.regions - DEBUG - Selecting from endpoint provider's list of auth schemes: "sigv4". User selected auth scheme is: "<botocore.UNSIGNED object at 0x754fa80d6300>"
# 2025-11-04 15:12:11 - botocore.hooks - DEBUG - Event before-call.s3.HeadObject: calling handler <function add_expect_header at 0x754fa8146480>
# 2025-11-04 15:12:11 - botocore.hooks - DEBUG - Event before-call.s3.HeadObject: calling handler <bound method S3ExpressIdentityResolver.apply_signing_cache_key of <aiobotocore.utils.AioS3ExpressIdentityResolver object at 0x75524a4f5c70>>
# 2025-11-04 15:12:11 - botocore.hooks - DEBUG - Event before-call.s3.HeadObject: calling handler <function add_recursion_detection_header at 0x754fa81445e0>
# 2025-11-04 15:12:11 - botocore.hooks - DEBUG - Event before-call.s3.HeadObject: calling handler <function inject_api_version_header_if_needed at 0x754fa81479c0>
# 2025-11-04 15:12:11 - botocore.endpoint - DEBUG - Making request for OperationModel(name=HeadObject) with params: {'url_path': '/model/common/cres_all_genes/ENSG00000000457.13/gene_vocab.csv', 'query_string': {}, 'method': 'HEAD', 'headers': {'User-Agent': 'aiobotocore/2.25.1 md/Botocore#1.40.61 ua/2.1 os/linux#6.5.13-65-650-4141-22041-coreweave-amd64-85c45edc md/arch#x86_64 lang/python#3.12.10 md/pyimpl#CPython m/b,D,Z cfg/retry-mode#legacy botocore/1.40.61'}, 'body': b'', 'auth_path': '/czi-variantformer/model/common/cres_all_genes/ENSG00000000457.13/gene_vocab.csv', 'url': 'https://czi-variantformer.s3.amazonaws.com/model/common/cres_all_genes/ENSG00000000457.13/gene_vocab.csv', 'context': {'client_region': 'us-east-1', 'client_config': <aiobotocore.config.AioConfig object at 0x75533043aae0>, 'has_streaming_input': False, 'auth_type': 'none', 'unsigned_payload': None, 'auth_options': ['aws.auth#sigv4'], 's3_redirect': {'redirected': False, 'bucket': 'czi-variantformer', 'params': {'Bucket': 'czi-variantformer', 'Key': 'model/common/cres_all_genes/ENSG00000000457.13/gene_vocab.csv'}}, 'input_params': {'Bucket': 'czi-variantformer', 'Key': 'model/common/cres_all_genes/ENSG00000000457.13/gene_vocab.csv'}, 'signing': {}, 'endpoint_properties': {'authSchemes': [{'disableDoubleEncoding': True, 'name': 'sigv4', 'signingName': 's3', 'signingRegion': 'us-east-1'}]}}}
# 2025-11-04 15:12:11 - botocore.hooks - DEBUG - Event request-created.s3.HeadObject: calling handler <bound method AioRequestSigner.handler of <aiobotocore.signers.AioRequestSigner object at 0x754febad8230>>
# 2025-11-04 15:12:11 - botocore.hooks - DEBUG - Event choose-signer.s3.HeadObject: calling handler <function set_operation_specific_signer at 0x754fa8145c60>
# 2025-11-04 15:12:11 - botocore.hooks - DEBUG - Event before-sign.s3.HeadObject: calling handler <function remove_arn_from_signing_path at 0x754fa80f8540>
# 2025-11-04 15:12:11 - botocore.hooks - DEBUG - Event before-sign.s3.HeadObject: calling handler <function _set_extra_headers_for_unsigned_request at 0x754fa80f8b80>
# 2025-11-04 15:12:11 - botocore.hooks - DEBUG - Event before-sign.s3.HeadObject: calling handler <bound method S3ExpressIdentityResolver.resolve_s3express_identity of <aiobotocore.utils.AioS3ExpressIdentityResolver object at 0x75524a4f5c70>>
# 2025-11-04 15:12:11 - botocore.hooks - DEBUG - Event request-created.s3.HeadObject: calling handler <bound method UserAgentString.rebuild_and_replace_user_agent_handler of <botocore.useragent.UserAgentString object at 0x75524a4e6120>>
# 2025-11-04 15:12:11 - botocore.hooks - DEBUG - Event request-created.s3.HeadObject: calling handler <function add_retry_headers at 0x754fa80f8360>
# 2025-11-04 15:12:11 - botocore.endpoint - DEBUG - Sending http request: <AWSPreparedRequest stream_output=False, method=HEAD, url=https://czi-variantformer.s3.amazonaws.com/model/common/cres_all_genes/ENSG00000000457.13/gene_vocab.csv, headers={'User-Agent': b'aiobotocore/2.25.1 md/Botocore#1.40.61 ua/2.1 os/linux#6.5.13-65-650-4141-22041-coreweave-amd64-85c45edc md/arch#x86_64 lang/python#3.12.10 md/pyimpl#CPython m/b,D,Z cfg/retry-mode#legacy botocore/1.40.61', 'amz-sdk-invocation-id': b'f8bb97e6-a58f-4d9d-97a7-6da0fcd0e09e', 'amz-sdk-request': b'attempt=1'}>
# 2025-11-04 15:12:11 - botocore.hooks - DEBUG - Event before-parse.s3.HeadObject: calling handler <function _handle_200_error at 0x754fa80f8900>
# 2025-11-04 15:12:11 - botocore.hooks - DEBUG - Event before-parse.s3.HeadObject: calling handler <function handle_expires_header at 0x754fa80f8720>
# 2025-11-04 15:12:11 - botocore.parsers - DEBUG - Response headers: {'x-amz-id-2': 'gXu7jiUR6rn6NN+PWa+I1/AelX0RNJwZHh3dOlqc+D7qH0GJfrHPVWWeb+NhJNtU7fomBlbjZkk=', 'x-amz-request-id': '6G5AQ2W99XF18MAC', 'date': 'Tue, 04 Nov 2025 23:12:12 GMT', 'last-modified': 'Thu, 23 Oct 2025 22:52:46 GMT', 'etag': '"b469be4b215cdb5fe2d9ac02df216035"', 'x-amz-server-side-encryption': 'AES256', 'x-amz-version-id': 'eS4ZJrHvlz9LwJI.0pQ4kMKwjS4QYLAN', 'accept-ranges': 'bytes', 'content-type': 'binary/octet-stream', 'content-length': '1805209', 'server': 'AmazonS3'}
# 2025-11-04 15:12:11 - botocore.parsers - DEBUG - Response body:
# b''
# 2025-11-04 15:12:11 - botocore.hooks - DEBUG - Event needs-retry.s3.HeadObject: calling handler <function _update_status_code at 0x754fa80f8a40>
# 2025-11-04 15:12:11 - botocore.hooks - DEBUG - Event needs-retry.s3.HeadObject: calling handler <aiobotocore.retryhandler.AioRetryHandler object at 0x755325df9730>
# 2025-11-04 15:12:11 - botocore.retryhandler - DEBUG - No retry needed.
# 2025-11-04 15:12:11 - botocore.hooks - DEBUG - Event needs-retry.s3.HeadObject: calling handler <bound method AioS3RegionRedirectorv2.redirect_from_error of <aiobotocore.utils.AioS3RegionRedirectorv2 object at 0x75526a732d20>>
# 2025-11-04 15:12:11 - filelock - DEBUG - Attempting to release lock 129002770750912 on /work/_artifacts/model/common/cres_all_genes/ENSG00000000457.13/gene_vocab.csv.lock
# 2025-11-04 15:12:11 - filelock - DEBUG - Lock 129002770750912 released on /work/_artifacts/model/common/cres_all_genes/ENSG00000000457.13/gene_vocab.csv.lock
# 2025-11-04 15:12:18 - filelock - DEBUG - Attempting to acquire lock 129002798020320 on /work/_artifacts/alzheimer_disease/v4_pcg/manifest.parquet.lock
# 2025-11-04 15:12:18 - filelock - DEBUG - Lock 129002798020320 acquired on /work/_artifacts/alzheimer_disease/v4_pcg/manifest.parquet.lock
# 2025-11-04 15:12:18 - asyncio - DEBUG - Using selector: EpollSelector
# 2025-11-04 15:12:18 - s3fs - DEBUG - Setting up s3fs instance
# 2025-11-04 15:12:18 - botocore.hooks - DEBUG - Changing event name from creating-client-class.iot-data to creating-client-class.iot-data-plane
# 2025-11-04 15:12:18 - botocore.hooks - DEBUG - Changing event name from before-call.apigateway to before-call.api-gateway
# 2025-11-04 15:12:18 - botocore.hooks - DEBUG - Changing event name from request-created.machinelearning.Predict to request-created.machine-learning.Predict
# 2025-11-04 15:12:18 - botocore.hooks - DEBUG - Changing event name from before-parameter-build.autoscaling.CreateLaunchConfiguration to before-parameter-build.auto-scaling.CreateLaunchConfiguration
# 2025-11-04 15:12:18 - botocore.hooks - DEBUG - Changing event name from before-parameter-build.route53 to before-parameter-build.route-53
# 2025-11-04 15:12:18 - botocore.hooks - DEBUG - Changing event name from request-created.cloudsearchdomain.Search to request-created.cloudsearch-domain.Search
# 2025-11-04 15:12:18 - botocore.hooks - DEBUG - Changing event name from docs.*.autoscaling.CreateLaunchConfiguration.complete-section to docs.*.auto-scaling.CreateLaunchConfiguration.complete-section
# 2025-11-04 15:12:18 - botocore.hooks - DEBUG - Changing event name from before-parameter-build.logs.CreateExportTask to before-parameter-build.cloudwatch-logs.CreateExportTask
# 2025-11-04 15:12:18 - botocore.hooks - DEBUG - Changing event name from docs.*.logs.CreateExportTask.complete-section to docs.*.cloudwatch-logs.CreateExportTask.complete-section
# 2025-11-04 15:12:18 - botocore.hooks - DEBUG - Changing event name from before-parameter-build.cloudsearchdomain.Search to before-parameter-build.cloudsearch-domain.Search
# 2025-11-04 15:12:18 - botocore.hooks - DEBUG - Changing event name from docs.*.cloudsearchdomain.Search.complete-section to docs.*.cloudsearch-domain.Search.complete-section
# 2025-11-04 15:12:18 - s3fs - DEBUG - RC: caching enabled? False (explicit option is False)
# 2025-11-04 15:12:18 - botocore.loaders - DEBUG - Loading JSON file: /work/.venv/lib/python3.12/site-packages/botocore/data/endpoints.json
# 2025-11-04 15:12:18 - botocore.loaders - DEBUG - Loading JSON file: /work/.venv/lib/python3.12/site-packages/botocore/data/sdk-default-configuration.json
# 2025-11-04 15:12:18 - botocore.hooks - DEBUG - Event choose-service-name: calling handler <function handle_service_name_alias at 0x75526a73c4a0>
# 2025-11-04 15:12:18 - botocore.loaders - DEBUG - Loading JSON file: /work/.venv/lib/python3.12/site-packages/botocore/data/s3/2006-03-01/service-2.json.gz
# 2025-11-04 15:12:18 - botocore.loaders - DEBUG - Loading JSON file: /work/.venv/lib/python3.12/site-packages/botocore/data/s3/2006-03-01/service-2.sdk-extras.json
# 2025-11-04 15:12:18 - botocore.loaders - DEBUG - Loading JSON file: /work/.venv/lib/python3.12/site-packages/botocore/data/s3/2006-03-01/endpoint-rule-set-1.json.gz
# 2025-11-04 15:12:18 - botocore.loaders - DEBUG - Loading JSON file: /work/.venv/lib/python3.12/site-packages/botocore/data/partitions.json
# 2025-11-04 15:12:18 - botocore.hooks - DEBUG - Event creating-client-class.s3: calling handler <function add_generate_presigned_post at 0x75532efd34c0>
# 2025-11-04 15:12:18 - botocore.hooks - DEBUG - Event creating-client-class.s3: calling handler <function add_generate_presigned_url at 0x75532efd3240>
# 2025-11-04 15:12:18 - botocore.configprovider - DEBUG - Looking for endpoint for s3 via: environment_service
# 2025-11-04 15:12:18 - botocore.configprovider - DEBUG - Looking for endpoint for s3 via: environment_global
# 2025-11-04 15:12:18 - botocore.configprovider - DEBUG - Looking for endpoint for s3 via: config_service
# 2025-11-04 15:12:18 - botocore.configprovider - DEBUG - Looking for endpoint for s3 via: config_global
# 2025-11-04 15:12:18 - botocore.configprovider - DEBUG - No configured endpoint found.
# 2025-11-04 15:12:18 - botocore.endpoint - DEBUG - Setting s3 timeout as (5, 15)
# 2025-11-04 15:12:18 - botocore.loaders - DEBUG - Loading JSON file: /work/.venv/lib/python3.12/site-packages/botocore/data/_retry.json
# 2025-11-04 15:12:18 - botocore.client - DEBUG - Registering retry handlers for service: s3
# 2025-11-04 15:12:18 - botocore.utils - DEBUG - Registering S3 region redirector handler
# 2025-11-04 15:12:18 - botocore.utils - DEBUG - Registering S3Express Identity Resolver
# 2025-11-04 15:12:18 - s3fs - DEBUG - CALL: get_object - () - {'Bucket': 'czi-variantformer', 'Key': 'alzheimer_disease/v4_pcg/manifest.parquet'}
# 2025-11-04 15:12:18 - botocore.hooks - DEBUG - Event before-parameter-build.s3.GetObject: calling handler <function sse_md5 at 0x75526a73e020>
# 2025-11-04 15:12:18 - botocore.hooks - DEBUG - Event before-parameter-build.s3.GetObject: calling handler <function validate_bucket_name at 0x75526a73df80>
# 2025-11-04 15:12:18 - botocore.hooks - DEBUG - Event before-parameter-build.s3.GetObject: calling handler <function remove_bucket_from_url_paths_from_model at 0x75526a70c2c0>
# 2025-11-04 15:12:18 - botocore.hooks - DEBUG - Event before-parameter-build.s3.GetObject: calling handler <bound method S3RegionRedirectorv2.annotate_request_context of <aiobotocore.utils.AioS3RegionRedirectorv2 object at 0x75532e4daff0>>
# 2025-11-04 15:12:18 - botocore.hooks - DEBUG - Event before-parameter-build.s3.GetObject: calling handler <bound method ClientCreator._inject_s3_input_parameters of <aiobotocore.client.AioClientCreator object at 0x75532ee6d460>>
# 2025-11-04 15:12:18 - botocore.hooks - DEBUG - Event before-parameter-build.s3.GetObject: calling handler <function generate_idempotent_uuid at 0x75526a73dda0>
# 2025-11-04 15:12:18 - botocore.hooks - DEBUG - Event before-parameter-build.s3.GetObject: calling handler <function _handle_request_validation_mode_member at 0x75526a70c9a0>
# 2025-11-04 15:12:18 - botocore.hooks - DEBUG - Event before-endpoint-resolution.s3: calling handler <function customize_endpoint_resolver_builtins at 0x75526a70c4a0>
# 2025-11-04 15:12:18 - botocore.hooks - DEBUG - Event before-endpoint-resolution.s3: calling handler <bound method S3RegionRedirectorv2.redirect_from_cache of <aiobotocore.utils.AioS3RegionRedirectorv2 object at 0x75532e4daff0>>
# 2025-11-04 15:12:18 - aiobotocore.regions - DEBUG - Calling endpoint provider with parameters: {'Bucket': 'czi-variantformer', 'Region': 'us-east-1', 'UseFIPS': False, 'UseDualStack': False, 'ForcePathStyle': False, 'Accelerate': False, 'UseGlobalEndpoint': True, 'Key': 'alzheimer_disease/v4_pcg/manifest.parquet', 'DisableMultiRegionAccessPoints': False, 'UseArnRegion': True}
# 2025-11-04 15:12:18 - aiobotocore.regions - DEBUG - Endpoint provider result: https://czi-variantformer.s3.amazonaws.com
# 2025-11-04 15:12:18 - botocore.regions - DEBUG - Selecting from endpoint provider's list of auth schemes: "sigv4". User selected auth scheme is: "<botocore.UNSIGNED object at 0x7553328937d0>"
# 2025-11-04 15:12:18 - botocore.hooks - DEBUG - Event before-call.s3.GetObject: calling handler <function add_expect_header at 0x75526a73e340>
# 2025-11-04 15:12:18 - botocore.hooks - DEBUG - Event before-call.s3.GetObject: calling handler <bound method S3ExpressIdentityResolver.apply_signing_cache_key of <aiobotocore.utils.AioS3ExpressIdentityResolver object at 0x75532e4db980>>
# 2025-11-04 15:12:18 - botocore.hooks - DEBUG - Event before-call.s3.GetObject: calling handler <function add_recursion_detection_header at 0x75526a73c720>
# 2025-11-04 15:12:18 - botocore.hooks - DEBUG - Event before-call.s3.GetObject: calling handler <function inject_api_version_header_if_needed at 0x75526a73f880>
# 2025-11-04 15:12:18 - botocore.endpoint - DEBUG - Making request for OperationModel(name=GetObject) with params: {'url_path': '/alzheimer_disease/v4_pcg/manifest.parquet', 'query_string': {}, 'method': 'GET', 'headers': {'x-amz-checksum-mode': 'ENABLED', 'User-Agent': 'aiobotocore/2.25.1 md/Botocore#1.40.61 ua/2.1 os/linux#6.5.13-65-650-4141-22041-coreweave-amd64-85c45edc md/arch#x86_64 lang/python#3.12.10 md/pyimpl#CPython m/b,D,Z cfg/retry-mode#legacy botocore/1.40.61'}, 'body': b'', 'auth_path': '/czi-variantformer/alzheimer_disease/v4_pcg/manifest.parquet', 'url': 'https://czi-variantformer.s3.amazonaws.com/alzheimer_disease/v4_pcg/manifest.parquet', 'context': {'client_region': 'us-east-1', 'client_config': <aiobotocore.config.AioConfig object at 0x754fa80d4680>, 'has_streaming_input': False, 'auth_type': 'none', 'unsigned_payload': None, 'auth_options': ['aws.auth#sigv4'], 's3_redirect': {'redirected': False, 'bucket': 'czi-variantformer', 'params': {'Bucket': 'czi-variantformer', 'Key': 'alzheimer_disease/v4_pcg/manifest.parquet', 'ChecksumMode': 'ENABLED'}}, 'input_params': {'Bucket': 'czi-variantformer', 'Key': 'alzheimer_disease/v4_pcg/manifest.parquet'}, 'signing': {}, 'endpoint_properties': {'authSchemes': [{'disableDoubleEncoding': True, 'name': 'sigv4', 'signingName': 's3', 'signingRegion': 'us-east-1'}]}, 'checksum': {'response_algorithms': ['crc32', 'sha1', 'sha256']}}}
# 2025-11-04 15:12:18 - botocore.hooks - DEBUG - Event request-created.s3.GetObject: calling handler <bound method AioRequestSigner.handler of <aiobotocore.signers.AioRequestSigner object at 0x75532f03bb30>>
# 2025-11-04 15:12:18 - botocore.hooks - DEBUG - Event choose-signer.s3.GetObject: calling handler <function set_operation_specific_signer at 0x75526a73db20>
# 2025-11-04 15:12:18 - botocore.hooks - DEBUG - Event before-sign.s3.GetObject: calling handler <function remove_arn_from_signing_path at 0x75526a70c400>
# 2025-11-04 15:12:18 - botocore.hooks - DEBUG - Event before-sign.s3.GetObject: calling handler <function _set_extra_headers_for_unsigned_request at 0x75526a70ca40>
# 2025-11-04 15:12:18 - botocore.hooks - DEBUG - Event before-sign.s3.GetObject: calling handler <bound method S3ExpressIdentityResolver.resolve_s3express_identity of <aiobotocore.utils.AioS3ExpressIdentityResolver object at 0x75532e4db980>>
# 2025-11-04 15:12:18 - botocore.hooks - DEBUG - Event request-created.s3.GetObject: calling handler <bound method UserAgentString.rebuild_and_replace_user_agent_handler of <botocore.useragent.UserAgentString object at 0x75532e4da690>>
# 2025-11-04 15:12:18 - botocore.hooks - DEBUG - Event request-created.s3.GetObject: calling handler <function add_retry_headers at 0x75526a70c220>
# 2025-11-04 15:12:18 - botocore.endpoint - DEBUG - Sending http request: <AWSPreparedRequest stream_output=True, method=GET, url=https://czi-variantformer.s3.amazonaws.com/alzheimer_disease/v4_pcg/manifest.parquet, headers={'x-amz-checksum-mode': b'ENABLED', 'User-Agent': b'aiobotocore/2.25.1 md/Botocore#1.40.61 ua/2.1 os/linux#6.5.13-65-650-4141-22041-coreweave-amd64-85c45edc md/arch#x86_64 lang/python#3.12.10 md/pyimpl#CPython m/b,D,Z cfg/retry-mode#legacy botocore/1.40.61', 'amz-sdk-invocation-id': b'e6b575ec-3d44-4517-90d3-1db31ee376b3', 'amz-sdk-request': b'attempt=1'}>
# 2025-11-04 15:12:18 - botocore.httpsession - DEBUG - Certificate path: /work/.venv/lib/python3.12/site-packages/certifi/cacert.pem
# 2025-11-04 15:12:19 - botocore.httpchecksum - DEBUG - Skipping checksum validation. Response did not contain one of the following algorithms: ['crc32', 'sha1', 'sha256'].
# 2025-11-04 15:12:19 - botocore.hooks - DEBUG - Event before-parse.s3.GetObject: calling handler <function _handle_200_error at 0x75526a70c7c0>
# 2025-11-04 15:12:19 - botocore.hooks - DEBUG - Event before-parse.s3.GetObject: calling handler <function handle_expires_header at 0x75526a70c5e0>
# 2025-11-04 15:12:19 - botocore.parsers - DEBUG - Response headers: {'x-amz-id-2': '/02+OfyC+vEUIv8f7T6iytRvtp0hYVsPxYUv5DvlqMrC54iTUX0cWtx43W6kMNdgd1PZL74O6vY=', 'x-amz-request-id': '0ZJ29V8DC902BW2K', 'date': 'Tue, 04 Nov 2025 23:12:19 GMT', 'last-modified': 'Thu, 23 Oct 2025 22:52:38 GMT', 'etag': '"0e85e1a11b21197b2e4d93e2df06161d"', 'x-amz-checksum-crc64nvme': 'qdw8DnyS3ms=', 'x-amz-checksum-type': 'FULL_OBJECT', 'x-amz-server-side-encryption': 'AES256', 'x-amz-version-id': 'yawVsuNUjvwmomYw6SFULLJid9berHui', 'accept-ranges': 'bytes', 'content-type': 'binary/octet-stream', 'content-length': '6801110', 'server': 'AmazonS3'}
# 2025-11-04 15:12:19 - botocore.parsers - DEBUG - Response body:
# <ClientResponse(https://czi-variantformer.s3.amazonaws.com/alzheimer_disease/v4_pcg/manifest.parquet) [200 OK]>
# <CIMultiDictProxy('x-amz-id-2': '/02+OfyC+vEUIv8f7T6iytRvtp0hYVsPxYUv5DvlqMrC54iTUX0cWtx43W6kMNdgd1PZL74O6vY=', 'x-amz-request-id': '0ZJ29V8DC902BW2K', 'Date': 'Tue, 04 Nov 2025 23:12:19 GMT', 'Last-Modified': 'Thu, 23 Oct 2025 22:52:38 GMT', 'Etag': '"0e85e1a11b21197b2e4d93e2df06161d"', 'x-amz-checksum-crc64nvme': 'qdw8DnyS3ms=', 'x-amz-checksum-type': 'FULL_OBJECT', 'x-amz-server-side-encryption': 'AES256', 'x-amz-version-id': 'yawVsuNUjvwmomYw6SFULLJid9berHui', 'Accept-Ranges': 'bytes', 'Content-Type': 'binary/octet-stream', 'Content-Length': '6801110', 'Server': 'AmazonS3')>
#
# 2025-11-04 15:12:19 - botocore.hooks - DEBUG - Event needs-retry.s3.GetObject: calling handler <function _update_status_code at 0x75526a70c900>
# 2025-11-04 15:12:19 - botocore.hooks - DEBUG - Event needs-retry.s3.GetObject: calling handler <aiobotocore.retryhandler.AioRetryHandler object at 0x75532e4db890>
# 2025-11-04 15:12:19 - botocore.retryhandler - DEBUG - No retry needed.
# 2025-11-04 15:12:19 - botocore.hooks - DEBUG - Event needs-retry.s3.GetObject: calling handler <bound method AioS3RegionRedirectorv2.redirect_from_error of <aiobotocore.utils.AioS3RegionRedirectorv2 object at 0x75532e4daff0>>
# 2025-11-04 15:12:19 - s3fs - DEBUG - CALL: head_object - ({},) - {'Bucket': 'czi-variantformer', 'Key': 'alzheimer_disease/v4_pcg/manifest.parquet'}
# 2025-11-04 15:12:19 - botocore.hooks - DEBUG - Event before-parameter-build.s3.HeadObject: calling handler <function sse_md5 at 0x75526a73e020>
# 2025-11-04 15:12:19 - botocore.hooks - DEBUG - Event before-parameter-build.s3.HeadObject: calling handler <function validate_bucket_name at 0x75526a73df80>
# 2025-11-04 15:12:19 - botocore.hooks - DEBUG - Event before-parameter-build.s3.HeadObject: calling handler <function remove_bucket_from_url_paths_from_model at 0x75526a70c2c0>
# 2025-11-04 15:12:19 - botocore.hooks - DEBUG - Event before-parameter-build.s3.HeadObject: calling handler <bound method S3RegionRedirectorv2.annotate_request_context of <aiobotocore.utils.AioS3RegionRedirectorv2 object at 0x75532e4daff0>>
# 2025-11-04 15:12:19 - botocore.hooks - DEBUG - Event before-parameter-build.s3.HeadObject: calling handler <bound method ClientCreator._inject_s3_input_parameters of <aiobotocore.client.AioClientCreator object at 0x75532ee6d460>>
# 2025-11-04 15:12:19 - botocore.hooks - DEBUG - Event before-parameter-build.s3.HeadObject: calling handler <function generate_idempotent_uuid at 0x75526a73dda0>
# 2025-11-04 15:12:19 - botocore.hooks - DEBUG - Event before-parameter-build.s3.HeadObject: calling handler <function _handle_request_validation_mode_member at 0x75526a70c9a0>
# 2025-11-04 15:12:19 - botocore.hooks - DEBUG - Event before-endpoint-resolution.s3: calling handler <function customize_endpoint_resolver_builtins at 0x75526a70c4a0>
# 2025-11-04 15:12:19 - botocore.hooks - DEBUG - Event before-endpoint-resolution.s3: calling handler <bound method S3RegionRedirectorv2.redirect_from_cache of <aiobotocore.utils.AioS3RegionRedirectorv2 object at 0x75532e4daff0>>
# 2025-11-04 15:12:19 - aiobotocore.regions - DEBUG - Calling endpoint provider with parameters: {'Bucket': 'czi-variantformer', 'Region': 'us-east-1', 'UseFIPS': False, 'UseDualStack': False, 'ForcePathStyle': False, 'Accelerate': False, 'UseGlobalEndpoint': True, 'Key': 'alzheimer_disease/v4_pcg/manifest.parquet', 'DisableMultiRegionAccessPoints': False, 'UseArnRegion': True}
# 2025-11-04 15:12:19 - aiobotocore.regions - DEBUG - Endpoint provider result: https://czi-variantformer.s3.amazonaws.com
# 2025-11-04 15:12:19 - botocore.regions - DEBUG - Selecting from endpoint provider's list of auth schemes: "sigv4". User selected auth scheme is: "<botocore.UNSIGNED object at 0x7553328937d0>"
# 2025-11-04 15:12:19 - botocore.hooks - DEBUG - Event before-call.s3.HeadObject: calling handler <function add_expect_header at 0x75526a73e340>
# 2025-11-04 15:12:19 - botocore.hooks - DEBUG - Event before-call.s3.HeadObject: calling handler <bound method S3ExpressIdentityResolver.apply_signing_cache_key of <aiobotocore.utils.AioS3ExpressIdentityResolver object at 0x75532e4db980>>
# 2025-11-04 15:12:19 - botocore.hooks - DEBUG - Event before-call.s3.HeadObject: calling handler <function add_recursion_detection_header at 0x75526a73c720>
# 2025-11-04 15:12:19 - botocore.hooks - DEBUG - Event before-call.s3.HeadObject: calling handler <function inject_api_version_header_if_needed at 0x75526a73f880>
# 2025-11-04 15:12:19 - botocore.endpoint - DEBUG - Making request for OperationModel(name=HeadObject) with params: {'url_path': '/alzheimer_disease/v4_pcg/manifest.parquet', 'query_string': {}, 'method': 'HEAD', 'headers': {'User-Agent': 'aiobotocore/2.25.1 md/Botocore#1.40.61 ua/2.1 os/linux#6.5.13-65-650-4141-22041-coreweave-amd64-85c45edc md/arch#x86_64 lang/python#3.12.10 md/pyimpl#CPython m/b,D,Z cfg/retry-mode#legacy botocore/1.40.61'}, 'body': b'', 'auth_path': '/czi-variantformer/alzheimer_disease/v4_pcg/manifest.parquet', 'url': 'https://czi-variantformer.s3.amazonaws.com/alzheimer_disease/v4_pcg/manifest.parquet', 'context': {'client_region': 'us-east-1', 'client_config': <aiobotocore.config.AioConfig object at 0x754fa80d4680>, 'has_streaming_input': False, 'auth_type': 'none', 'unsigned_payload': None, 'auth_options': ['aws.auth#sigv4'], 's3_redirect': {'redirected': False, 'bucket': 'czi-variantformer', 'params': {'Bucket': 'czi-variantformer', 'Key': 'alzheimer_disease/v4_pcg/manifest.parquet'}}, 'input_params': {'Bucket': 'czi-variantformer', 'Key': 'alzheimer_disease/v4_pcg/manifest.parquet'}, 'signing': {}, 'endpoint_properties': {'authSchemes': [{'disableDoubleEncoding': True, 'name': 'sigv4', 'signingName': 's3', 'signingRegion': 'us-east-1'}]}}}
# 2025-11-04 15:12:19 - botocore.hooks - DEBUG - Event request-created.s3.HeadObject: calling handler <bound method AioRequestSigner.handler of <aiobotocore.signers.AioRequestSigner object at 0x75532f03bb30>>
# 2025-11-04 15:12:19 - botocore.hooks - DEBUG - Event choose-signer.s3.HeadObject: calling handler <function set_operation_specific_signer at 0x75526a73db20>
# 2025-11-04 15:12:19 - botocore.hooks - DEBUG - Event before-sign.s3.HeadObject: calling handler <function remove_arn_from_signing_path at 0x75526a70c400>
# 2025-11-04 15:12:19 - botocore.hooks - DEBUG - Event before-sign.s3.HeadObject: calling handler <function _set_extra_headers_for_unsigned_request at 0x75526a70ca40>
# 2025-11-04 15:12:19 - botocore.hooks - DEBUG - Event before-sign.s3.HeadObject: calling handler <bound method S3ExpressIdentityResolver.resolve_s3express_identity of <aiobotocore.utils.AioS3ExpressIdentityResolver object at 0x75532e4db980>>
# 2025-11-04 15:12:19 - botocore.hooks - DEBUG - Event request-created.s3.HeadObject: calling handler <bound method UserAgentString.rebuild_and_replace_user_agent_handler of <botocore.useragent.UserAgentString object at 0x75532e4da690>>
# 2025-11-04 15:12:19 - botocore.hooks - DEBUG - Event request-created.s3.HeadObject: calling handler <function add_retry_headers at 0x75526a70c220>
# 2025-11-04 15:12:19 - botocore.endpoint - DEBUG - Sending http request: <AWSPreparedRequest stream_output=False, method=HEAD, url=https://czi-variantformer.s3.amazonaws.com/alzheimer_disease/v4_pcg/manifest.parquet, headers={'User-Agent': b'aiobotocore/2.25.1 md/Botocore#1.40.61 ua/2.1 os/linux#6.5.13-65-650-4141-22041-coreweave-amd64-85c45edc md/arch#x86_64 lang/python#3.12.10 md/pyimpl#CPython m/b,D,Z cfg/retry-mode#legacy botocore/1.40.61', 'amz-sdk-invocation-id': b'b445c5d9-5898-4ac5-bf16-1e9a3b03b743', 'amz-sdk-request': b'attempt=1'}>
# 2025-11-04 15:12:20 - botocore.hooks - DEBUG - Event before-parse.s3.HeadObject: calling handler <function _handle_200_error at 0x75526a70c7c0>
# 2025-11-04 15:12:20 - botocore.hooks - DEBUG - Event before-parse.s3.HeadObject: calling handler <function handle_expires_header at 0x75526a70c5e0>
# 2025-11-04 15:12:20 - botocore.parsers - DEBUG - Response headers: {'x-amz-id-2': 'D92xihGJEsUVVVZQQrDiyeifkPseRMjFHmwFV3N8H/a33tVsfwyjgS7mys0B8j+Q6+wT8U8ytB0=', 'x-amz-request-id': 'SRJ2JGV7P2F0XRMD', 'date': 'Tue, 04 Nov 2025 23:12:20 GMT', 'last-modified': 'Thu, 23 Oct 2025 22:52:38 GMT', 'etag': '"0e85e1a11b21197b2e4d93e2df06161d"', 'x-amz-server-side-encryption': 'AES256', 'x-amz-version-id': 'yawVsuNUjvwmomYw6SFULLJid9berHui', 'accept-ranges': 'bytes', 'content-type': 'binary/octet-stream', 'content-length': '6801110', 'server': 'AmazonS3'}
# 2025-11-04 15:12:20 - botocore.parsers - DEBUG - Response body:
# b''
# 2025-11-04 15:12:20 - botocore.hooks - DEBUG - Event needs-retry.s3.HeadObject: calling handler <function _update_status_code at 0x75526a70c900>
# 2025-11-04 15:12:20 - botocore.hooks - DEBUG - Event needs-retry.s3.HeadObject: calling handler <aiobotocore.retryhandler.AioRetryHandler object at 0x75532e4db890>
# 2025-11-04 15:12:20 - botocore.retryhandler - DEBUG - No retry needed.
# 2025-11-04 15:12:20 - botocore.hooks - DEBUG - Event needs-retry.s3.HeadObject: calling handler <bound method AioS3RegionRedirectorv2.redirect_from_error of <aiobotocore.utils.AioS3RegionRedirectorv2 object at 0x75532e4daff0>>
# 2025-11-04 15:12:20 - filelock - DEBUG - Attempting to release lock 129002798020320 on /work/_artifacts/alzheimer_disease/v4_pcg/manifest.parquet.lock
# 2025-11-04 15:12:20 - filelock - DEBUG - Lock 129002798020320 released on /work/_artifacts/alzheimer_disease/v4_pcg/manifest.parquet.lock
# 2025-11-04 15:12:20 - utils.assets - INFO - Loading parquet file: /work/_artifacts/alzheimer_disease/v4_pcg/manifest.parquet
# 2025-11-04 15:12:20 - utils.assets - INFO - Validated schema - found columns: {'file_path', 'gene_id', 'tissue_id'}
# 2025-11-04 15:12:20 - filelock - DEBUG - Attempting to acquire lock 129000131376048 on /work/_artifacts/alzheimer_disease/v4_pcg/ad/ENSG00000000419.12/model_tissue_20.tl.lock
# 2025-11-04 15:12:20 - filelock - DEBUG - Lock 129000131376048 acquired on /work/_artifacts/alzheimer_disease/v4_pcg/ad/ENSG00000000419.12/model_tissue_20.tl.lock
# 2025-11-04 15:12:20 - s3fs - DEBUG - CALL: get_object - () - {'Bucket': 'czi-variantformer', 'Key': 'alzheimer_disease/v4_pcg/ad/ENSG00000000419.12/model_tissue_20.tl'}
# 2025-11-04 15:12:20 - botocore.hooks - DEBUG - Event before-parameter-build.s3.GetObject: calling handler <function sse_md5 at 0x75526a73e020>
# 2025-11-04 15:12:20 - botocore.hooks - DEBUG - Event before-parameter-build.s3.GetObject: calling handler <function validate_bucket_name at 0x75526a73df80>
# 2025-11-04 15:12:20 - botocore.hooks - DEBUG - Event before-parameter-build.s3.GetObject: calling handler <function remove_bucket_from_url_paths_from_model at 0x75526a70c2c0>
# 2025-11-04 15:12:20 - botocore.hooks - DEBUG - Event before-parameter-build.s3.GetObject: calling handler <bound method S3RegionRedirectorv2.annotate_request_context of <aiobotocore.utils.AioS3RegionRedirectorv2 object at 0x75532e4daff0>>
# 2025-11-04 15:12:20 - botocore.hooks - DEBUG - Event before-parameter-build.s3.GetObject: calling handler <bound method ClientCreator._inject_s3_input_parameters of <aiobotocore.client.AioClientCreator object at 0x75532ee6d460>>
# 2025-11-04 15:12:20 - botocore.hooks - DEBUG - Event before-parameter-build.s3.GetObject: calling handler <function generate_idempotent_uuid at 0x75526a73dda0>
# 2025-11-04 15:12:20 - botocore.hooks - DEBUG - Event before-parameter-build.s3.GetObject: calling handler <function _handle_request_validation_mode_member at 0x75526a70c9a0>
# ...
# 2025-11-04 15:12:21 - botocore.hooks - DEBUG - Event before-endpoint-resolution.s3: calling handler <function customize_endpoint_resolver_builtins at 0x75526a70c4a0>
# 2025-11-04 15:12:21 - botocore.hooks - DEBUG - Event before-endpoint-resolution.s3: calling handler <bound method S3RegionRedirectorv2.redirect_from_cache of <aiobotocore.utils.AioS3RegionRedirectorv2 object at 0x75532e4daff0>>
# 2025-11-04 15:12:21 - aiobotocore.regions - DEBUG - Calling endpoint provider with parameters: {'Bucket': 'czi-variantformer', 'Region': 'us-east-1', 'UseFIPS': False, 'UseDualStack': False, 'ForcePathStyle': False, 'Accelerate': False, 'UseGlobalEndpoint': True, 'Key': 'alzheimer_disease/v4_pcg/ad/ENSG00000000457.13/model_tissue_22.tl', 'DisableMultiRegionAccessPoints': False, 'UseArnRegion': True}
# 2025-11-04 15:12:21 - aiobotocore.regions - DEBUG - Endpoint provider result: https://czi-variantformer.s3.amazonaws.com
# 2025-11-04 15:12:21 - botocore.regions - DEBUG - Selecting from endpoint provider's list of auth schemes: "sigv4". User selected auth scheme is: "<botocore.UNSIGNED object at 0x7553328937d0>"
# 2025-11-04 15:12:21 - botocore.hooks - DEBUG - Event before-call.s3.GetObject: calling handler <function add_expect_header at 0x75526a73e340>
# 2025-11-04 15:12:21 - botocore.hooks - DEBUG - Event before-call.s3.GetObject: calling handler <bound method S3ExpressIdentityResolver.apply_signing_cache_key of <aiobotocore.utils.AioS3ExpressIdentityResolver object at 0x75532e4db980>>
# 2025-11-04 15:12:21 - botocore.hooks - DEBUG - Event before-call.s3.GetObject: calling handler <function add_recursion_detection_header at 0x75526a73c720>
# 2025-11-04 15:12:21 - botocore.hooks - DEBUG - Event before-call.s3.GetObject: calling handler <function inject_api_version_header_if_needed at 0x75526a73f880>
# 2025-11-04 15:12:21 - botocore.endpoint - DEBUG - Making request for OperationModel(name=GetObject) with params: {'url_path': '/alzheimer_disease/v4_pcg/ad/ENSG00000000457.13/model_tissue_22.tl', 'query_string': {}, 'method': 'GET', 'headers': {'x-amz-checksum-mode': 'ENABLED', 'User-Agent': 'aiobotocore/2.25.1 md/Botocore#1.40.61 ua/2.1 os/linux#6.5.13-65-650-4141-22041-coreweave-amd64-85c45edc md/arch#x86_64 lang/python#3.12.10 md/pyimpl#CPython m/b,D,Z cfg/retry-mode#legacy botocore/1.40.61'}, 'body': b'', 'auth_path': '/czi-variantformer/alzheimer_disease/v4_pcg/ad/ENSG00000000457.13/model_tissue_22.tl', 'url': 'https://czi-variantformer.s3.amazonaws.com/alzheimer_disease/v4_pcg/ad/ENSG00000000457.13/model_tissue_22.tl', 'context': {'client_region': 'us-east-1', 'client_config': <aiobotocore.config.AioConfig object at 0x754fa80d4680>, 'has_streaming_input': False, 'auth_type': 'none', 'unsigned_payload': None, 'auth_options': ['aws.auth#sigv4'], 's3_redirect': {'redirected': False, 'bucket': 'czi-variantformer', 'params': {'Bucket': 'czi-variantformer', 'Key': 'alzheimer_disease/v4_pcg/ad/ENSG00000000457.13/model_tissue_22.tl', 'ChecksumMode': 'ENABLED'}}, 'input_params': {'Bucket': 'czi-variantformer', 'Key': 'alzheimer_disease/v4_pcg/ad/ENSG00000000457.13/model_tissue_22.tl'}, 'signing': {}, 'endpoint_properties': {'authSchemes': [{'disableDoubleEncoding': True, 'name': 'sigv4', 'signingName': 's3', 'signingRegion': 'us-east-1'}]}, 'checksum': {'response_algorithms': ['crc32', 'sha1', 'sha256']}}}
# 2025-11-04 15:12:21 - botocore.hooks - DEBUG - Event request-created.s3.GetObject: calling handler <bound method AioRequestSigner.handler of <aiobotocore.signers.AioRequestSigner object at 0x75532f03bb30>>
# 2025-11-04 15:12:21 - botocore.hooks - DEBUG - Event choose-signer.s3.GetObject: calling handler <function set_operation_specific_signer at 0x75526a73db20>
# 2025-11-04 15:12:21 - botocore.hooks - DEBUG - Event before-sign.s3.GetObject: calling handler <function remove_arn_from_signing_path at 0x75526a70c400>
# 2025-11-04 15:12:21 - botocore.hooks - DEBUG - Event before-sign.s3.GetObject: calling handler <function _set_extra_headers_for_unsigned_request at 0x75526a70ca40>
# 2025-11-04 15:12:21 - botocore.hooks - DEBUG - Event before-sign.s3.GetObject: calling handler <bound method S3ExpressIdentityResolver.resolve_s3express_identity of <aiobotocore.utils.AioS3ExpressIdentityResolver object at 0x75532e4db980>>
# 2025-11-04 15:12:21 - botocore.hooks - DEBUG - Event request-created.s3.GetObject: calling handler <bound method UserAgentString.rebuild_and_replace_user_agent_handler of <botocore.useragent.UserAgentString object at 0x75532e4da690>>
# 2025-11-04 15:12:21 - botocore.hooks - DEBUG - Event request-created.s3.GetObject: calling handler <function add_retry_headers at 0x75526a70c220>
# 2025-11-04 15:12:21 - botocore.endpoint - DEBUG - Sending http request: <AWSPreparedRequest stream_output=True, method=GET, url=https://czi-variantformer.s3.amazonaws.com/alzheimer_disease/v4_pcg/ad/ENSG00000000457.13/model_tissue_22.tl, headers={'x-amz-checksum-mode': b'ENABLED', 'User-Agent': b'aiobotocore/2.25.1 md/Botocore#1.40.61 ua/2.1 os/linux#6.5.13-65-650-4141-22041-coreweave-amd64-85c45edc md/arch#x86_64 lang/python#3.12.10 md/pyimpl#CPython m/b,D,Z cfg/retry-mode#legacy botocore/1.40.61', 'amz-sdk-invocation-id': b'b7ca2a81-5878-4c74-9f4c-8adc72c6b7d6', 'amz-sdk-request': b'attempt=1'}>
# 2025-11-04 15:12:21 - botocore.hooks - DEBUG - Event before-parse.s3.GetObject: calling handler <function _handle_200_error at 0x75526a70c7c0>
# 2025-11-04 15:12:21 - botocore.hooks - DEBUG - Event before-parse.s3.GetObject: calling handler <function handle_expires_header at 0x75526a70c5e0>
# 2025-11-04 15:12:21 - botocore.parsers - DEBUG - Response headers: {'x-amz-id-2': 'Z9WGtYqlVbF6JP+mu5vKN5AeP07aW3FqdFtno1O5cbwmOFcHhOfT/mvQhf5ZsKr3sdVnv3aJXAk=', 'x-amz-request-id': 'XDZKQN2Y68F2GWCK', 'date': 'Tue, 04 Nov 2025 23:12:22 GMT', 'last-modified': 'Thu, 23 Oct 2025 19:36:24 GMT', 'etag': '"82a5a2b7a67357ccebbc953e3c77ea29"', 'x-amz-checksum-crc32': 'M5ZI1w==', 'x-amz-checksum-type': 'FULL_OBJECT', 'x-amz-server-side-encryption': 'AES256', 'x-amz-version-id': 'blxUC0IHpKMHkJkrktR7UHq.kon4eEuN', 'accept-ranges': 'bytes', 'content-type': 'binary/octet-stream', 'content-length': '658801', 'server': 'AmazonS3'}
# 2025-11-04 15:12:21 - botocore.parsers - DEBUG - Response body:
# <ClientResponse(https://czi-variantformer.s3.amazonaws.com/alzheimer_disease/v4_pcg/ad/ENSG00000000457.13/model_tissue_22.tl) [200 OK]>
# <CIMultiDictProxy('x-amz-id-2': 'Z9WGtYqlVbF6JP+mu5vKN5AeP07aW3FqdFtno1O5cbwmOFcHhOfT/mvQhf5ZsKr3sdVnv3aJXAk=', 'x-amz-request-id': 'XDZKQN2Y68F2GWCK', 'Date': 'Tue, 04 Nov 2025 23:12:22 GMT', 'Last-Modified': 'Thu, 23 Oct 2025 19:36:24 GMT', 'Etag': '"82a5a2b7a67357ccebbc953e3c77ea29"', 'x-amz-checksum-crc32': 'M5ZI1w==', 'x-amz-checksum-type': 'FULL_OBJECT', 'x-amz-server-side-encryption': 'AES256', 'x-amz-version-id': 'blxUC0IHpKMHkJkrktR7UHq.kon4eEuN', 'Accept-Ranges': 'bytes', 'Content-Type': 'binary/octet-stream', 'Content-Length': '658801', 'Server': 'AmazonS3')>
#
# 2025-11-04 15:12:21 - botocore.hooks - DEBUG - Event needs-retry.s3.GetObject: calling handler <function _update_status_code at 0x75526a70c900>
# 2025-11-04 15:12:21 - botocore.hooks - DEBUG - Event needs-retry.s3.GetObject: calling handler <aiobotocore.retryhandler.AioRetryHandler object at 0x75532e4db890>
# 2025-11-04 15:12:21 - botocore.retryhandler - DEBUG - No retry needed.
# 2025-11-04 15:12:21 - botocore.hooks - DEBUG - Event needs-retry.s3.GetObject: calling handler <bound method AioS3RegionRedirectorv2.redirect_from_error of <aiobotocore.utils.AioS3RegionRedirectorv2 object at 0x75532e4daff0>>
# 2025-11-04 15:12:21 - s3fs - DEBUG - CALL: head_object - ({},) - {'Bucket': 'czi-variantformer', 'Key': 'alzheimer_disease/v4_pcg/ad/ENSG00000000457.13/model_tissue_22.tl'}
# 2025-11-04 15:12:21 - botocore.hooks - DEBUG - Event before-parameter-build.s3.HeadObject: calling handler <function sse_md5 at 0x75526a73e020>
# 2025-11-04 15:12:21 - botocore.hooks - DEBUG - Event before-parameter-build.s3.HeadObject: calling handler <function validate_bucket_name at 0x75526a73df80>
# 2025-11-04 15:12:21 - botocore.hooks - DEBUG - Event before-parameter-build.s3.HeadObject: calling handler <function remove_bucket_from_url_paths_from_model at 0x75526a70c2c0>
# 2025-11-04 15:12:21 - botocore.hooks - DEBUG - Event before-parameter-build.s3.HeadObject: calling handler <bound method S3RegionRedirectorv2.annotate_request_context of <aiobotocore.utils.AioS3RegionRedirectorv2 object at 0x75532e4daff0>>
# 2025-11-04 15:12:21 - botocore.hooks - DEBUG - Event before-parameter-build.s3.HeadObject: calling handler <bound method ClientCreator._inject_s3_input_parameters of <aiobotocore.client.AioClientCreator object at 0x75532ee6d460>>
# 2025-11-04 15:12:21 - botocore.hooks - DEBUG - Event before-parameter-build.s3.HeadObject: calling handler <function generate_idempotent_uuid at 0x75526a73dda0>
# 2025-11-04 15:12:21 - botocore.hooks - DEBUG - Event before-parameter-build.s3.HeadObject: calling handler <function _handle_request_validation_mode_member at 0x75526a70c9a0>
# 2025-11-04 15:12:21 - botocore.hooks - DEBUG - Event before-endpoint-resolution.s3: calling handler <function customize_endpoint_resolver_builtins at 0x75526a70c4a0>
# 2025-11-04 15:12:21 - botocore.hooks - DEBUG - Event before-endpoint-resolution.s3: calling handler <bound method S3RegionRedirectorv2.redirect_from_cache of <aiobotocore.utils.AioS3RegionRedirectorv2 object at 0x75532e4daff0>>
# 2025-11-04 15:12:21 - aiobotocore.regions - DEBUG - Calling endpoint provider with parameters: {'Bucket': 'czi-variantformer', 'Region': 'us-east-1', 'UseFIPS': False, 'UseDualStack': False, 'ForcePathStyle': False, 'Accelerate': False, 'UseGlobalEndpoint': True, 'Key': 'alzheimer_disease/v4_pcg/ad/ENSG00000000457.13/model_tissue_22.tl', 'DisableMultiRegionAccessPoints': False, 'UseArnRegion': True}
# 2025-11-04 15:12:21 - aiobotocore.regions - DEBUG - Endpoint provider result: https://czi-variantformer.s3.amazonaws.com
# 2025-11-04 15:12:21 - botocore.regions - DEBUG - Selecting from endpoint provider's list of auth schemes: "sigv4". User selected auth scheme is: "<botocore.UNSIGNED object at 0x7553328937d0>"
# 2025-11-04 15:12:21 - botocore.hooks - DEBUG - Event before-call.s3.HeadObject: calling handler <function add_expect_header at 0x75526a73e340>
# 2025-11-04 15:12:21 - botocore.hooks - DEBUG - Event before-call.s3.HeadObject: calling handler <bound method S3ExpressIdentityResolver.apply_signing_cache_key of <aiobotocore.utils.AioS3ExpressIdentityResolver object at 0x75532e4db980>>
# 2025-11-04 15:12:21 - botocore.hooks - DEBUG - Event before-call.s3.HeadObject: calling handler <function add_recursion_detection_header at 0x75526a73c720>
# 2025-11-04 15:12:21 - botocore.hooks - DEBUG - Event before-call.s3.HeadObject: calling handler <function inject_api_version_header_if_needed at 0x75526a73f880>
# 2025-11-04 15:12:21 - botocore.endpoint - DEBUG - Making request for OperationModel(name=HeadObject) with params: {'url_path': '/alzheimer_disease/v4_pcg/ad/ENSG00000000457.13/model_tissue_22.tl', 'query_string': {}, 'method': 'HEAD', 'headers': {'User-Agent': 'aiobotocore/2.25.1 md/Botocore#1.40.61 ua/2.1 os/linux#6.5.13-65-650-4141-22041-coreweave-amd64-85c45edc md/arch#x86_64 lang/python#3.12.10 md/pyimpl#CPython m/b,D,Z cfg/retry-mode#legacy botocore/1.40.61'}, 'body': b'', 'auth_path': '/czi-variantformer/alzheimer_disease/v4_pcg/ad/ENSG00000000457.13/model_tissue_22.tl', 'url': 'https://czi-variantformer.s3.amazonaws.com/alzheimer_disease/v4_pcg/ad/ENSG00000000457.13/model_tissue_22.tl', 'context': {'client_region': 'us-east-1', 'client_config': <aiobotocore.config.AioConfig object at 0x754fa80d4680>, 'has_streaming_input': False, 'auth_type': 'none', 'unsigned_payload': None, 'auth_options': ['aws.auth#sigv4'], 's3_redirect': {'redirected': False, 'bucket': 'czi-variantformer', 'params': {'Bucket': 'czi-variantformer', 'Key': 'alzheimer_disease/v4_pcg/ad/ENSG00000000457.13/model_tissue_22.tl'}}, 'input_params': {'Bucket': 'czi-variantformer', 'Key': 'alzheimer_disease/v4_pcg/ad/ENSG00000000457.13/model_tissue_22.tl'}, 'signing': {}, 'endpoint_properties': {'authSchemes': [{'disableDoubleEncoding': True, 'name': 'sigv4', 'signingName': 's3', 'signingRegion': 'us-east-1'}]}}}
# 2025-11-04 15:12:21 - botocore.hooks - DEBUG - Event request-created.s3.HeadObject: calling handler <bound method AioRequestSigner.handler of <aiobotocore.signers.AioRequestSigner object at 0x75532f03bb30>>
# 2025-11-04 15:12:21 - botocore.hooks - DEBUG - Event choose-signer.s3.HeadObject: calling handler <function set_operation_specific_signer at 0x75526a73db20>
# 2025-11-04 15:12:21 - botocore.hooks - DEBUG - Event before-sign.s3.HeadObject: calling handler <function remove_arn_from_signing_path at 0x75526a70c400>
# 2025-11-04 15:12:21 - botocore.hooks - DEBUG - Event before-sign.s3.HeadObject: calling handler <function _set_extra_headers_for_unsigned_request at 0x75526a70ca40>
# 2025-11-04 15:12:21 - botocore.hooks - DEBUG - Event before-sign.s3.HeadObject: calling handler <bound method S3ExpressIdentityResolver.resolve_s3express_identity of <aiobotocore.utils.AioS3ExpressIdentityResolver object at 0x75532e4db980>>
# 2025-11-04 15:12:21 - botocore.hooks - DEBUG - Event request-created.s3.HeadObject: calling handler <bound method UserAgentString.rebuild_and_replace_user_agent_handler of <botocore.useragent.UserAgentString object at 0x75532e4da690>>
# 2025-11-04 15:12:21 - botocore.hooks - DEBUG - Event request-created.s3.HeadObject: calling handler <function add_retry_headers at 0x75526a70c220>
# 2025-11-04 15:12:21 - botocore.endpoint - DEBUG - Sending http request: <AWSPreparedRequest stream_output=False, method=HEAD, url=https://czi-variantformer.s3.amazonaws.com/alzheimer_disease/v4_pcg/ad/ENSG00000000457.13/model_tissue_22.tl, headers={'User-Agent': b'aiobotocore/2.25.1 md/Botocore#1.40.61 ua/2.1 os/linux#6.5.13-65-650-4141-22041-coreweave-amd64-85c45edc md/arch#x86_64 lang/python#3.12.10 md/pyimpl#CPython m/b,D,Z cfg/retry-mode#legacy botocore/1.40.61', 'amz-sdk-invocation-id': b'ad0e4f39-adbc-4d62-84fc-fe657a18a2e0', 'amz-sdk-request': b'attempt=1'}>
# 2025-11-04 15:12:21 - botocore.hooks - DEBUG - Event before-parse.s3.HeadObject: calling handler <function _handle_200_error at 0x75526a70c7c0>
# 2025-11-04 15:12:21 - botocore.hooks - DEBUG - Event before-parse.s3.HeadObject: calling handler <function handle_expires_header at 0x75526a70c5e0>
# 2025-11-04 15:12:21 - botocore.parsers - DEBUG - Response headers: {'x-amz-id-2': '+2mDV4w/ri7+MyjKFlknjntGmgDgzoxlQ6aeFf0aehVtJlbiVljCVMW5p1ubWU9ciW1MAO8Yzis=', 'x-amz-request-id': 'XDZZ1Y44SQ08RZTV', 'date': 'Tue, 04 Nov 2025 23:12:22 GMT', 'last-modified': 'Thu, 23 Oct 2025 19:36:24 GMT', 'etag': '"82a5a2b7a67357ccebbc953e3c77ea29"', 'x-amz-server-side-encryption': 'AES256', 'x-amz-version-id': 'blxUC0IHpKMHkJkrktR7UHq.kon4eEuN', 'accept-ranges': 'bytes', 'content-type': 'binary/octet-stream', 'content-length': '658801', 'server': 'AmazonS3'}
# 2025-11-04 15:12:21 - botocore.parsers - DEBUG - Response body:
# b''
# 2025-11-04 15:12:21 - botocore.hooks - DEBUG - Event needs-retry.s3.HeadObject: calling handler <function _update_status_code at 0x75526a70c900>
# 2025-11-04 15:12:21 - botocore.hooks - DEBUG - Event needs-retry.s3.HeadObject: calling handler <aiobotocore.retryhandler.AioRetryHandler object at 0x75532e4db890>
# 2025-11-04 15:12:21 - botocore.retryhandler - DEBUG - No retry needed.
# 2025-11-04 15:12:21 - botocore.hooks - DEBUG - Event needs-retry.s3.HeadObject: calling handler <bound method AioS3RegionRedirectorv2.redirect_from_error of <aiobotocore.utils.AioS3RegionRedirectorv2 object at 0x75532e4daff0>>
# 2025-11-04 15:12:21 - filelock - DEBUG - Attempting to release lock 129002801060928 on /work/_artifacts/alzheimer_disease/v4_pcg/ad/ENSG00000000457.13/model_tissue_22.tl.lock
# 2025-11-04 15:12:21 - filelock - DEBUG - Lock 129002801060928 released on /work/_artifacts/alzheimer_disease/v4_pcg/ad/ENSG00000000457.13/model_tissue_22.tl.lock

# %% [markdown]
# ## 7. View Results
#
# Output DataFrame contains gene IDs/names, tissue IDs/names, and AD risk scores.

# %%
# Print predictions
preds
# Out:
#               gene_id  tissue_id          tissue_name  predicted_expression  \
# 0  ENSG00000000419.12         20       brain - cortex              3.242956
# 1  ENSG00000000457.13         22  brain - hippocampus              1.025923
#
#                                            embedding  ad_risk gene_name
# 0  [[8.6875, -1.0078125, 0.7421875, 1.125, 16.75,...    0.574      DPM1
# 1  [[-9.75, -0.71875, -2.96875, -5.28125, -2.1562...    0.820     SCYL3

# %% [markdown]
# ## 8. Visualize Results
#
# Interactive bar chart showing AD risk predictions across tissues.

# %%
# Visualize predictions
fig = px.bar(
    preds, x="tissue_name", y="ad_risk", title="AD Risk Predictions across Tissues"
)
fig.show()
