# %% [markdown]
# # VCF to Gene Expression Prediction
#
# This notebook demonstrates how to use the VariantFormer VCFProcessor to predict gene expression from VCF (Variant Call Format) files. The VCFProcessor leverages a transformer model to predict gene expression levels based on genetic variants and tissue types.
#
# ## Overview
#
# The VariantFormer pipeline can:
# - Process VCF files containing genetic variants
# - Predict gene expression levels for specific genes and tissues
# - Generate embeddings for specific genes
# - Handle multiple tissues and genes in a single analysis
#
# ## Prerequisites
#
# - GPU-enabled environment (CUDA required)
# - Access to reference genome and model checkpoints (run `python download_artifacts.py` before running the notebook)
# - VCF files with genetic variants
#
# ## Key Outputs:
#
# - **Gene Expression Predictions**: Quantitative predictions of expression levels
# - **Embeddings**: Embedding for each gene-tissue pair

# %%
import sys
import os
from pathlib import Path
import ipynbname
import pandas as pd
from processors.vcfprocessor import VCFProcessor
import warnings
 
# Check GPU availability
import torch

if torch.cuda.is_available():
    print(f"🚀 GPU available: {torch.cuda.get_device_name(0)}")
    print(
        f"💾 GPU memory: {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f} GB"
    )
else:
    print("⚠️  No GPU available - this notebook requires CUDA")

# Set repository path
REPO_PATH = ipynbname.path().parent.parent
# Out:
# 2025-11-04 15:09:07 - matplotlib - DEBUG - matplotlib data path: /work/.venv/lib/python3.12/site-packages/matplotlib/mpl-data
# 2025-11-04 15:09:07 - matplotlib - DEBUG - CONFIGDIR=/flow/.config/matplotlib
# 2025-11-04 15:09:07 - matplotlib - DEBUG - interactive is False
# 2025-11-04 15:09:07 - matplotlib - DEBUG - platform is linux
# 2025-11-04 15:09:08 - matplotlib - DEBUG - CACHEDIR=/flow/.cache/matplotlib
# 2025-11-04 15:09:08 - matplotlib.font_manager - DEBUG - Using fontManager instance from /flow/.cache/matplotlib/fontlist-v390.json
# 🚀 GPU available: NVIDIA H100 80GB HBM3
# 💾 GPU memory: 84.9 GB

# %% [markdown]
# ## 1. Initialize VCFProcessor
#
# The VCFProcessor is the main class that handles:
# - Loading model configurations
# - Managing tissue and gene vocabularies
# - Creating data loaders for VCF files
# - Loading pre-trained models (v4_pcg, v4_ag)
# - Running predictions
#
# Let's initialize it with the default VariantFormer protein-coding gene (PCG) model.

# %%
# Initialize the VCFProcessor with the default v4_PCG model
model_class = "v4_ag" # You can also use "v4_ag" for protein-coding genes
#model_class = "v4_pcg"  # Uncomment to use the protein-coding gene model
vcf_processor = VCFProcessor(model_class=model_class)

print(f"📊 Model class: {model_class}")
print(f"⚙️  Configuration loaded from: {vcf_processor.config_location}")
# Out:
# 📊 Model class: v4_ag
# ⚙️  Configuration loaded from: /work/configs

# %% [markdown]
# ## 2. Explore Available Tissues and Genes
#
# Before making predictions, let's explore what tissues and genes are available in the system. This will help us understand the scope of the model and choose appropriate targets for our analysis.

# %%
# Get available tissues
tissues = vcf_processor.get_tissues()
print(f"🧪 Available tissues ({len(tissues)} total):")
print("=" * 50)
print("First 10 tissues in the dataset:")
for i, tissue in enumerate(tissues, 1):
    print(f"{i:2d}. {tissue}")
    if i == 10:
        break

print("\n" + "=" * 70)

# Get available genes
genes_df = vcf_processor.get_genes()
print(f"🧬 Available genes ({len(genes_df)} total):")
print("=" * 50)
print("First 10 genes in the dataset:")
print(genes_df[["gene_id", "gene_name"]].head(10).to_string(index=False))

print("\n📊 Gene statistics:")
print(f"   • Total genes: {len(genes_df):,}")
# Out:
# 🧪 Available tissues (62 total):
# ==================================================
# First 10 tissues in the dataset:
#  1. A549
#  2. GM23248
#  3. HepG2
#  4. K562
#  5. NCI-H460
#  6. Panc1
#  7. adipose - subcutaneous
#  8. adipose - visceral (omentum)
#  9. adrenal gland
# 10. artery - aorta
#
# ======================================================================
# 🧬 Available genes (51061 total):
# ==================================================
# First 10 genes in the dataset:
#            gene_id gene_name
# ENSG00000000419.12      DPM1
# ENSG00000000457.13     SCYL3
# ENSG00000000460.16  C1orf112
# ENSG00000000938.12       FGR
# ENSG00000000971.15       CFH
# ENSG00000001036.13     FUCA2
# ENSG00000001084.10      GCLC
# ENSG00000001167.14      NFYA
# ENSG00000001460.17     STPG1
# ENSG00000001461.16    NIPAL3
#
# 📊 Gene statistics:
#    • Total genes: 51,061

# %% [markdown]
# ## 3. Prepare Query Data
#
# Now we'll prepare our query data, which specifies:
# - **gene_id**: Which genes we want to predict expression for
# - **tissues**: Which tissues/cell types we're interested in
#
# For this demo, we'll use the same example as in the test function, but let's also prepare a more diverse example.

# %%
# Example 1: Simple query
'''
General format for queries:
simple_query = {
    "gene_id": [gene ID],
    "tissues": [Comma separated tissue names],
}
'''
simple_query = {
    "gene_id": ["ENSG00000001461.16", "ENSG00000000419.12"],
    "tissues": ["whole blood,thyroid,artery - aorta", "brain - amygdala"],
} 
query_df = pd.DataFrame(simple_query)
print("🔍 Simple Query DataFrame:")
print(query_df.to_string(index=False))
# Out:
# 🔍 Simple Query DataFrame:
#            gene_id                            tissues
# ENSG00000001461.16 whole blood,thyroid,artery - aorta
# ENSG00000000419.12                   brain - amygdala

# %% [markdown]
# ## 4. Specify VCF File and Create Dataset
#
# Now we need to specify the path to our VCF file containing genetic variants. The VCFProcessor will:
# - Load the VCF file and extract relevant variants
# - Map variants to regulatory regions (CREs) and genes
# - Create sequence data for model input
# - Prepare batches for efficient processing
#
# **Note**: Update the `vcf_path` below to point to your actual VCF file.

# %%
# Specify VCF file path (update this path to your actual VCF file)
vcf_path = os.path.join(REPO_PATH, "_artifacts/HG00096.vcf.gz")
# Create data loader from VCF and query
vcf_dataset, dataloader = vcf_processor.create_data(vcf_path, query_df)
# Out:
# Loaded BPE vocabulary from /work/vocabs/bpe_vocabulary_500.json
# Filtered query df to 2 genes reducing from 2

# %%
import time

print("🔄 Loading pre-trained model...")
start_time = time.time()


model, checkpoint_path, trainer = vcf_processor.load_model()

load_time = time.time() - start_time
print(f"📂 Checkpoint path: {checkpoint_path}")
print(f"⚡ Precision: {trainer.precision}")

# Print model information
total_params = sum(p.numel() for p in model.parameters())

print("\n📊 Model Statistics:")
print(f"   • Total parameters: {total_params:,}")
# Out:
# 2025-11-04 15:09:21 - processors.model_manager - INFO - Loading Seq2Reg model...
# 🔄 Loading pre-trained model...
# 2025-11-04 15:09:22 - processors.model_manager - INFO - Loading Seq2Reg gene model...
# 2025-11-04 15:09:22 - processors.model_manager - INFO - Creating Seq2Gene model...
# 2025-11-04 15:09:28 - processors.model_manager - INFO - Model class: <class 'seq2gene.model_combined_modulator.Seq2GenePredictorCombinedModulator'>
# 2025-11-04 15:09:28 - processors.model_manager - INFO - Model architecture:
# 2025-11-04 15:09:28 - processors.model_manager - INFO - Model: Seq2GenePredictorCombinedModulator
# 2025-11-04 15:09:28 - processors.model_manager - INFO -   start_tkn: 96,768 params
# 2025-11-04 15:09:28 - processors.model_manager - INFO -   cre_tokenizer: 31,826,153 params
# 2025-11-04 15:09:28 - processors.model_manager - INFO -   gene_tokenizer: 31,826,153 params
# 2025-11-04 15:09:28 - processors.model_manager - INFO -   gene_map: 787,968 params
# 2025-11-04 15:09:28 - processors.model_manager - INFO -   cre_map: 787,968 params
# 2025-11-04 15:09:28 - processors.model_manager - INFO -   combined_modulator: 1,157,298,176 params
# 2025-11-04 15:09:28 - processors.model_manager - INFO -   tissue_heads: 4,726,273 params
# 2025-11-04 15:09:28 - processors.model_manager - INFO -   gene_loss: 0 params
# 2025-11-04 15:09:28 - processors.model_manager - INFO - Total number of parameters: 1,227,349,459
# 2025-11-04 15:09:28 - processors.model_manager - INFO - Loading checkpoint from /work/_artifacts/v4_ag_epoch9_checkpoint.pth
# 2025-11-04 15:09:32 - processors.model_manager - INFO - Model loaded successfully on cuda
# INFO: Using bfloat16 Automatic Mixed Precision (AMP)
# 2025-11-04 15:09:32 - lightning.pytorch.utilities.rank_zero - INFO - Using bfloat16 Automatic Mixed Precision (AMP)
# INFO: GPU available: True (cuda), used: True
# 2025-11-04 15:09:32 - lightning.pytorch.utilities.rank_zero - INFO - GPU available: True (cuda), used: True
# INFO: TPU available: False, using: 0 TPU cores
# 2025-11-04 15:09:32 - lightning.pytorch.utilities.rank_zero - INFO - TPU available: False, using: 0 TPU cores
# INFO: HPU available: False, using: 0 HPUs
# 2025-11-04 15:09:32 - lightning.pytorch.utilities.rank_zero - INFO - HPU available: False, using: 0 HPUs
# 📂 Checkpoint path: /work/_artifacts/v4_ag_epoch9_checkpoint.pth
# ⚡ Precision: bf16-mixed
#
# 📊 Model Statistics:
#    • Total parameters: 1,227,349,459

# %% [markdown]
# ## 6. Run Predictions
#
# Now we're ready to run the actual predictions! The model will:
# - Process the genetic variants
# - Generate embeddings that capture gene representation
# - Predict gene expression levels for each gene-tissue combination
#
# This step may take some time depending on the size of your VCF file and the complexity of your queries. Prune the VCF files to remove all ref variant which will improve speed.

# %%
print("🔄 Running predictions...")

start_time = time.time()

# Run predictions
predictions_df = vcf_processor.predict(
    model, checkpoint_path, trainer, dataloader, vcf_dataset
)

prediction_time = time.time() - start_time
print(f"✅ Predictions completed in {prediction_time:.1f} seconds!")
print(f"📊 Results shape: {predictions_df.shape}")
# Out:
# INFO: Restoring states from the checkpoint path at /work/_artifacts/v4_ag_epoch9_checkpoint.pth
# 2025-11-04 15:09:54 - lightning.pytorch.utilities.rank_zero - INFO - Restoring states from the checkpoint path at /work/_artifacts/v4_ag_epoch9_checkpoint.pth
# 2025-11-04 15:09:54 - fsspec.local - DEBUG - open file: /work/_artifacts/v4_ag_epoch9_checkpoint.pth
# 🔄 Running predictions...
# /work/.venv/lib/python3.12/site-packages/lightning/pytorch/trainer/call.py:283: Be aware that when using `ckpt_path`, callbacks used to create the checkpoint need to be provided during `Trainer` instantiation. Please add the following callbacks: ["ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}"].
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# 2025-11-04 15:10:01 - lightning.pytorch.accelerators.cuda - INFO - LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO: Loaded model weights from the checkpoint at /work/_artifacts/v4_ag_epoch9_checkpoint.pth
# 2025-11-04 15:10:01 - lightning.pytorch.utilities.rank_zero - INFO - Loaded model weights from the checkpoint at /work/_artifacts/v4_ag_epoch9_checkpoint.pth
# Predicting: |          | 0/? [00:00<?, ?it/s]
# 2025-11-04 15:10:02 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/cres_all_genes_manifest.parquet
# 2025-11-04 15:10:02 - utils.assets - INFO - Loading parquet file: /work/_artifacts/model/common/cres_all_genes_manifest.parquet
# 2025-11-04 15:10:02 - utils.assets - INFO - Validated schema - found columns: {'gene_id', 'file_path'}
# 2025-11-04 15:10:02 - filelock - DEBUG - Attempting to acquire lock 139332232152368 on /work/_artifacts/model/common/cres_all_genes/ENSG00000001461.16/gene_vocab.csv.lock
# 2025-11-04 15:10:02 - filelock - DEBUG - Lock 139332232152368 acquired on /work/_artifacts/model/common/cres_all_genes/ENSG00000001461.16/gene_vocab.csv.lock
# 2025-11-04 15:10:02 - asyncio - DEBUG - Using selector: EpollSelector
# 2025-11-04 15:10:02 - s3fs - DEBUG - Setting up s3fs instance
# 2025-11-04 15:10:02 - botocore.hooks - DEBUG - Changing event name from creating-client-class.iot-data to creating-client-class.iot-data-plane
# 2025-11-04 15:10:02 - botocore.hooks - DEBUG - Changing event name from before-call.apigateway to before-call.api-gateway
# 2025-11-04 15:10:02 - botocore.hooks - DEBUG - Changing event name from request-created.machinelearning.Predict to request-created.machine-learning.Predict
# 2025-11-04 15:10:02 - botocore.hooks - DEBUG - Changing event name from before-parameter-build.autoscaling.CreateLaunchConfiguration to before-parameter-build.auto-scaling.CreateLaunchConfiguration
# 2025-11-04 15:10:02 - botocore.hooks - DEBUG - Changing event name from before-parameter-build.route53 to before-parameter-build.route-53
# 2025-11-04 15:10:02 - botocore.hooks - DEBUG - Changing event name from request-created.cloudsearchdomain.Search to request-created.cloudsearch-domain.Search
# 2025-11-04 15:10:02 - botocore.hooks - DEBUG - Changing event name from docs.*.autoscaling.CreateLaunchConfiguration.complete-section to docs.*.auto-scaling.CreateLaunchConfiguration.complete-section
# 2025-11-04 15:10:02 - botocore.hooks - DEBUG - Changing event name from before-parameter-build.logs.CreateExportTask to before-parameter-build.cloudwatch-logs.CreateExportTask
# 2025-11-04 15:10:02 - botocore.hooks - DEBUG - Changing event name from docs.*.logs.CreateExportTask.complete-section to docs.*.cloudwatch-logs.CreateExportTask.complete-section
# 2025-11-04 15:10:02 - botocore.hooks - DEBUG - Changing event name from before-parameter-build.cloudsearchdomain.Search to before-parameter-build.cloudsearch-domain.Search
# 2025-11-04 15:10:02 - botocore.hooks - DEBUG - Changing event name from docs.*.cloudsearchdomain.Search.complete-section to docs.*.cloudsearch-domain.Search.complete-section
# 2025-11-04 15:10:02 - s3fs - DEBUG - RC: caching enabled? False (explicit option is False)
# 2025-11-04 15:10:02 - botocore.loaders - DEBUG - Loading JSON file: /work/.venv/lib/python3.12/site-packages/botocore/data/endpoints.json
# 2025-11-04 15:10:02 - botocore.loaders - DEBUG - Loading JSON file: /work/.venv/lib/python3.12/site-packages/botocore/data/sdk-default-configuration.json
# 2025-11-04 15:10:02 - botocore.hooks - DEBUG - Event choose-service-name: calling handler <function handle_service_name_alias at 0x7eb8d0324ea0>
# 2025-11-04 15:10:02 - botocore.loaders - DEBUG - Loading JSON file: /work/.venv/lib/python3.12/site-packages/botocore/data/s3/2006-03-01/service-2.json.gz
# 2025-11-04 15:10:02 - botocore.loaders - DEBUG - Loading JSON file: /work/.venv/lib/python3.12/site-packages/botocore/data/s3/2006-03-01/service-2.sdk-extras.json
# 2025-11-04 15:10:02 - botocore.loaders - DEBUG - Loading JSON file: /work/.venv/lib/python3.12/site-packages/botocore/data/s3/2006-03-01/endpoint-rule-set-1.json.gz
# 2025-11-04 15:10:02 - botocore.loaders - DEBUG - Loading JSON file: /work/.venv/lib/python3.12/site-packages/botocore/data/partitions.json
# 2025-11-04 15:10:02 - botocore.hooks - DEBUG - Event creating-client-class.s3: calling handler <function add_generate_presigned_post at 0x7ebde7e09ee0>
# 2025-11-04 15:10:02 - botocore.hooks - DEBUG - Event creating-client-class.s3: calling handler <function add_generate_presigned_url at 0x7ebde7e09c60>
# 2025-11-04 15:10:02 - botocore.configprovider - DEBUG - Looking for endpoint for s3 via: environment_service
# 2025-11-04 15:10:02 - botocore.configprovider - DEBUG - Looking for endpoint for s3 via: environment_global
# 2025-11-04 15:10:02 - botocore.configprovider - DEBUG - Looking for endpoint for s3 via: config_service
# 2025-11-04 15:10:02 - botocore.configprovider - DEBUG - Looking for endpoint for s3 via: config_global
# 2025-11-04 15:10:02 - botocore.configprovider - DEBUG - No configured endpoint found.
# 2025-11-04 15:10:02 - botocore.endpoint - DEBUG - Setting s3 timeout as (5, 15)
# 2025-11-04 15:10:02 - botocore.loaders - DEBUG - Loading JSON file: /work/.venv/lib/python3.12/site-packages/botocore/data/_retry.json
# 2025-11-04 15:10:02 - botocore.client - DEBUG - Registering retry handlers for service: s3
# 2025-11-04 15:10:02 - botocore.utils - DEBUG - Registering S3 region redirector handler
# 2025-11-04 15:10:02 - botocore.utils - DEBUG - Registering S3Express Identity Resolver
# 2025-11-04 15:10:02 - s3fs - DEBUG - CALL: get_object - () - {'Bucket': 'czi-variantformer', 'Key': 'model/common/cres_all_genes/ENSG00000001461.16/gene_vocab.csv'}
# 2025-11-04 15:10:02 - botocore.hooks - DEBUG - Event before-parameter-build.s3.GetObject: calling handler <function sse_md5 at 0x7eb8d035bec0>
# 2025-11-04 15:10:02 - botocore.hooks - DEBUG - Event before-parameter-build.s3.GetObject: calling handler <function validate_bucket_name at 0x7eb8d035be20>
# 2025-11-04 15:10:02 - botocore.hooks - DEBUG - Event before-parameter-build.s3.GetObject: calling handler <function remove_bucket_from_url_paths_from_model at 0x7eb8d039e160>
# 2025-11-04 15:10:02 - botocore.hooks - DEBUG - Event before-parameter-build.s3.GetObject: calling handler <bound method S3RegionRedirectorv2.annotate_request_context of <aiobotocore.utils.AioS3RegionRedirectorv2 object at 0x7ebde6abdc40>>
# 2025-11-04 15:10:02 - botocore.hooks - DEBUG - Event before-parameter-build.s3.GetObject: calling handler <bound method ClientCreator._inject_s3_input_parameters of <aiobotocore.client.AioClientCreator object at 0x7eb8d03771a0>>
# 2025-11-04 15:10:02 - botocore.hooks - DEBUG - Event before-parameter-build.s3.GetObject: calling handler <function generate_idempotent_uuid at 0x7eb8d035bc40>
# 2025-11-04 15:10:02 - botocore.hooks - DEBUG - Event before-parameter-build.s3.GetObject: calling handler <function _handle_request_validation_mode_member at 0x7eb8d039e840>
# 2025-11-04 15:10:02 - botocore.hooks - DEBUG - Event before-endpoint-resolution.s3: calling handler <function customize_endpoint_resolver_builtins at 0x7eb8d039e340>
# 2025-11-04 15:10:02 - botocore.hooks - DEBUG - Event before-endpoint-resolution.s3: calling handler <bound method S3RegionRedirectorv2.redirect_from_cache of <aiobotocore.utils.AioS3RegionRedirectorv2 object at 0x7ebde6abdc40>>
# 2025-11-04 15:10:02 - aiobotocore.regions - DEBUG - Calling endpoint provider with parameters: {'Bucket': 'czi-variantformer', 'Region': 'us-east-1', 'UseFIPS': False, 'UseDualStack': False, 'ForcePathStyle': False, 'Accelerate': False, 'UseGlobalEndpoint': True, 'Key': 'model/common/cres_all_genes/ENSG00000001461.16/gene_vocab.csv', 'DisableMultiRegionAccessPoints': False, 'UseArnRegion': True}
# 2025-11-04 15:10:02 - aiobotocore.regions - DEBUG - Endpoint provider result: https://czi-variantformer.s3.amazonaws.com
# 2025-11-04 15:10:02 - botocore.regions - DEBUG - Selecting from endpoint provider's list of auth schemes: "sigv4". User selected auth scheme is: "<botocore.UNSIGNED object at 0x7eb8d03722a0>"
# 2025-11-04 15:10:02 - botocore.hooks - DEBUG - Event before-call.s3.GetObject: calling handler <function add_expect_header at 0x7eb8d039c220>
# 2025-11-04 15:10:02 - botocore.hooks - DEBUG - Event before-call.s3.GetObject: calling handler <bound method S3ExpressIdentityResolver.apply_signing_cache_key of <aiobotocore.utils.AioS3ExpressIdentityResolver object at 0x7eb951cc3500>>
# 2025-11-04 15:10:02 - botocore.hooks - DEBUG - Event before-call.s3.GetObject: calling handler <function add_recursion_detection_header at 0x7eb8d035a340>
# 2025-11-04 15:10:02 - botocore.hooks - DEBUG - Event before-call.s3.GetObject: calling handler <function inject_api_version_header_if_needed at 0x7eb8d039d760>
# 2025-11-04 15:10:02 - botocore.endpoint - DEBUG - Making request for OperationModel(name=GetObject) with params: {'url_path': '/model/common/cres_all_genes/ENSG00000001461.16/gene_vocab.csv', 'query_string': {}, 'method': 'GET', 'headers': {'x-amz-checksum-mode': 'ENABLED', 'User-Agent': 'aiobotocore/2.25.1 md/Botocore#1.40.61 ua/2.1 os/linux#6.5.13-65-650-4141-22041-coreweave-amd64-85c45edc md/arch#x86_64 lang/python#3.12.10 md/pyimpl#CPython m/Z,b,D cfg/retry-mode#legacy botocore/1.40.61'}, 'body': b'', 'auth_path': '/czi-variantformer/model/common/cres_all_genes/ENSG00000001461.16/gene_vocab.csv', 'url': 'https://czi-variantformer.s3.amazonaws.com/model/common/cres_all_genes/ENSG00000001461.16/gene_vocab.csv', 'context': {'client_region': 'us-east-1', 'client_config': <aiobotocore.config.AioConfig object at 0x7eb9524e1670>, 'has_streaming_input': False, 'auth_type': 'none', 'unsigned_payload': None, 'auth_options': ['aws.auth#sigv4'], 's3_redirect': {'redirected': False, 'bucket': 'czi-variantformer', 'params': {'Bucket': 'czi-variantformer', 'Key': 'model/common/cres_all_genes/ENSG00000001461.16/gene_vocab.csv', 'ChecksumMode': 'ENABLED'}}, 'input_params': {'Bucket': 'czi-variantformer', 'Key': 'model/common/cres_all_genes/ENSG00000001461.16/gene_vocab.csv'}, 'signing': {}, 'endpoint_properties': {'authSchemes': [{'disableDoubleEncoding': True, 'name': 'sigv4', 'signingName': 's3', 'signingRegion': 'us-east-1'}]}, 'checksum': {'response_algorithms': ['crc32', 'sha1', 'sha256']}}}
# 2025-11-04 15:10:02 - botocore.hooks - DEBUG - Event request-created.s3.GetObject: calling handler <bound method AioRequestSigner.handler of <aiobotocore.signers.AioRequestSigner object at 0x7eb8d02a7560>>
# 2025-11-04 15:10:02 - botocore.hooks - DEBUG - Event choose-signer.s3.GetObject: calling handler <function set_operation_specific_signer at 0x7eb8d035b9c0>
# 2025-11-04 15:10:02 - botocore.hooks - DEBUG - Event before-sign.s3.GetObject: calling handler <function remove_arn_from_signing_path at 0x7eb8d039e2a0>
# 2025-11-04 15:10:02 - botocore.hooks - DEBUG - Event before-sign.s3.GetObject: calling handler <function _set_extra_headers_for_unsigned_request at 0x7eb8d039e8e0>
# 2025-11-04 15:10:02 - botocore.hooks - DEBUG - Event before-sign.s3.GetObject: calling handler <bound method S3ExpressIdentityResolver.resolve_s3express_identity of <aiobotocore.utils.AioS3ExpressIdentityResolver object at 0x7eb951cc3500>>
# 2025-11-04 15:10:02 - botocore.hooks - DEBUG - Event request-created.s3.GetObject: calling handler <bound method UserAgentString.rebuild_and_replace_user_agent_handler of <botocore.useragent.UserAgentString object at 0x7ebde6abdbe0>>
# 2025-11-04 15:10:02 - botocore.hooks - DEBUG - Event request-created.s3.GetObject: calling handler <function add_retry_headers at 0x7eb8d039e0c0>
# 2025-11-04 15:10:02 - botocore.endpoint - DEBUG - Sending http request: <AWSPreparedRequest stream_output=True, method=GET, url=https://czi-variantformer.s3.amazonaws.com/model/common/cres_all_genes/ENSG00000001461.16/gene_vocab.csv, headers={'x-amz-checksum-mode': b'ENABLED', 'User-Agent': b'aiobotocore/2.25.1 md/Botocore#1.40.61 ua/2.1 os/linux#6.5.13-65-650-4141-22041-coreweave-amd64-85c45edc md/arch#x86_64 lang/python#3.12.10 md/pyimpl#CPython m/Z,b,D cfg/retry-mode#legacy botocore/1.40.61', 'amz-sdk-invocation-id': b'5f167ac9-b97f-4773-9e08-0045edb71d9e', 'amz-sdk-request': b'attempt=1'}>
# 2025-11-04 15:10:02 - botocore.httpsession - DEBUG - Certificate path: /work/.venv/lib/python3.12/site-packages/certifi/cacert.pem
# 2025-11-04 15:10:03 - botocore.hooks - DEBUG - Event before-parse.s3.GetObject: calling handler <function _handle_200_error at 0x7eb8d039e660>
# 2025-11-04 15:10:03 - botocore.hooks - DEBUG - Event before-parse.s3.GetObject: calling handler <function handle_expires_header at 0x7eb8d039e480>
# 2025-11-04 15:10:03 - botocore.parsers - DEBUG - Response headers: {'x-amz-id-2': 'ALvyq4/oejyGLa78AU6p6SQ/25hxIdqFV6HAwasTHG5Rn99Hccp0OgX+aePESHfEYsnLJN7lYOE=', 'x-amz-request-id': 'J4SJK4Y1WM6AEVBP', 'date': 'Tue, 04 Nov 2025 23:10:04 GMT', 'last-modified': 'Thu, 23 Oct 2025 22:52:46 GMT', 'etag': '"acc59765e38068a8d715b04dc9c7ac0e"', 'x-amz-checksum-crc32': 'YVjHJg==', 'x-amz-checksum-type': 'FULL_OBJECT', 'x-amz-server-side-encryption': 'AES256', 'x-amz-version-id': 't1FixK2cx7KMhtJZ.mQCM2jLKhwFpmRh', 'accept-ranges': 'bytes', 'content-type': 'binary/octet-stream', 'content-length': '3926886', 'server': 'AmazonS3'}
# 2025-11-04 15:10:03 - botocore.parsers - DEBUG - Response body:
# <ClientResponse(https://czi-variantformer.s3.amazonaws.com/model/common/cres_all_genes/ENSG00000001461.16/gene_vocab.csv) [200 OK]>
# <CIMultiDictProxy('x-amz-id-2': 'ALvyq4/oejyGLa78AU6p6SQ/25hxIdqFV6HAwasTHG5Rn99Hccp0OgX+aePESHfEYsnLJN7lYOE=', 'x-amz-request-id': 'J4SJK4Y1WM6AEVBP', 'Date': 'Tue, 04 Nov 2025 23:10:04 GMT', 'Last-Modified': 'Thu, 23 Oct 2025 22:52:46 GMT', 'Etag': '"acc59765e38068a8d715b04dc9c7ac0e"', 'x-amz-checksum-crc32': 'YVjHJg==', 'x-amz-checksum-type': 'FULL_OBJECT', 'x-amz-server-side-encryption': 'AES256', 'x-amz-version-id': 't1FixK2cx7KMhtJZ.mQCM2jLKhwFpmRh', 'Accept-Ranges': 'bytes', 'Content-Type': 'binary/octet-stream', 'Content-Length': '3926886', 'Server': 'AmazonS3')>
#
# 2025-11-04 15:10:03 - botocore.hooks - DEBUG - Event needs-retry.s3.GetObject: calling handler <function _update_status_code at 0x7eb8d039e7a0>
# 2025-11-04 15:10:03 - botocore.hooks - DEBUG - Event needs-retry.s3.GetObject: calling handler <aiobotocore.retryhandler.AioRetryHandler object at 0x7ebde6abe2a0>
# 2025-11-04 15:10:03 - botocore.retryhandler - DEBUG - No retry needed.
# 2025-11-04 15:10:03 - botocore.hooks - DEBUG - Event needs-retry.s3.GetObject: calling handler <bound method AioS3RegionRedirectorv2.redirect_from_error of <aiobotocore.utils.AioS3RegionRedirectorv2 object at 0x7ebde6abdc40>>
# 2025-11-04 15:10:03 - s3fs - DEBUG - CALL: head_object - ({},) - {'Bucket': 'czi-variantformer', 'Key': 'model/common/cres_all_genes/ENSG00000001461.16/gene_vocab.csv'}
# 2025-11-04 15:10:03 - botocore.hooks - DEBUG - Event before-parameter-build.s3.HeadObject: calling handler <function sse_md5 at 0x7eb8d035bec0>
# 2025-11-04 15:10:03 - botocore.hooks - DEBUG - Event before-parameter-build.s3.HeadObject: calling handler <function validate_bucket_name at 0x7eb8d035be20>
# 2025-11-04 15:10:03 - botocore.hooks - DEBUG - Event before-parameter-build.s3.HeadObject: calling handler <function remove_bucket_from_url_paths_from_model at 0x7eb8d039e160>
# 2025-11-04 15:10:03 - botocore.hooks - DEBUG - Event before-parameter-build.s3.HeadObject: calling handler <bound method S3RegionRedirectorv2.annotate_request_context of <aiobotocore.utils.AioS3RegionRedirectorv2 object at 0x7ebde6abdc40>>
# 2025-11-04 15:10:03 - botocore.hooks - DEBUG - Event before-parameter-build.s3.HeadObject: calling handler <bound method ClientCreator._inject_s3_input_parameters of <aiobotocore.client.AioClientCreator object at 0x7eb8d03771a0>>
# 2025-11-04 15:10:03 - botocore.hooks - DEBUG - Event before-parameter-build.s3.HeadObject: calling handler <function generate_idempotent_uuid at 0x7eb8d035bc40>
# 2025-11-04 15:10:03 - botocore.hooks - DEBUG - Event before-parameter-build.s3.HeadObject: calling handler <function _handle_request_validation_mode_member at 0x7eb8d039e840>
# 2025-11-04 15:10:03 - botocore.hooks - DEBUG - Event before-endpoint-resolution.s3: calling handler <function customize_endpoint_resolver_builtins at 0x7eb8d039e340>
# 2025-11-04 15:10:03 - botocore.hooks - DEBUG - Event before-endpoint-resolution.s3: calling handler <bound method S3RegionRedirectorv2.redirect_from_cache of <aiobotocore.utils.AioS3RegionRedirectorv2 object at 0x7ebde6abdc40>>
# 2025-11-04 15:10:03 - aiobotocore.regions - DEBUG - Calling endpoint provider with parameters: {'Bucket': 'czi-variantformer', 'Region': 'us-east-1', 'UseFIPS': False, 'UseDualStack': False, 'ForcePathStyle': False, 'Accelerate': False, 'UseGlobalEndpoint': True, 'Key': 'model/common/cres_all_genes/ENSG00000001461.16/gene_vocab.csv', 'DisableMultiRegionAccessPoints': False, 'UseArnRegion': True}
# 2025-11-04 15:10:03 - aiobotocore.regions - DEBUG - Endpoint provider result: https://czi-variantformer.s3.amazonaws.com
# 2025-11-04 15:10:03 - botocore.regions - DEBUG - Selecting from endpoint provider's list of auth schemes: "sigv4". User selected auth scheme is: "<botocore.UNSIGNED object at 0x7eb8d03722a0>"
# 2025-11-04 15:10:03 - botocore.hooks - DEBUG - Event before-call.s3.HeadObject: calling handler <function add_expect_header at 0x7eb8d039c220>
# 2025-11-04 15:10:03 - botocore.hooks - DEBUG - Event before-call.s3.HeadObject: calling handler <bound method S3ExpressIdentityResolver.apply_signing_cache_key of <aiobotocore.utils.AioS3ExpressIdentityResolver object at 0x7eb951cc3500>>
# 2025-11-04 15:10:03 - botocore.hooks - DEBUG - Event before-call.s3.HeadObject: calling handler <function add_recursion_detection_header at 0x7eb8d035a340>
# 2025-11-04 15:10:03 - botocore.hooks - DEBUG - Event before-call.s3.HeadObject: calling handler <function inject_api_version_header_if_needed at 0x7eb8d039d760>
# 2025-11-04 15:10:03 - botocore.endpoint - DEBUG - Making request for OperationModel(name=HeadObject) with params: {'url_path': '/model/common/cres_all_genes/ENSG00000001461.16/gene_vocab.csv', 'query_string': {}, 'method': 'HEAD', 'headers': {'User-Agent': 'aiobotocore/2.25.1 md/Botocore#1.40.61 ua/2.1 os/linux#6.5.13-65-650-4141-22041-coreweave-amd64-85c45edc md/arch#x86_64 lang/python#3.12.10 md/pyimpl#CPython m/Z,b,D cfg/retry-mode#legacy botocore/1.40.61'}, 'body': b'', 'auth_path': '/czi-variantformer/model/common/cres_all_genes/ENSG00000001461.16/gene_vocab.csv', 'url': 'https://czi-variantformer.s3.amazonaws.com/model/common/cres_all_genes/ENSG00000001461.16/gene_vocab.csv', 'context': {'client_region': 'us-east-1', 'client_config': <aiobotocore.config.AioConfig object at 0x7eb9524e1670>, 'has_streaming_input': False, 'auth_type': 'none', 'unsigned_payload': None, 'auth_options': ['aws.auth#sigv4'], 's3_redirect': {'redirected': False, 'bucket': 'czi-variantformer', 'params': {'Bucket': 'czi-variantformer', 'Key': 'model/common/cres_all_genes/ENSG00000001461.16/gene_vocab.csv'}}, 'input_params': {'Bucket': 'czi-variantformer', 'Key': 'model/common/cres_all_genes/ENSG00000001461.16/gene_vocab.csv'}, 'signing': {}, 'endpoint_properties': {'authSchemes': [{'disableDoubleEncoding': True, 'name': 'sigv4', 'signingName': 's3', 'signingRegion': 'us-east-1'}]}}}
# 2025-11-04 15:10:03 - botocore.hooks - DEBUG - Event request-created.s3.HeadObject: calling handler <bound method AioRequestSigner.handler of <aiobotocore.signers.AioRequestSigner object at 0x7eb8d02a7560>>
# 2025-11-04 15:10:03 - botocore.hooks - DEBUG - Event choose-signer.s3.HeadObject: calling handler <function set_operation_specific_signer at 0x7eb8d035b9c0>
# 2025-11-04 15:10:03 - botocore.hooks - DEBUG - Event before-sign.s3.HeadObject: calling handler <function remove_arn_from_signing_path at 0x7eb8d039e2a0>
# 2025-11-04 15:10:03 - botocore.hooks - DEBUG - Event before-sign.s3.HeadObject: calling handler <function _set_extra_headers_for_unsigned_request at 0x7eb8d039e8e0>
# 2025-11-04 15:10:03 - botocore.hooks - DEBUG - Event before-sign.s3.HeadObject: calling handler <bound method S3ExpressIdentityResolver.resolve_s3express_identity of <aiobotocore.utils.AioS3ExpressIdentityResolver object at 0x7eb951cc3500>>
# 2025-11-04 15:10:03 - botocore.hooks - DEBUG - Event request-created.s3.HeadObject: calling handler <bound method UserAgentString.rebuild_and_replace_user_agent_handler of <botocore.useragent.UserAgentString object at 0x7ebde6abdbe0>>
# 2025-11-04 15:10:03 - botocore.hooks - DEBUG - Event request-created.s3.HeadObject: calling handler <function add_retry_headers at 0x7eb8d039e0c0>
# 2025-11-04 15:10:03 - botocore.endpoint - DEBUG - Sending http request: <AWSPreparedRequest stream_output=False, method=HEAD, url=https://czi-variantformer.s3.amazonaws.com/model/common/cres_all_genes/ENSG00000001461.16/gene_vocab.csv, headers={'User-Agent': b'aiobotocore/2.25.1 md/Botocore#1.40.61 ua/2.1 os/linux#6.5.13-65-650-4141-22041-coreweave-amd64-85c45edc md/arch#x86_64 lang/python#3.12.10 md/pyimpl#CPython m/Z,b,D cfg/retry-mode#legacy botocore/1.40.61', 'amz-sdk-invocation-id': b'19742488-81a4-4338-b2ad-b144efcb4c48', 'amz-sdk-request': b'attempt=1'}>
# 2025-11-04 15:10:04 - botocore.hooks - DEBUG - Event before-parse.s3.HeadObject: calling handler <function _handle_200_error at 0x7eb8d039e660>
# 2025-11-04 15:10:04 - botocore.hooks - DEBUG - Event before-parse.s3.HeadObject: calling handler <function handle_expires_header at 0x7eb8d039e480>
# 2025-11-04 15:10:04 - botocore.parsers - DEBUG - Response headers: {'x-amz-id-2': 'NQjRd2ceKm6JLCHqLrx3hJ2UiOchhZJzgujupOZbJbskVKZrtQ33tPGoN8M6txRrZNzQ2WZbU0I=', 'x-amz-request-id': 'CP6ZJ0ZD1NV9Z9AX', 'date': 'Tue, 04 Nov 2025 23:10:05 GMT', 'last-modified': 'Thu, 23 Oct 2025 22:52:46 GMT', 'etag': '"acc59765e38068a8d715b04dc9c7ac0e"', 'x-amz-server-side-encryption': 'AES256', 'x-amz-version-id': 't1FixK2cx7KMhtJZ.mQCM2jLKhwFpmRh', 'accept-ranges': 'bytes', 'content-type': 'binary/octet-stream', 'content-length': '3926886', 'server': 'AmazonS3'}
# 2025-11-04 15:10:04 - botocore.parsers - DEBUG - Response body:
# b''
# 2025-11-04 15:10:04 - botocore.hooks - DEBUG - Event needs-retry.s3.HeadObject: calling handler <function _update_status_code at 0x7eb8d039e7a0>
# 2025-11-04 15:10:04 - botocore.hooks - DEBUG - Event needs-retry.s3.HeadObject: calling handler <aiobotocore.retryhandler.AioRetryHandler object at 0x7ebde6abe2a0>
# 2025-11-04 15:10:04 - botocore.retryhandler - DEBUG - No retry needed.
# 2025-11-04 15:10:04 - botocore.hooks - DEBUG - Event needs-retry.s3.HeadObject: calling handler <bound method AioS3RegionRedirectorv2.redirect_from_error of <aiobotocore.utils.AioS3RegionRedirectorv2 object at 0x7ebde6abdc40>>
# 2025-11-04 15:10:04 - filelock - DEBUG - Attempting to release lock 139332232152368 on /work/_artifacts/model/common/cres_all_genes/ENSG00000001461.16/gene_vocab.csv.lock
# 2025-11-04 15:10:04 - filelock - DEBUG - Lock 139332232152368 released on /work/_artifacts/model/common/cres_all_genes/ENSG00000001461.16/gene_vocab.csv.lock
# 2025-11-04 15:10:11 - filelock - DEBUG - Attempting to acquire lock 139354086545056 on /work/_artifacts/model/common/cres_all_genes/ENSG00000000419.12/gene_vocab.csv.lock
# 2025-11-04 15:10:11 - filelock - DEBUG - Lock 139354086545056 acquired on /work/_artifacts/model/common/cres_all_genes/ENSG00000000419.12/gene_vocab.csv.lock
# 2025-11-04 15:10:11 - s3fs - DEBUG - CALL: get_object - () - {'Bucket': 'czi-variantformer', 'Key': 'model/common/cres_all_genes/ENSG00000000419.12/gene_vocab.csv'}
# 2025-11-04 15:10:11 - botocore.hooks - DEBUG - Event before-parameter-build.s3.GetObject: calling handler <function sse_md5 at 0x7eb8d035bec0>
# 2025-11-04 15:10:11 - botocore.hooks - DEBUG - Event before-parameter-build.s3.GetObject: calling handler <function validate_bucket_name at 0x7eb8d035be20>
# 2025-11-04 15:10:11 - botocore.hooks - DEBUG - Event before-parameter-build.s3.GetObject: calling handler <function remove_bucket_from_url_paths_from_model at 0x7eb8d039e160>
# 2025-11-04 15:10:11 - botocore.hooks - DEBUG - Event before-parameter-build.s3.GetObject: calling handler <bound method S3RegionRedirectorv2.annotate_request_context of <aiobotocore.utils.AioS3RegionRedirectorv2 object at 0x7ebde6abdc40>>
# 2025-11-04 15:10:11 - botocore.hooks - DEBUG - Event before-parameter-build.s3.GetObject: calling handler <bound method ClientCreator._inject_s3_input_parameters of <aiobotocore.client.AioClientCreator object at 0x7eb8d03771a0>>
# 2025-11-04 15:10:11 - botocore.hooks - DEBUG - Event before-parameter-build.s3.GetObject: calling handler <function generate_idempotent_uuid at 0x7eb8d035bc40>
# 2025-11-04 15:10:11 - botocore.hooks - DEBUG - Event before-parameter-build.s3.GetObject: calling handler <function _handle_request_validation_mode_member at 0x7eb8d039e840>
# 2025-11-04 15:10:11 - botocore.hooks - DEBUG - Event before-endpoint-resolution.s3: calling handler <function customize_endpoint_resolver_builtins at 0x7eb8d039e340>
# 2025-11-04 15:10:11 - botocore.hooks - DEBUG - Event before-endpoint-resolution.s3: calling handler <bound method S3RegionRedirectorv2.redirect_from_cache of <aiobotocore.utils.AioS3RegionRedirectorv2 object at 0x7ebde6abdc40>>
# 2025-11-04 15:10:11 - aiobotocore.regions - DEBUG - Calling endpoint provider with parameters: {'Bucket': 'czi-variantformer', 'Region': 'us-east-1', 'UseFIPS': False, 'UseDualStack': False, 'ForcePathStyle': False, 'Accelerate': False, 'UseGlobalEndpoint': True, 'Key': 'model/common/cres_all_genes/ENSG00000000419.12/gene_vocab.csv', 'DisableMultiRegionAccessPoints': False, 'UseArnRegion': True}
# 2025-11-04 15:10:11 - aiobotocore.regions - DEBUG - Endpoint provider result: https://czi-variantformer.s3.amazonaws.com
# 2025-11-04 15:10:11 - botocore.regions - DEBUG - Selecting from endpoint provider's list of auth schemes: "sigv4". User selected auth scheme is: "<botocore.UNSIGNED object at 0x7eb8d03722a0>"
# 2025-11-04 15:10:11 - botocore.hooks - DEBUG - Event before-call.s3.GetObject: calling handler <function add_expect_header at 0x7eb8d039c220>
# 2025-11-04 15:10:11 - botocore.hooks - DEBUG - Event before-call.s3.GetObject: calling handler <bound method S3ExpressIdentityResolver.apply_signing_cache_key of <aiobotocore.utils.AioS3ExpressIdentityResolver object at 0x7eb951cc3500>>
# 2025-11-04 15:10:11 - botocore.hooks - DEBUG - Event before-call.s3.GetObject: calling handler <function add_recursion_detection_header at 0x7eb8d035a340>
# 2025-11-04 15:10:11 - botocore.hooks - DEBUG - Event before-call.s3.GetObject: calling handler <function inject_api_version_header_if_needed at 0x7eb8d039d760>
# 2025-11-04 15:10:11 - botocore.endpoint - DEBUG - Making request for OperationModel(name=GetObject) with params: {'url_path': '/model/common/cres_all_genes/ENSG00000000419.12/gene_vocab.csv', 'query_string': {}, 'method': 'GET', 'headers': {'x-amz-checksum-mode': 'ENABLED', 'User-Agent': 'aiobotocore/2.25.1 md/Botocore#1.40.61 ua/2.1 os/linux#6.5.13-65-650-4141-22041-coreweave-amd64-85c45edc md/arch#x86_64 lang/python#3.12.10 md/pyimpl#CPython m/Z,b,D cfg/retry-mode#legacy botocore/1.40.61'}, 'body': b'', 'auth_path': '/czi-variantformer/model/common/cres_all_genes/ENSG00000000419.12/gene_vocab.csv', 'url': 'https://czi-variantformer.s3.amazonaws.com/model/common/cres_all_genes/ENSG00000000419.12/gene_vocab.csv', 'context': {'client_region': 'us-east-1', 'client_config': <aiobotocore.config.AioConfig object at 0x7eb9524e1670>, 'has_streaming_input': False, 'auth_type': 'none', 'unsigned_payload': None, 'auth_options': ['aws.auth#sigv4'], 's3_redirect': {'redirected': False, 'bucket': 'czi-variantformer', 'params': {'Bucket': 'czi-variantformer', 'Key': 'model/common/cres_all_genes/ENSG00000000419.12/gene_vocab.csv', 'ChecksumMode': 'ENABLED'}}, 'input_params': {'Bucket': 'czi-variantformer', 'Key': 'model/common/cres_all_genes/ENSG00000000419.12/gene_vocab.csv'}, 'signing': {}, 'endpoint_properties': {'authSchemes': [{'disableDoubleEncoding': True, 'name': 'sigv4', 'signingName': 's3', 'signingRegion': 'us-east-1'}]}, 'checksum': {'response_algorithms': ['crc32', 'sha1', 'sha256']}}}
# 2025-11-04 15:10:11 - botocore.hooks - DEBUG - Event request-created.s3.GetObject: calling handler <bound method AioRequestSigner.handler of <aiobotocore.signers.AioRequestSigner object at 0x7eb8d02a7560>>
# 2025-11-04 15:10:11 - botocore.hooks - DEBUG - Event choose-signer.s3.GetObject: calling handler <function set_operation_specific_signer at 0x7eb8d035b9c0>
# 2025-11-04 15:10:11 - botocore.hooks - DEBUG - Event before-sign.s3.GetObject: calling handler <function remove_arn_from_signing_path at 0x7eb8d039e2a0>
# 2025-11-04 15:10:11 - botocore.hooks - DEBUG - Event before-sign.s3.GetObject: calling handler <function _set_extra_headers_for_unsigned_request at 0x7eb8d039e8e0>
# 2025-11-04 15:10:11 - botocore.hooks - DEBUG - Event before-sign.s3.GetObject: calling handler <bound method S3ExpressIdentityResolver.resolve_s3express_identity of <aiobotocore.utils.AioS3ExpressIdentityResolver object at 0x7eb951cc3500>>
# 2025-11-04 15:10:11 - botocore.hooks - DEBUG - Event request-created.s3.GetObject: calling handler <bound method UserAgentString.rebuild_and_replace_user_agent_handler of <botocore.useragent.UserAgentString object at 0x7ebde6abdbe0>>
# 2025-11-04 15:10:11 - botocore.hooks - DEBUG - Event request-created.s3.GetObject: calling handler <function add_retry_headers at 0x7eb8d039e0c0>
# 2025-11-04 15:10:11 - botocore.endpoint - DEBUG - Sending http request: <AWSPreparedRequest stream_output=True, method=GET, url=https://czi-variantformer.s3.amazonaws.com/model/common/cres_all_genes/ENSG00000000419.12/gene_vocab.csv, headers={'x-amz-checksum-mode': b'ENABLED', 'User-Agent': b'aiobotocore/2.25.1 md/Botocore#1.40.61 ua/2.1 os/linux#6.5.13-65-650-4141-22041-coreweave-amd64-85c45edc md/arch#x86_64 lang/python#3.12.10 md/pyimpl#CPython m/Z,b,D cfg/retry-mode#legacy botocore/1.40.61', 'amz-sdk-invocation-id': b'db2f287b-54de-4d69-bffb-73ef0e9fa99e', 'amz-sdk-request': b'attempt=1'}>
# 2025-11-04 15:10:11 - botocore.hooks - DEBUG - Event before-parse.s3.GetObject: calling handler <function _handle_200_error at 0x7eb8d039e660>
# 2025-11-04 15:10:11 - botocore.hooks - DEBUG - Event before-parse.s3.GetObject: calling handler <function handle_expires_header at 0x7eb8d039e480>
# 2025-11-04 15:10:11 - botocore.parsers - DEBUG - Response headers: {'x-amz-id-2': 'mWlhOf2cwj4tWhhuPApUB31gxTtqvx0BQk53xWJnxewTDnAjx030MKYLlSSZSMHXxU5dU0blEm4=', 'x-amz-request-id': 'NRNN5CNB004JK169', 'date': 'Tue, 04 Nov 2025 23:10:12 GMT', 'last-modified': 'Thu, 23 Oct 2025 22:52:46 GMT', 'etag': '"be32dae7ce4eaf545fc13e8c1ae4e2e8"', 'x-amz-checksum-crc32': '9WZ5rg==', 'x-amz-checksum-type': 'FULL_OBJECT', 'x-amz-server-side-encryption': 'AES256', 'x-amz-version-id': 'rdw65sdyOeBgNUuY2ob.em9uwjMQyGMk', 'accept-ranges': 'bytes', 'content-type': 'binary/octet-stream', 'content-length': '4322091', 'server': 'AmazonS3'}
# 2025-11-04 15:10:11 - botocore.parsers - DEBUG - Response body:
# <ClientResponse(https://czi-variantformer.s3.amazonaws.com/model/common/cres_all_genes/ENSG00000000419.12/gene_vocab.csv) [200 OK]>
# <CIMultiDictProxy('x-amz-id-2': 'mWlhOf2cwj4tWhhuPApUB31gxTtqvx0BQk53xWJnxewTDnAjx030MKYLlSSZSMHXxU5dU0blEm4=', 'x-amz-request-id': 'NRNN5CNB004JK169', 'Date': 'Tue, 04 Nov 2025 23:10:12 GMT', 'Last-Modified': 'Thu, 23 Oct 2025 22:52:46 GMT', 'Etag': '"be32dae7ce4eaf545fc13e8c1ae4e2e8"', 'x-amz-checksum-crc32': '9WZ5rg==', 'x-amz-checksum-type': 'FULL_OBJECT', 'x-amz-server-side-encryption': 'AES256', 'x-amz-version-id': 'rdw65sdyOeBgNUuY2ob.em9uwjMQyGMk', 'Accept-Ranges': 'bytes', 'Content-Type': 'binary/octet-stream', 'Content-Length': '4322091', 'Server': 'AmazonS3')>
#
# 2025-11-04 15:10:11 - botocore.hooks - DEBUG - Event needs-retry.s3.GetObject: calling handler <function _update_status_code at 0x7eb8d039e7a0>
# 2025-11-04 15:10:11 - botocore.hooks - DEBUG - Event needs-retry.s3.GetObject: calling handler <aiobotocore.retryhandler.AioRetryHandler object at 0x7ebde6abe2a0>
# 2025-11-04 15:10:11 - botocore.retryhandler - DEBUG - No retry needed.
# 2025-11-04 15:10:11 - botocore.hooks - DEBUG - Event needs-retry.s3.GetObject: calling handler <bound method AioS3RegionRedirectorv2.redirect_from_error of <aiobotocore.utils.AioS3RegionRedirectorv2 object at 0x7ebde6abdc40>>
# 2025-11-04 15:10:12 - s3fs - DEBUG - CALL: head_object - ({},) - {'Bucket': 'czi-variantformer', 'Key': 'model/common/cres_all_genes/ENSG00000000419.12/gene_vocab.csv'}
# 2025-11-04 15:10:12 - botocore.hooks - DEBUG - Event before-parameter-build.s3.HeadObject: calling handler <function sse_md5 at 0x7eb8d035bec0>
# 2025-11-04 15:10:12 - botocore.hooks - DEBUG - Event before-parameter-build.s3.HeadObject: calling handler <function validate_bucket_name at 0x7eb8d035be20>
# 2025-11-04 15:10:12 - botocore.hooks - DEBUG - Event before-parameter-build.s3.HeadObject: calling handler <function remove_bucket_from_url_paths_from_model at 0x7eb8d039e160>
# 2025-11-04 15:10:12 - botocore.hooks - DEBUG - Event before-parameter-build.s3.HeadObject: calling handler <bound method S3RegionRedirectorv2.annotate_request_context of <aiobotocore.utils.AioS3RegionRedirectorv2 object at 0x7ebde6abdc40>>
# 2025-11-04 15:10:12 - botocore.hooks - DEBUG - Event before-parameter-build.s3.HeadObject: calling handler <bound method ClientCreator._inject_s3_input_parameters of <aiobotocore.client.AioClientCreator object at 0x7eb8d03771a0>>
# 2025-11-04 15:10:12 - botocore.hooks - DEBUG - Event before-parameter-build.s3.HeadObject: calling handler <function generate_idempotent_uuid at 0x7eb8d035bc40>
# 2025-11-04 15:10:12 - botocore.hooks - DEBUG - Event before-parameter-build.s3.HeadObject: calling handler <function _handle_request_validation_mode_member at 0x7eb8d039e840>
# 2025-11-04 15:10:12 - botocore.hooks - DEBUG - Event before-endpoint-resolution.s3: calling handler <function customize_endpoint_resolver_builtins at 0x7eb8d039e340>
# 2025-11-04 15:10:12 - botocore.hooks - DEBUG - Event before-endpoint-resolution.s3: calling handler <bound method S3RegionRedirectorv2.redirect_from_cache of <aiobotocore.utils.AioS3RegionRedirectorv2 object at 0x7ebde6abdc40>>
# 2025-11-04 15:10:12 - aiobotocore.regions - DEBUG - Calling endpoint provider with parameters: {'Bucket': 'czi-variantformer', 'Region': 'us-east-1', 'UseFIPS': False, 'UseDualStack': False, 'ForcePathStyle': False, 'Accelerate': False, 'UseGlobalEndpoint': True, 'Key': 'model/common/cres_all_genes/ENSG00000000419.12/gene_vocab.csv', 'DisableMultiRegionAccessPoints': False, 'UseArnRegion': True}
# 2025-11-04 15:10:12 - aiobotocore.regions - DEBUG - Endpoint provider result: https://czi-variantformer.s3.amazonaws.com
# 2025-11-04 15:10:12 - botocore.regions - DEBUG - Selecting from endpoint provider's list of auth schemes: "sigv4". User selected auth scheme is: "<botocore.UNSIGNED object at 0x7eb8d03722a0>"
# 2025-11-04 15:10:12 - botocore.hooks - DEBUG - Event before-call.s3.HeadObject: calling handler <function add_expect_header at 0x7eb8d039c220>
# 2025-11-04 15:10:12 - botocore.hooks - DEBUG - Event before-call.s3.HeadObject: calling handler <bound method S3ExpressIdentityResolver.apply_signing_cache_key of <aiobotocore.utils.AioS3ExpressIdentityResolver object at 0x7eb951cc3500>>
# 2025-11-04 15:10:12 - botocore.hooks - DEBUG - Event before-call.s3.HeadObject: calling handler <function add_recursion_detection_header at 0x7eb8d035a340>
# 2025-11-04 15:10:12 - botocore.hooks - DEBUG - Event before-call.s3.HeadObject: calling handler <function inject_api_version_header_if_needed at 0x7eb8d039d760>
# 2025-11-04 15:10:12 - botocore.endpoint - DEBUG - Making request for OperationModel(name=HeadObject) with params: {'url_path': '/model/common/cres_all_genes/ENSG00000000419.12/gene_vocab.csv', 'query_string': {}, 'method': 'HEAD', 'headers': {'User-Agent': 'aiobotocore/2.25.1 md/Botocore#1.40.61 ua/2.1 os/linux#6.5.13-65-650-4141-22041-coreweave-amd64-85c45edc md/arch#x86_64 lang/python#3.12.10 md/pyimpl#CPython m/Z,b,D cfg/retry-mode#legacy botocore/1.40.61'}, 'body': b'', 'auth_path': '/czi-variantformer/model/common/cres_all_genes/ENSG00000000419.12/gene_vocab.csv', 'url': 'https://czi-variantformer.s3.amazonaws.com/model/common/cres_all_genes/ENSG00000000419.12/gene_vocab.csv', 'context': {'client_region': 'us-east-1', 'client_config': <aiobotocore.config.AioConfig object at 0x7eb9524e1670>, 'has_streaming_input': False, 'auth_type': 'none', 'unsigned_payload': None, 'auth_options': ['aws.auth#sigv4'], 's3_redirect': {'redirected': False, 'bucket': 'czi-variantformer', 'params': {'Bucket': 'czi-variantformer', 'Key': 'model/common/cres_all_genes/ENSG00000000419.12/gene_vocab.csv'}}, 'input_params': {'Bucket': 'czi-variantformer', 'Key': 'model/common/cres_all_genes/ENSG00000000419.12/gene_vocab.csv'}, 'signing': {}, 'endpoint_properties': {'authSchemes': [{'disableDoubleEncoding': True, 'name': 'sigv4', 'signingName': 's3', 'signingRegion': 'us-east-1'}]}}}
# 2025-11-04 15:10:12 - botocore.hooks - DEBUG - Event request-created.s3.HeadObject: calling handler <bound method AioRequestSigner.handler of <aiobotocore.signers.AioRequestSigner object at 0x7eb8d02a7560>>
# 2025-11-04 15:10:12 - botocore.hooks - DEBUG - Event choose-signer.s3.HeadObject: calling handler <function set_operation_specific_signer at 0x7eb8d035b9c0>
# 2025-11-04 15:10:12 - botocore.hooks - DEBUG - Event before-sign.s3.HeadObject: calling handler <function remove_arn_from_signing_path at 0x7eb8d039e2a0>
# 2025-11-04 15:10:12 - botocore.hooks - DEBUG - Event before-sign.s3.HeadObject: calling handler <function _set_extra_headers_for_unsigned_request at 0x7eb8d039e8e0>
# 2025-11-04 15:10:12 - botocore.hooks - DEBUG - Event before-sign.s3.HeadObject: calling handler <bound method S3ExpressIdentityResolver.resolve_s3express_identity of <aiobotocore.utils.AioS3ExpressIdentityResolver object at 0x7eb951cc3500>>
# 2025-11-04 15:10:12 - botocore.hooks - DEBUG - Event request-created.s3.HeadObject: calling handler <bound method UserAgentString.rebuild_and_replace_user_agent_handler of <botocore.useragent.UserAgentString object at 0x7ebde6abdbe0>>
# 2025-11-04 15:10:12 - botocore.hooks - DEBUG - Event request-created.s3.HeadObject: calling handler <function add_retry_headers at 0x7eb8d039e0c0>
# 2025-11-04 15:10:12 - botocore.endpoint - DEBUG - Sending http request: <AWSPreparedRequest stream_output=False, method=HEAD, url=https://czi-variantformer.s3.amazonaws.com/model/common/cres_all_genes/ENSG00000000419.12/gene_vocab.csv, headers={'User-Agent': b'aiobotocore/2.25.1 md/Botocore#1.40.61 ua/2.1 os/linux#6.5.13-65-650-4141-22041-coreweave-amd64-85c45edc md/arch#x86_64 lang/python#3.12.10 md/pyimpl#CPython m/Z,b,D cfg/retry-mode#legacy botocore/1.40.61', 'amz-sdk-invocation-id': b'fc1e215f-cd68-4719-983b-5806ca1a443e', 'amz-sdk-request': b'attempt=1'}>
# 2025-11-04 15:10:12 - botocore.hooks - DEBUG - Event before-parse.s3.HeadObject: calling handler <function _handle_200_error at 0x7eb8d039e660>
# 2025-11-04 15:10:12 - botocore.hooks - DEBUG - Event before-parse.s3.HeadObject: calling handler <function handle_expires_header at 0x7eb8d039e480>
# 2025-11-04 15:10:12 - botocore.parsers - DEBUG - Response headers: {'x-amz-id-2': '+IElI4+q/S+WGETBKnDLBg+lU4DOyncvrKAwdweXYnEHjnkqjNaj2eIO06wVXY9kzVG2I8eG4Qo=', 'x-amz-request-id': '2J5GTP3K2X5DK9HF', 'date': 'Tue, 04 Nov 2025 23:10:13 GMT', 'last-modified': 'Thu, 23 Oct 2025 22:52:46 GMT', 'etag': '"be32dae7ce4eaf545fc13e8c1ae4e2e8"', 'x-amz-server-side-encryption': 'AES256', 'x-amz-version-id': 'rdw65sdyOeBgNUuY2ob.em9uwjMQyGMk', 'accept-ranges': 'bytes', 'content-type': 'binary/octet-stream', 'content-length': '4322091', 'server': 'AmazonS3'}
# 2025-11-04 15:10:12 - botocore.parsers - DEBUG - Response body:
# b''
# 2025-11-04 15:10:12 - botocore.hooks - DEBUG - Event needs-retry.s3.HeadObject: calling handler <function _update_status_code at 0x7eb8d039e7a0>
# 2025-11-04 15:10:12 - botocore.hooks - DEBUG - Event needs-retry.s3.HeadObject: calling handler <aiobotocore.retryhandler.AioRetryHandler object at 0x7ebde6abe2a0>
# 2025-11-04 15:10:12 - botocore.retryhandler - DEBUG - No retry needed.
# 2025-11-04 15:10:12 - botocore.hooks - DEBUG - Event needs-retry.s3.HeadObject: calling handler <bound method AioS3RegionRedirectorv2.redirect_from_error of <aiobotocore.utils.AioS3RegionRedirectorv2 object at 0x7ebde6abdc40>>
# 2025-11-04 15:10:12 - filelock - DEBUG - Attempting to release lock 139354086545056 on /work/_artifacts/model/common/cres_all_genes/ENSG00000000419.12/gene_vocab.csv.lock
# 2025-11-04 15:10:12 - filelock - DEBUG - Lock 139354086545056 released on /work/_artifacts/model/common/cres_all_genes/ENSG00000000419.12/gene_vocab.csv.lock
# ✅ Predictions completed in 29.7 seconds!
# 📊 Results shape: (2, 5)

# %% [markdown]
# ## 7. Analyze Results

# %%
print("📊 PREDICTION RESULTS ANALYSIS")
print("=" * 50)

# Display basic information about results
print("🔍 Results Overview:")
print(f"   • Number of predictions: {len(predictions_df)}")
print(f"   • Columns: {list(predictions_df.columns)}")
print("\n📋 Sample Results:")
print("=" * 30)
print("Predictions:")
predictions_df
# Out:
# 📊 PREDICTION RESULTS ANALYSIS
# ==================================================
# 🔍 Results Overview:
#    • Number of predictions: 2
#    • Columns: ['gene_id', 'tissues', 'tissue_names', 'predicted_expression', 'embeddings']
#
# 📋 Sample Results:
# ==============================
# Predictions:
#               gene_id       tissues                            tissue_names  \
# 0  ENSG00000001461.16  [62, 59, 10]  [whole blood, thyroid, artery - aorta]
# 1  ENSG00000000419.12          [15]                      [brain - amygdala]
#
#                     predicted_expression  \
# 0  [[1.2623504], [2.944679], [1.612904]]
# 1                          [[2.8708205]]
#
#                                           embeddings
# 0  [[-6.375, -4.78125, 1.5546875, 2.71875, 0.4042...
# 1  [[9.625, 4.65625, -3.34375, 1.90625, 19.625, -...

# %% [markdown]
# **The output schema**
# - Original query information: (gene_id, tissues)
# - `predicted_expression`: Model's prediction of gene expression levels
# - `embeddings`: High-dimensional representations of the gene conditioned on tissue and neighboring regulatory regions

# %% [markdown]
# ## Run the analysis on ref genome hg38 without any mutations
# This analysis allows to compare gene expression change due to the presence of the mutations.

# %%
# Np VCF file provided, so using empty string
vcf_dataset, dataloader = vcf_processor.create_data("", query_df) # Replace actual VCF path with "" to indicate no VCF
predictions_df_ref = vcf_processor.predict(
    model, checkpoint_path, trainer, dataloader, vcf_dataset
)
# Out:
# INFO: Restoring states from the checkpoint path at /work/_artifacts/v4_ag_epoch9_checkpoint.pth
# 2025-11-04 15:10:40 - lightning.pytorch.utilities.rank_zero - INFO - Restoring states from the checkpoint path at /work/_artifacts/v4_ag_epoch9_checkpoint.pth
# 2025-11-04 15:10:40 - fsspec.local - DEBUG - open file: /work/_artifacts/v4_ag_epoch9_checkpoint.pth
# Loaded BPE vocabulary from /work/vocabs/bpe_vocabulary_500.json
# Filtered query df to 2 genes reducing from 2
# /work/.venv/lib/python3.12/site-packages/lightning/pytorch/trainer/call.py:283: Be aware that when using `ckpt_path`, callbacks used to create the checkpoint need to be provided during `Trainer` instantiation. Please add the following callbacks: ["ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}"].
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# 2025-11-04 15:10:46 - lightning.pytorch.accelerators.cuda - INFO - LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO: Loaded model weights from the checkpoint at /work/_artifacts/v4_ag_epoch9_checkpoint.pth
# 2025-11-04 15:10:46 - lightning.pytorch.utilities.rank_zero - INFO - Loaded model weights from the checkpoint at /work/_artifacts/v4_ag_epoch9_checkpoint.pth
# Predicting: |          | 0/? [00:00<?, ?it/s]
# 2025-11-04 15:10:47 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/cres_all_genes_manifest.parquet
# 2025-11-04 15:10:48 - utils.assets - INFO - Loading parquet file: /work/_artifacts/model/common/cres_all_genes_manifest.parquet
# 2025-11-04 15:10:48 - utils.assets - INFO - Validated schema - found columns: {'gene_id', 'file_path'}
# 2025-11-04 15:10:48 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/cres_all_genes/ENSG00000001461.16/gene_vocab.csv
# 2025-11-04 15:10:49 - utils.assets - INFO - Using cached file: /work/_artifacts/model/common/cres_all_genes/ENSG00000000419.12/gene_vocab.csv

# %%
print("✅ Predictions with made from reference genome (no VCF provided):")  
predictions_df_ref.head()
# Out:
# ✅ Predictions with made from reference genome (no VCF provided):
#               gene_id       tissues                            tissue_names  \
# 0  ENSG00000001461.16  [62, 59, 10]  [whole blood, thyroid, artery - aorta]
# 1  ENSG00000000419.12          [15]                      [brain - amygdala]
#
#                       predicted_expression  \
# 0  [[1.1905905], [2.7972884], [1.6317137]]
# 1                            [[2.8560872]]
#
#                                           embeddings
# 0  [[-5.71875, -4.65625, 1.0859375, 1.9765625, -1...
# 1  [[9.625, 3.453125, -3.703125, 2.328125, 18.875...

# %% [markdown]
# ### Compare the log2fc from REF genome

# %%
import numpy as np

# Extract the predicted expression values from nested lists
ref_expr = predictions_df_ref['predicted_expression'].values[0]
vcf_expr = predictions_df['predicted_expression'].values[0]

# Calculate log2 fold change
print(f'Tissues: {predictions_df["tissue_names"].values[0]}')
print(f'Log2 fold change: {np.log2(vcf_expr / ref_expr)}')
# Out:
# Tissues: ['whole blood', 'thyroid', 'artery - aorta']
# Log2 fold change: [[ 0.0844352 ]
#  [ 0.07408135]
#  [-0.0167275 ]]

# %%
predictions_df
# Out:
#               gene_id       tissues                            tissue_names  \
# 0  ENSG00000001461.16  [62, 59, 10]  [whole blood, thyroid, artery - aorta]
# 1  ENSG00000000419.12          [15]                      [brain - amygdala]
#
#                     predicted_expression  \
# 0  [[1.2623504], [2.944679], [1.612904]]
# 1                          [[2.8708205]]
#
#                                           embeddings
# 0  [[-6.375, -4.78125, 1.5546875, 2.71875, 0.4042...
# 1  [[9.625, 4.65625, -3.34375, 1.90625, 19.625, -...
